# %% [markdown]
# ### Model preparation

# %%
import torch
import torch.nn as nn
from PIL import Image
import os
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, f1_score, confusion_matrix
from torchvision.models import densenet121, densenet169
from torch.utils.data import Dataset
from torchvision import transforms

num_classes = 10

model = densenet121()

model.classifier = nn.Linear(model.classifier.in_features, num_classes)

'''
model.classifier = nn.Sequential(
    nn.Linear(model.classifier.in_features, 512),
    nn.ReLU(),
    nn.Dropout(p=0.3),   # Dropout layer
    nn.Linear(512, num_classes)
)
'''
# Out:
# '\nmodel.classifier = nn.Sequential(\n    nn.Linear(model.classifier.in_features, 512),\n    nn.ReLU(),\n    nn.Dropout(p=0.3),   # Dropout layer\n    nn.Linear(512, num_classes)\n)\n'

# %% [markdown]
# ### Dataset preparation

# %%
class SpectrogramDataset(Dataset):
    def __init__(self, dataframe=None, csv_file=None, root_dir=None, transform=None, label_map=None):
        if dataframe is not None:
            self.annotations = dataframe.reset_index(drop=True)
        elif csv_file is not None:
            self.annotations = pd.read_csv(csv_file)
        else:
            raise ValueError("This should be either dataframe or csv!")

        self.root_dir = root_dir
        self.transform = transform
        self.label_map = label_map or self._build_label_map()

    def _build_label_map(self):
        labels = self.annotations['genre'].unique()
        return {label: idx for idx, label in enumerate(sorted(labels))}

    def __len__(self):
        return len(self.annotations)

    def __getitem__(self, idx):
        filename = self.annotations.iloc[idx, 0]
        subfolder = filename.split('.')[0]
        filename = filename[:-4] + '.png'
        img_name = os.path.join(self.root_dir, subfolder, filename)

        image = Image.open(img_name).convert('RGB')
        label_str = self.annotations.iloc[idx, 1]
        label = self.label_map[label_str]

        if self.transform:
            image = self.transform(image)

        return image, label

# %%
'''
from sklearn.model_selection import train_test_split
csv_file = 'project_data/tracks.csv'
df = pd.read_csv(csv_file)
df = df.sample(frac=1).reset_index(drop=True)
train_df, temp_df = train_test_split(df, test_size=0.3, stratify=df['genre'])
valid_df, test_df = train_test_split(temp_df, test_size=0.5, stratify=temp_df['genre'])

train_df.to_csv('densenet_dataset_split/train.csv', index=False)
valid_df.to_csv('densenet_dataset_split/valid.csv', index=False)
test_df.to_csv('densenet_dataset_split/test.csv', index=False)

print("Data has been split into train.csv, valid.csv, and test.csv with balanced genres.")
'''
# Out:
# '\nfrom sklearn.model_selection import train_test_split\ncsv_file = \'project_data/tracks.csv\'\ndf = pd.read_csv(csv_file)\ndf = df.sample(frac=1).reset_index(drop=True)\ntrain_df, temp_df = train_test_split(df, test_size=0.3, stratify=df[\'genre\'])\nvalid_df, test_df = train_test_split(temp_df, test_size=0.5, stratify=temp_df[\'genre\'])\n\ntrain_df.to_csv(\'densenet_dataset_split/train.csv\', index=False)\nvalid_df.to_csv(\'densenet_dataset_split/valid.csv\', index=False)\ntest_df.to_csv(\'densenet_dataset_split/test.csv\', index=False)\n\nprint("Data has been split into train.csv, valid.csv, and test.csv with balanced genres.")\n'

# %%
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])

train_df = pd.read_csv('densenet_dataset_split/train.csv')
val_df = pd.read_csv('densenet_dataset_split/valid.csv')
test_df = pd.read_csv('densenet_dataset_split/test.csv')

train_dataset = SpectrogramDataset(
    dataframe=train_df,
    root_dir='../project_data/spectrograms',
    transform=transform
)

val_dataset = SpectrogramDataset(
    dataframe=val_df,
    root_dir='../project_data/spectrograms',
    transform=transform
)

test_dataset = SpectrogramDataset(
    dataframe=test_df,
    root_dir='../project_data/spectrograms',
    transform=transform
)

# %%
#validation
image, label = train_dataset[1]
print(image.shape)
print(label)
print(train_dataset.label_map)
# Out:
# torch.Size([3, 224, 224])
# 6
# {'blues': 0, 'classical': 1, 'country': 2, 'disco': 3, 'hiphop': 4, 'jazz': 5, 'metal': 6, 'pop': 7, 'reggae': 8, 'rock': 9}

# %%
print(torch.__version__)
print(torch.version.cuda)
print(torch.backends.cudnn.version())

if torch.cuda.is_available():
    print(f"CUDA is available. Using GPU: {torch.cuda.get_device_name(0)}")
else: 
    print("CUDA is not available. Using CPU.")
# Out:
# 2.5.1+cu121
# 12.1
# 90100
# CUDA is available. Using GPU: NVIDIA GeForce GTX 1650

# %% [markdown]
# ### Model training

# %%
def get_filename_with_date(prefix="model", extension="pth"):
    now = datetime.datetime.now()
    date_str = now.strftime("%d_%b_%H_%M")
    return f"{prefix}_{date_str}.{extension}"


class EarlyStopping:
    def __init__(self, patience=5, delta=0.0):
        self.patience = patience
        self.delta = delta
        self.counter = 0
        self.best_loss = None
        self.early_stop = False
        self.best_model_state = None

    def __call__(self, val_loss, model):
        if self.best_loss is None:
            self.best_loss = val_loss
        elif val_loss > self.best_loss - self.delta:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_loss = val_loss
            self.counter = 0
            self.best_model_state = model.state_dict()

# %%
import torch.optim as optim
from torch.utils.data import DataLoader

def optimizer_to(optimizer, device):
    for param_group in optimizer.param_groups:
        for param in param_group['params']:
            param.data = param.data.to(device)
    return optimizer

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print(device)
criterion = nn.CrossEntropyLoss()
#optimizer = optim.Adam(model.parameters(), lr=1e-4)
optimizer = optim.AdamW(model.parameters(), lr=5e-5, weight_decay=1e-2, eps=1e-8)


start_epoch = 0
num_epochs = 100


train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []
train_precisions = []
val_precisions = []


#BELOW: loading existing checkpoint model
'''
optimizer = optimizer_to(optimizer, device)
checkpoint = torch.load('model_densenet169_13_May_19_22.pth', map_location=device)
model.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
start_epoch = checkpoint['epoch']

num_epochs = 25
train_losses = checkpoint['train_losses']
val_losses = checkpoint['val_losses']
train_accuracies = checkpoint['train_accuracies']
val_accuracies = checkpoint['val_accuracies']
train_precisions = checkpoint['train_precisions: ']
val_precisions = checkpoint['val_precisions']
'''
# Out:
# cuda
# "\noptimizer = optimizer_to(optimizer, device)\ncheckpoint = torch.load('model_densenet169_13_May_19_22.pth', map_location=device)\nmodel.load_state_dict(checkpoint['model_state_dict'])\noptimizer.load_state_dict(checkpoint['optimizer_state_dict'])\nstart_epoch = checkpoint['epoch']\n\nnum_epochs = 25\ntrain_losses = checkpoint['train_losses']\nval_losses = checkpoint['val_losses']\ntrain_accuracies = checkpoint['train_accuracies']\nval_accuracies = checkpoint['val_accuracies']\ntrain_precisions = checkpoint['train_precisions: ']\nval_precisions = checkpoint['val_precisions']\n"

# %%
model = model.to(device, non_blocking=True) #CUDA
early_stopping = EarlyStopping(patience=5, delta=0.001)
for epoch in range(start_epoch, num_epochs):
    # Training phase
    model.train()
    total_train_loss = 0
    correct_train = 0
    total_train = 0
    y_train_true = []
    y_train_pred = []
    for images, labels in train_loader:
        images, labels = images.to(device, non_blocking=True), labels.to(device, non_blocking=True)

        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        total_train_loss += loss.item()

        _, predicted = torch.max(outputs, 1)
        correct_train += (predicted == labels).sum().item()
        total_train += labels.size(0)

        y_train_true.extend(labels.cpu().numpy())
        y_train_pred.extend(predicted.cpu().numpy())

    avg_train_loss = total_train_loss / len(train_loader)
    train_accuracy = correct_train / total_train

    train_losses.append(avg_train_loss)
    train_accuracies.append(train_accuracy)

    train_precision = precision_score(y_train_true, y_train_pred, average='macro', zero_division=0)
    train_precisions.append(train_precision)

    # Validation phase
    model.eval()
    total_val_loss = 0
    correct_val = 0
    total_val = 0
    y_val_true = []
    y_val_pred = []
    
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device, non_blocking=True), labels.to(device, non_blocking=True)
            outputs = model(images)
            total_val_loss += criterion(outputs, labels).item()

            _, predicted = torch.max(outputs, 1)
            correct_val += (predicted == labels).sum().item()
            total_val += labels.size(0)

            y_val_true.extend(labels.cpu().numpy())
            y_val_pred.extend(predicted.cpu().numpy())

    avg_val_loss = total_val_loss / len(val_loader)
    val_accuracy = correct_val / total_val

    val_losses.append(avg_val_loss)
    val_accuracies.append(val_accuracy)

    val_precision = precision_score(y_val_true, y_val_pred, average='macro', zero_division=0)
    val_precisions.append(val_precision)

    '''
    early_stopping(avg_val_loss, model)
    if early_stopping.early_stop:
        print(f"Early stopping at epoch {epoch+1}")
        num_epochs = epoch + 1
        break
    '''

    print(f"Epoch {epoch+1} | Train Loss: {avg_train_loss:.4f} | Train Acc: {train_accuracy:.4f} | Train Prec: {train_precision:.4f}")
    print(f"Epoch {epoch+1} | Val Loss: {avg_val_loss:.4f} | Val Acc: {val_accuracy:.4f} | Val Prec: {val_precision:.4f}")
# Out:
# Epoch 1 | Train Loss: 2.0805 | Train Acc: 0.2671 | Train Prec: 0.3532
# Epoch 1 | Val Loss: 2.2163 | Val Acc: 0.1333 | Val Prec: 0.1906
# Epoch 2 | Train Loss: 1.7305 | Train Acc: 0.4657 | Train Prec: 0.4706
# Epoch 2 | Val Loss: 1.7143 | Val Acc: 0.3733 | Val Prec: 0.3230
# Epoch 3 | Train Loss: 1.5122 | Train Acc: 0.5429 | Train Prec: 0.5547
# Epoch 3 | Val Loss: 1.4832 | Val Acc: 0.5200 | Val Prec: 0.5295
# Epoch 4 | Train Loss: 1.3479 | Train Acc: 0.5857 | Train Prec: 0.5898
# Epoch 4 | Val Loss: 1.3642 | Val Acc: 0.5333 | Val Prec: 0.5320
# Epoch 5 | Train Loss: 1.2316 | Train Acc: 0.6214 | Train Prec: 0.6157
# Epoch 5 | Val Loss: 1.2842 | Val Acc: 0.5733 | Val Prec: 0.5733
# Epoch 6 | Train Loss: 1.1069 | Train Acc: 0.6486 | Train Prec: 0.6478
# Epoch 6 | Val Loss: 1.2313 | Val Acc: 0.5933 | Val Prec: 0.6161
# Epoch 7 | Train Loss: 1.0101 | Train Acc: 0.7114 | Train Prec: 0.7076
# Epoch 7 | Val Loss: 1.1932 | Val Acc: 0.5933 | Val Prec: 0.6291
# Epoch 8 | Train Loss: 0.9190 | Train Acc: 0.7343 | Train Prec: 0.7314
# Epoch 8 | Val Loss: 1.1326 | Val Acc: 0.6000 | Val Prec: 0.6070
# Epoch 9 | Train Loss: 0.8190 | Train Acc: 0.7457 | Train Prec: 0.7424
# Epoch 9 | Val Loss: 1.1831 | Val Acc: 0.5400 | Val Prec: 0.5883
# Epoch 10 | Train Loss: 0.7714 | Train Acc: 0.7886 | Train Prec: 0.7840
# Epoch 10 | Val Loss: 1.2060 | Val Acc: 0.5533 | Val Prec: 0.5994
# Epoch 11 | Train Loss: 0.6926 | Train Acc: 0.8114 | Train Prec: 0.8128
# Epoch 11 | Val Loss: 1.0826 | Val Acc: 0.6133 | Val Prec: 0.6228
# Epoch 12 | Train Loss: 0.6382 | Train Acc: 0.8400 | Train Prec: 0.8402
# Epoch 12 | Val Loss: 1.1163 | Val Acc: 0.5867 | Val Prec: 0.6239
# Epoch 13 | Train Loss: 0.5525 | Train Acc: 0.8757 | Train Prec: 0.8772
# Epoch 13 | Val Loss: 1.0333 | Val Acc: 0.6400 | Val Prec: 0.6690
# Epoch 14 | Train Loss: 0.4372 | Train Acc: 0.9057 | Train Prec: 0.9061
# Epoch 14 | Val Loss: 1.0171 | Val Acc: 0.6267 | Val Prec: 0.6227
# Epoch 15 | Train Loss: 0.3771 | Train Acc: 0.9271 | Train Prec: 0.9271
# Epoch 15 | Val Loss: 1.0267 | Val Acc: 0.6400 | Val Prec: 0.6706
# Epoch 16 | Train Loss: 0.3165 | Train Acc: 0.9529 | Train Prec: 0.9532
# Epoch 16 | Val Loss: 1.0379 | Val Acc: 0.6200 | Val Prec: 0.6487
# Epoch 17 | Train Loss: 0.2323 | Train Acc: 0.9686 | Train Prec: 0.9689
# Epoch 17 | Val Loss: 1.0410 | Val Acc: 0.6733 | Val Prec: 0.6935
# Epoch 18 | Train Loss: 0.2159 | Train Acc: 0.9729 | Train Prec: 0.9735
# Epoch 18 | Val Loss: 1.0765 | Val Acc: 0.6800 | Val Prec: 0.7109
# Epoch 19 | Train Loss: 0.1899 | Train Acc: 0.9857 | Train Prec: 0.9857
# Epoch 19 | Val Loss: 1.0218 | Val Acc: 0.6933 | Val Prec: 0.7341
# Epoch 20 | Train Loss: 0.1320 | Train Acc: 0.9943 | Train Prec: 0.9943
# Epoch 20 | Val Loss: 1.0143 | Val Acc: 0.7000 | Val Prec: 0.7221
# Epoch 21 | Train Loss: 0.1549 | Train Acc: 0.9786 | Train Prec: 0.9788
# Epoch 21 | Val Loss: 1.0186 | Val Acc: 0.7067 | Val Prec: 0.7237
# Epoch 22 | Train Loss: 0.1082 | Train Acc: 0.9871 | Train Prec: 0.9872
# Epoch 22 | Val Loss: 1.0742 | Val Acc: 0.6333 | Val Prec: 0.6613
# Epoch 23 | Train Loss: 0.0963 | Train Acc: 0.9929 | Train Prec: 0.9929
# Epoch 23 | Val Loss: 1.0446 | Val Acc: 0.6467 | Val Prec: 0.6785
# Epoch 24 | Train Loss: 0.0929 | Train Acc: 0.9957 | Train Prec: 0.9957
# Epoch 24 | Val Loss: 1.1075 | Val Acc: 0.6333 | Val Prec: 0.6533
# Epoch 25 | Train Loss: 0.0892 | Train Acc: 0.9929 | Train Prec: 0.9929
# Epoch 25 | Val Loss: 1.2208 | Val Acc: 0.6400 | Val Prec: 0.6895
# Epoch 26 | Train Loss: 0.0679 | Train Acc: 0.9957 | Train Prec: 0.9958
# Epoch 26 | Val Loss: 0.9601 | Val Acc: 0.6800 | Val Prec: 0.6947
# Epoch 27 | Train Loss: 0.0577 | Train Acc: 0.9971 | Train Prec: 0.9972
# Epoch 27 | Val Loss: 0.9713 | Val Acc: 0.7000 | Val Prec: 0.7172
# Epoch 28 | Train Loss: 0.0444 | Train Acc: 0.9986 | Train Prec: 0.9986
# Epoch 28 | Val Loss: 0.9383 | Val Acc: 0.6800 | Val Prec: 0.6985
# Epoch 29 | Train Loss: 0.0424 | Train Acc: 1.0000 | Train Prec: 1.0000
# Epoch 29 | Val Loss: 0.9502 | Val Acc: 0.6867 | Val Prec: 0.6966
# Epoch 30 | Train Loss: 0.0437 | Train Acc: 1.0000 | Train Prec: 1.0000
# Epoch 30 | Val Loss: 0.9896 | Val Acc: 0.7000 | Val Prec: 0.7291
# Epoch 31 | Train Loss: 0.0850 | Train Acc: 0.9843 | Train Prec: 0.9843
# Epoch 31 | Val Loss: 1.1834 | Val Acc: 0.6400 | Val Prec: 0.6843
# Epoch 32 | Train Loss: 0.0625 | Train Acc: 0.9929 | Train Prec: 0.9929
# Epoch 32 | Val Loss: 1.1027 | Val Acc: 0.6600 | Val Prec: 0.6476
# Epoch 33 | Train Loss: 0.0504 | Train Acc: 0.9971 | Train Prec: 0.9972
# Epoch 33 | Val Loss: 1.0963 | Val Acc: 0.6533 | Val Prec: 0.6475
# Epoch 34 | Train Loss: 0.0576 | Train Acc: 0.9943 | Train Prec: 0.9944
# Epoch 34 | Val Loss: 1.1573 | Val Acc: 0.6867 | Val Prec: 0.7166
# Epoch 35 | Train Loss: 0.0528 | Train Acc: 0.9957 | Train Prec: 0.9958
# Epoch 35 | Val Loss: 0.9648 | Val Acc: 0.7133 | Val Prec: 0.7437
# Epoch 36 | Train Loss: 0.0499 | Train Acc: 0.9971 | Train Prec: 0.9972
# Epoch 36 | Val Loss: 1.3044 | Val Acc: 0.6200 | Val Prec: 0.6825
# Epoch 37 | Train Loss: 0.0375 | Train Acc: 0.9943 | Train Prec: 0.9943
# Epoch 37 | Val Loss: 0.9459 | Val Acc: 0.7133 | Val Prec: 0.7297
# Epoch 38 | Train Loss: 0.0263 | Train Acc: 1.0000 | Train Prec: 1.0000
# Epoch 38 | Val Loss: 0.9783 | Val Acc: 0.6933 | Val Prec: 0.7103
# Epoch 39 | Train Loss: 0.0218 | Train Acc: 1.0000 | Train Prec: 1.0000
# Epoch 39 | Val Loss: 0.9701 | Val Acc: 0.7067 | Val Prec: 0.7225
# Epoch 40 | Train Loss: 0.0228 | Train Acc: 1.0000 | Train Prec: 1.0000
# Epoch 40 | Val Loss: 1.0480 | Val Acc: 0.6800 | Val Prec: 0.6893
# Epoch 41 | Train Loss: 0.0238 | Train Acc: 0.9986 | Train Prec: 0.9986
# Epoch 41 | Val Loss: 1.0523 | Val Acc: 0.7067 | Val Prec: 0.7431
# Epoch 42 | Train Loss: 0.0282 | Train Acc: 0.9986 | Train Prec: 0.9986
# Epoch 42 | Val Loss: 1.0135 | Val Acc: 0.7200 | Val Prec: 0.7303
# Epoch 43 | Train Loss: 0.0175 | Train Acc: 1.0000 | Train Prec: 1.0000
# Epoch 43 | Val Loss: 1.0088 | Val Acc: 0.6933 | Val Prec: 0.7144
# Epoch 44 | Train Loss: 0.0187 | Train Acc: 1.0000 | Train Prec: 1.0000
# Epoch 44 | Val Loss: 0.9775 | Val Acc: 0.7000 | Val Prec: 0.7163
# Epoch 45 | Train Loss: 0.0176 | Train Acc: 1.0000 | Train Prec: 1.0000
# Epoch 45 | Val Loss: 1.0013 | Val Acc: 0.6867 | Val Prec: 0.7092
# Epoch 46 | Train Loss: 0.0172 | Train Acc: 1.0000 | Train Prec: 1.0000
# Epoch 46 | Val Loss: 0.9576 | Val Acc: 0.7133 | Val Prec: 0.7269
# Epoch 47 | Train Loss: 0.0169 | Train Acc: 1.0000 | Train Prec: 1.0000
# Epoch 47 | Val Loss: 0.9609 | Val Acc: 0.7333 | Val Prec: 0.7424
# Epoch 48 | Train Loss: 0.0243 | Train Acc: 0.9986 | Train Prec: 0.9986
# Epoch 48 | Val Loss: 1.0718 | Val Acc: 0.6800 | Val Prec: 0.6964
# Epoch 49 | Train Loss: 0.0256 | Train Acc: 0.9986 | Train Prec: 0.9986
# Epoch 49 | Val Loss: 1.1747 | Val Acc: 0.6667 | Val Prec: 0.6949
# Epoch 50 | Train Loss: 0.0268 | Train Acc: 0.9986 | Train Prec: 0.9986
# Epoch 50 | Val Loss: 1.0776 | Val Acc: 0.6867 | Val Prec: 0.6796
# Epoch 51 | Train Loss: 0.0227 | Train Acc: 0.9986 | Train Prec: 0.9986
# Epoch 51 | Val Loss: 1.0526 | Val Acc: 0.7067 | Val Prec: 0.7245
# Epoch 52 | Train Loss: 0.0257 | Train Acc: 0.9957 | Train Prec: 0.9958
# Epoch 52 | Val Loss: 1.3836 | Val Acc: 0.6267 | Val Prec: 0.7360
# Epoch 53 | Train Loss: 0.0308 | Train Acc: 0.9957 | Train Prec: 0.9958
# Epoch 53 | Val Loss: 1.2266 | Val Acc: 0.6867 | Val Prec: 0.6765
# Epoch 54 | Train Loss: 0.0479 | Train Acc: 0.9914 | Train Prec: 0.9915
# Epoch 54 | Val Loss: 1.0712 | Val Acc: 0.6600 | Val Prec: 0.6902
# Epoch 55 | Train Loss: 0.0530 | Train Acc: 0.9900 | Train Prec: 0.9902
# Epoch 55 | Val Loss: 1.4398 | Val Acc: 0.6600 | Val Prec: 0.7254
# Epoch 56 | Train Loss: 0.0473 | Train Acc: 0.9914 | Train Prec: 0.9914
# Epoch 56 | Val Loss: 1.1210 | Val Acc: 0.6467 | Val Prec: 0.6602
# Epoch 57 | Train Loss: 0.0341 | Train Acc: 0.9929 | Train Prec: 0.9929
# Epoch 57 | Val Loss: 1.0402 | Val Acc: 0.7267 | Val Prec: 0.7265
# Epoch 58 | Train Loss: 0.0323 | Train Acc: 0.9971 | Train Prec: 0.9971
# Epoch 58 | Val Loss: 1.0355 | Val Acc: 0.6933 | Val Prec: 0.7036
# Epoch 59 | Train Loss: 0.0144 | Train Acc: 1.0000 | Train Prec: 1.0000
# Epoch 59 | Val Loss: 1.1027 | Val Acc: 0.6800 | Val Prec: 0.7094
# Epoch 60 | Train Loss: 0.0116 | Train Acc: 1.0000 | Train Prec: 1.0000
# Epoch 60 | Val Loss: 1.0694 | Val Acc: 0.7000 | Val Prec: 0.7156
# Epoch 61 | Train Loss: 0.0123 | Train Acc: 1.0000 | Train Prec: 1.0000
# Epoch 61 | Val Loss: 0.9726 | Val Acc: 0.7333 | Val Prec: 0.7446
# Epoch 62 | Train Loss: 0.0108 | Train Acc: 1.0000 | Train Prec: 1.0000
# Epoch 62 | Val Loss: 0.9699 | Val Acc: 0.7267 | Val Prec: 0.7472
# Epoch 63 | Train Loss: 0.0094 | Train Acc: 1.0000 | Train Prec: 1.0000
# Epoch 63 | Val Loss: 1.0190 | Val Acc: 0.7200 | Val Prec: 0.7453
# Epoch 64 | Train Loss: 0.0116 | Train Acc: 1.0000 | Train Prec: 1.0000
# Epoch 64 | Val Loss: 0.9964 | Val Acc: 0.7267 | Val Prec: 0.7510
# Epoch 65 | Train Loss: 0.0075 | Train Acc: 1.0000 | Train Prec: 1.0000
# Epoch 65 | Val Loss: 0.9749 | Val Acc: 0.7400 | Val Prec: 0.7573
# Epoch 66 | Train Loss: 0.0075 | Train Acc: 1.0000 | Train Prec: 1.0000
# Epoch 66 | Val Loss: 0.9893 | Val Acc: 0.7133 | Val Prec: 0.7330
# Epoch 67 | Train Loss: 0.0093 | Train Acc: 1.0000 | Train Prec: 1.0000
# Epoch 67 | Val Loss: 1.0036 | Val Acc: 0.7200 | Val Prec: 0.7263
# Epoch 68 | Train Loss: 0.0167 | Train Acc: 1.0000 | Train Prec: 1.0000
# Epoch 68 | Val Loss: 1.1427 | Val Acc: 0.6867 | Val Prec: 0.7127
# Epoch 69 | Train Loss: 0.0133 | Train Acc: 1.0000 | Train Prec: 1.0000
# Epoch 69 | Val Loss: 1.0970 | Val Acc: 0.6667 | Val Prec: 0.6781
# Epoch 70 | Train Loss: 0.0112 | Train Acc: 1.0000 | Train Prec: 1.0000
# Epoch 70 | Val Loss: 1.0034 | Val Acc: 0.7000 | Val Prec: 0.6994
# Epoch 71 | Train Loss: 0.0077 | Train Acc: 1.0000 | Train Prec: 1.0000
# Epoch 71 | Val Loss: 0.9839 | Val Acc: 0.7067 | Val Prec: 0.6996
# Epoch 72 | Train Loss: 0.0065 | Train Acc: 1.0000 | Train Prec: 1.0000
# Epoch 72 | Val Loss: 1.0394 | Val Acc: 0.7067 | Val Prec: 0.7212
# Epoch 73 | Train Loss: 0.0047 | Train Acc: 1.0000 | Train Prec: 1.0000
# Epoch 73 | Val Loss: 1.0488 | Val Acc: 0.7000 | Val Prec: 0.7225
# Epoch 74 | Train Loss: 0.0046 | Train Acc: 1.0000 | Train Prec: 1.0000
# Epoch 74 | Val Loss: 1.0532 | Val Acc: 0.7200 | Val Prec: 0.7383
# Epoch 75 | Train Loss: 0.0095 | Train Acc: 0.9986 | Train Prec: 0.9986
# Epoch 75 | Val Loss: 1.0573 | Val Acc: 0.7067 | Val Prec: 0.7121
# Epoch 76 | Train Loss: 0.0155 | Train Acc: 1.0000 | Train Prec: 1.0000
# Epoch 76 | Val Loss: 1.1343 | Val Acc: 0.6867 | Val Prec: 0.7184
# Epoch 77 | Train Loss: 0.0317 | Train Acc: 0.9929 | Train Prec: 0.9929
# Epoch 77 | Val Loss: 1.4371 | Val Acc: 0.7000 | Val Prec: 0.6747
# Epoch 78 | Train Loss: 0.1031 | Train Acc: 0.9686 | Train Prec: 0.9688
# Epoch 78 | Val Loss: 2.4463 | Val Acc: 0.4800 | Val Prec: 0.6421
# Epoch 79 | Train Loss: 0.1238 | Train Acc: 0.9657 | Train Prec: 0.9657
# Epoch 79 | Val Loss: 1.7595 | Val Acc: 0.5667 | Val Prec: 0.7100
# Epoch 80 | Train Loss: 0.0744 | Train Acc: 0.9800 | Train Prec: 0.9801
# Epoch 80 | Val Loss: 1.3878 | Val Acc: 0.6467 | Val Prec: 0.6884
# Epoch 81 | Train Loss: 0.0871 | Train Acc: 0.9700 | Train Prec: 0.9703
# Epoch 81 | Val Loss: 1.2715 | Val Acc: 0.6200 | Val Prec: 0.6512
# Epoch 82 | Train Loss: 0.0487 | Train Acc: 0.9886 | Train Prec: 0.9886
# Epoch 82 | Val Loss: 1.2637 | Val Acc: 0.6467 | Val Prec: 0.6819
# Epoch 83 | Train Loss: 0.0196 | Train Acc: 0.9986 | Train Prec: 0.9986
# Epoch 83 | Val Loss: 1.1093 | Val Acc: 0.7067 | Val Prec: 0.7140
# Epoch 84 | Train Loss: 0.0214 | Train Acc: 0.9943 | Train Prec: 0.9944
# Epoch 84 | Val Loss: 1.1497 | Val Acc: 0.6800 | Val Prec: 0.6939
# Epoch 85 | Train Loss: 0.0291 | Train Acc: 0.9914 | Train Prec: 0.9914
# Epoch 85 | Val Loss: 1.2447 | Val Acc: 0.6333 | Val Prec: 0.6688
# Epoch 86 | Train Loss: 0.0356 | Train Acc: 0.9929 | Train Prec: 0.9930
# Epoch 86 | Val Loss: 1.1600 | Val Acc: 0.6667 | Val Prec: 0.6777
# Epoch 87 | Train Loss: 0.0151 | Train Acc: 1.0000 | Train Prec: 1.0000
# Epoch 87 | Val Loss: 1.0463 | Val Acc: 0.7000 | Val Prec: 0.7200
# Epoch 88 | Train Loss: 0.0081 | Train Acc: 0.9986 | Train Prec: 0.9986
# Epoch 88 | Val Loss: 1.0108 | Val Acc: 0.6867 | Val Prec: 0.7089
# Epoch 89 | Train Loss: 0.0149 | Train Acc: 0.9986 | Train Prec: 0.9986
# Epoch 89 | Val Loss: 1.2095 | Val Acc: 0.7000 | Val Prec: 0.7452
# Epoch 90 | Train Loss: 0.0128 | Train Acc: 0.9986 | Train Prec: 0.9986
# Epoch 90 | Val Loss: 0.9171 | Val Acc: 0.7000 | Val Prec: 0.6977
# Epoch 91 | Train Loss: 0.0080 | Train Acc: 1.0000 | Train Prec: 1.0000
# Epoch 91 | Val Loss: 1.0332 | Val Acc: 0.7000 | Val Prec: 0.7329
# Epoch 92 | Train Loss: 0.0102 | Train Acc: 0.9986 | Train Prec: 0.9986
# Epoch 92 | Val Loss: 1.1220 | Val Acc: 0.7133 | Val Prec: 0.7344
# Epoch 93 | Train Loss: 0.0084 | Train Acc: 1.0000 | Train Prec: 1.0000
# Epoch 93 | Val Loss: 1.0440 | Val Acc: 0.7333 | Val Prec: 0.7496
# Epoch 94 | Train Loss: 0.0061 | Train Acc: 1.0000 | Train Prec: 1.0000
# Epoch 94 | Val Loss: 0.9722 | Val Acc: 0.7400 | Val Prec: 0.7546
# Epoch 95 | Train Loss: 0.0056 | Train Acc: 1.0000 | Train Prec: 1.0000
# Epoch 95 | Val Loss: 0.9427 | Val Acc: 0.7133 | Val Prec: 0.7242
# Epoch 96 | Train Loss: 0.0050 | Train Acc: 1.0000 | Train Prec: 1.0000
# Epoch 96 | Val Loss: 0.9173 | Val Acc: 0.7400 | Val Prec: 0.7425
# Epoch 97 | Train Loss: 0.0042 | Train Acc: 1.0000 | Train Prec: 1.0000
# Epoch 97 | Val Loss: 0.9550 | Val Acc: 0.7200 | Val Prec: 0.7472
# Epoch 98 | Train Loss: 0.0028 | Train Acc: 1.0000 | Train Prec: 1.0000
# Epoch 98 | Val Loss: 0.9690 | Val Acc: 0.7200 | Val Prec: 0.7347
# Epoch 99 | Train Loss: 0.0034 | Train Acc: 1.0000 | Train Prec: 1.0000
# Epoch 99 | Val Loss: 0.9201 | Val Acc: 0.7400 | Val Prec: 0.7396
# Epoch 100 | Train Loss: 0.0063 | Train Acc: 1.0000 | Train Prec: 1.0000
# Epoch 100 | Val Loss: 0.9738 | Val Acc: 0.7200 | Val Prec: 0.7318

# %%
y_true = []
y_pred = []

with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device, non_blocking=True)
        labels = labels.to(device, non_blocking=True)

        outputs = model(images)
        _, preds = torch.max(outputs, 1)

        y_true.extend(labels.cpu().numpy())
        y_pred.extend(preds.cpu().numpy())

# %%
import matplotlib.pyplot as plt
test_accuracy = accuracy_score(y_true, y_pred)
test_precision = precision_score(y_true, y_pred, average='macro')
test_f1 = f1_score(y_true, y_pred, average='macro')
conf_matrix = confusion_matrix(y_true, y_pred)

print(f"Accuracy: {test_accuracy:.4f}")
print(f"Precision (macro): {test_precision:.4f}")
print(f"F1 Score (macro): {test_f1:.4f}")
print("Confusion Matrix:")

class_names = test_dataset.label_map.keys()

fig, ax = plt.subplots(figsize=(8, 6))
cax = ax.matshow(conf_matrix, cmap='Blues')
fig.colorbar(cax)
# Dodaj etykiety osi
ax.set_xticks(np.arange(len(class_names)))
ax.set_yticks(np.arange(len(class_names)))
ax.set_xticklabels(class_names)
ax.set_yticklabels(class_names)

# Dodaj liczby do komórek
for i in range(len(conf_matrix)):
    for j in range(len(conf_matrix[i])):
        ax.text(j, i, str(conf_matrix[i][j]),
                va='center', ha='center', color='black', fontsize=12)

# Oznaczenia osi
plt.xlabel('Prediction')
plt.ylabel('True genre')
plt.title('Confusion matrix')
plt.tight_layout()
plt.show()
# Out:
# Accuracy: 0.8000
# Precision (macro): 0.7984
# F1 Score (macro): 0.7972
# Confusion Matrix:

# %%
# Plotting the Loss and Accuracy curves
plt.figure(figsize=(12, 6))

# Losses
plt.subplot(1, 3, 1)
plt.plot(range(num_epochs), train_losses, label='Train Loss')
plt.plot(range(num_epochs), val_losses, label='Val Loss')
plt.title("Loss Curve")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()

# Accuracy
plt.subplot(1, 3, 2)
plt.plot(range(num_epochs), train_accuracies, label='Train Accuracy')
plt.plot(range(num_epochs), val_accuracies, label='Val Accuracy')
plt.title("Accuracy Curve")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()

# Precision
plt.subplot(1, 3, 3)
plt.plot(range(num_epochs), train_precisions, label='Train Precision')
plt.plot(range(num_epochs), val_precisions, label='Val Precision')
plt.title("Precision Curve")
plt.xlabel("Epochs")
plt.ylabel("Precision")
plt.legend()

plt.show()

# %%
torch.save({
    'epoch': num_epochs,
    'model_state_dict': model.state_dict(),
    'optimizer_state_dict': optimizer.state_dict(),
    'loss': loss,
    'train_accuracies': train_accuracies,
    'val_accuracies': val_accuracies,
    'train_losses': train_losses,
    'val_losses': val_losses,
    'train_precisions: ': train_precisions,
    'val_precisions': val_precisions,
    'test_accuracy' : test_accuracy,
    'test_precision' : test_precision,
    'test_f1': test_f1,
    'conf_matrix': conf_matrix
}, get_filename_with_date())

# %%
'''
torch.save(model.state_dict(), 'model.pth')
'''
# Out:
# "\ntorch.save(model.state_dict(), 'model.pth')\n"

# %%
'''

num_classes = 10
model = densenet121()
model.classifier = nn.Linear(model.classifier.in_features, num_classes)
model.load_state_dict(torch.load('model.pth'))
model.eval()
success = 0
val_size = 1
for elem in val_dataset:
    image, label = elem
    with torch.no_grad():
        output = model(image.unsqueeze(0))
    _, predicted = torch.max(output, 1)

    if predicted == label:
        success += 1
    val_size += 1
print(success/val_size)

'''
# Out:
# "\n\nnum_classes = 10\nmodel = densenet121()\nmodel.classifier = nn.Linear(model.classifier.in_features, num_classes)\nmodel.load_state_dict(torch.load('model.pth'))\nmodel.eval()\nsuccess = 0\nval_size = 1\nfor elem in val_dataset:\n    image, label = elem\n    with torch.no_grad():\n        output = model(image.unsqueeze(0))\n    _, predicted = torch.max(output, 1)\n\n    if predicted == label:\n        success += 1\n    val_size += 1\nprint(success/val_size)\n\n"
