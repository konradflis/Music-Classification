# %% [markdown]
# # Music Genre Classification using Neural Network

# %%
import pandas as pd
import numpy as np
import platform
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, LeakyReLU, ReLU, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import LearningRateScheduler, EarlyStopping, ModelCheckpoint
from tensorflow.keras.metrics import Precision, Accuracy, AUC, F1Score
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import accuracy_score, precision_score, f1_score, confusion_matrix, roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    try:
        for device in physical_devices:
            tf.config.experimental.set_memory_growth(device, True)
        if tf.test.is_built_with_cuda():
            print(
                f"CUDA is enabled. Using GPU(s) with CUDA: {physical_devices}")
        elif platform.system() == 'Darwin':
            print(
                f"Metal is enabled. Using Metal-enabled GPU on macOS: {physical_devices}")
        else:
            print(
                f"GPU detected but neither CUDA nor Metal is enabled: {physical_devices}")
    except RuntimeError as e:
        print(f"Error enabling GPU acceleration: {e}")
else:
    print("No GPU found. Running on CPU.")
# Out:
# Metal is enabled. Using Metal-enabled GPU on macOS: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Load MFCC data
mfcc_df = pd.read_csv('mfcc_data_gtzan_v1.csv', header=[0, 1], index_col=0)
labels = pd.read_csv('../project_data/tracks.csv')['genre']

# Encode labels
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(labels)

# Drop non-numeric columns
mfcc_df = mfcc_df.drop(columns=['file_name'])

# Flatten multi-index columns and scale features
mfcc_df.columns = ['_'.join(map(str, col)) for col in mfcc_df.columns]
scaler = StandardScaler()
X = scaler.fit_transform(mfcc_df)
# Out:
# /var/folders/42/12p7rrgx3zj15zz7yc0tm30w0000gn/T/ipykernel_44269/2681949578.py:10: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   mfcc_df = mfcc_df.drop(columns=['file_name'])

# %%
mfcc_df.hist(bins=30, figsize=(12, 14), edgecolor='black')
plt.tight_layout()
plt.show()

# %%
y = to_categorical(y, num_classes=10)

# %%
X_train_full, X_test, y_train_full, y_test = train_test_split(
    X, y,
    test_size=0.2,
    stratify=y.argmax(axis=1),
    random_state=42
)

X_train, X_val, y_train, y_val = train_test_split(
    X_train_full, y_train_full,
    test_size=0.2,
    stratify=y_train_full.argmax(axis=1),
    random_state=42
)

# %%
x_train_nan = np.isnan(X_train).sum()  # Liczba NaN w X_train
y_train_nan = np.isnan(y_train).sum()  # Liczba NaN w y_train

print(f"NaN values in X_train: {x_train_nan}")
print(f"NaN values in y_train: {y_train_nan}")
# Out:
# NaN values in X_train: 0
# NaN values in y_train: 0

# %%
def build_and_train_model(X_train, y_train, X_val, y_val,
                          hidden_layers=[64, 32],
                          output_activation='softmax',
                          loss='categorical_crossentropy',
                          optimizer='adam',
                          metrics=['accuracy', Precision(name='precision')],
                          monitor_metric='val_precision',
                          model_path='best_model.h5',
                          epochs=20,
                          batch_size=32,
                          patience=5,
                          dropout=0.2):

    model = Sequential()
    model.add(Input(shape=(X_train.shape[1],)))
    model.add(Dense(hidden_layers[0]))
    model.add(LeakyReLU(negative_slope=0.1))
    for units in hidden_layers[1:]:
        model.add(Dense(units))
        model.add(LeakyReLU(negative_slope=0.1))
        model.add(BatchNormalization())
        model.add(Dropout(dropout)),
    model.add(Dense(10, activation=output_activation))

    model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

    checkpoint = ModelCheckpoint(
        model_path,
        monitor=monitor_metric,
        mode='min',
        save_best_only=True,
        verbose=1
    )

    early_stopping = EarlyStopping(
        monitor=monitor_metric,
        patience=patience,
        mode='min',
        verbose=1,
        restore_best_weights=True
    )

    history = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=epochs,
        batch_size=batch_size,
        callbacks=[checkpoint, early_stopping]
    )

    return model, history
# Out:
# 2025-05-13 11:58:32.976621: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2
# 2025-05-13 11:58:32.976663: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2025-05-13 11:58:32.976667: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1747130312.976968 11918782 pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# I0000 00:00:1747130312.977119 11918782 pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
model, history = build_and_train_model(
    X_train, y_train,
    X_val, y_val,
    hidden_layers=[256, 128, 64],
    optimizer=Adam(learning_rate=0.0001),
    metrics=[AUC(), F1Score(), 'accuracy', Precision(name='precision')],
    monitor_metric='val_loss',
    model_path='best_model_gtzan.keras',
    epochs=500,
    batch_size=64,
    patience=50,
    dropout=0.45
)
# Out:
# Epoch 1/500
# 2025-05-13 11:58:33.675041: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.1118 - auc: 0.4996 - f1_score: 0.1117 - loss: 3.4691 - precision: 0.1013
# Epoch 1: val_loss improved from inf to 2.37992, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - accuracy: 0.1116 - auc: 0.5001 - f1_score: 0.1114 - loss: 3.4634 - precision: 0.1020 - val_accuracy: 0.0625 - val_auc: 0.4659 - val_f1_score: 0.0448 - val_loss: 2.3799 - val_precision: 0.0000e+00
# Epoch 2/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1269 - auc: 0.5112 - f1_score: 0.1244 - loss: 3.2844 - precision: 0.0879
# Epoch 2: val_loss improved from 2.37992 to 2.32575, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.1254 - auc: 0.5118 - f1_score: 0.1234 - loss: 3.2890 - precision: 0.0904 - val_accuracy: 0.0875 - val_auc: 0.5140 - val_f1_score: 0.0727 - val_loss: 2.3258 - val_precision: 0.0000e+00
# Epoch 3/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1395 - auc: 0.5344 - f1_score: 0.1368 - loss: 3.2301 - precision: 0.1466
# Epoch 3: val_loss improved from 2.32575 to 2.27550, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.1397 - auc: 0.5344 - f1_score: 0.1373 - loss: 3.2254 - precision: 0.1485 - val_accuracy: 0.1625 - val_auc: 0.5636 - val_f1_score: 0.1512 - val_loss: 2.2755 - val_precision: 0.0000e+00
# Epoch 4/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.1807 - auc: 0.5926 - f1_score: 0.1759 - loss: 2.8557 - precision: 0.2211
# Epoch 4: val_loss improved from 2.27550 to 2.22867, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.1785 - auc: 0.5920 - f1_score: 0.1744 - loss: 2.8588 - precision: 0.2171 - val_accuracy: 0.2125 - val_auc: 0.6133 - val_f1_score: 0.1975 - val_loss: 2.2287 - val_precision: 0.0000e+00
# Epoch 5/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1567 - auc: 0.5997 - f1_score: 0.1496 - loss: 2.8195 - precision: 0.2621
# Epoch 5: val_loss improved from 2.22867 to 2.18516, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.1634 - auc: 0.6033 - f1_score: 0.1573 - loss: 2.8085 - precision: 0.2597 - val_accuracy: 0.2625 - val_auc: 0.6497 - val_f1_score: 0.2345 - val_loss: 2.1852 - val_precision: 0.0000e+00
# Epoch 6/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.1620 - auc: 0.6114 - f1_score: 0.1614 - loss: 2.8067 - precision: 0.2161
# Epoch 6: val_loss improved from 2.18516 to 2.14420, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.1656 - auc: 0.6139 - f1_score: 0.1641 - loss: 2.7898 - precision: 0.2194 - val_accuracy: 0.3313 - val_auc: 0.6769 - val_f1_score: 0.3011 - val_loss: 2.1442 - val_precision: 0.0000e+00
# Epoch 7/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.2216 - auc: 0.6803 - f1_score: 0.2107 - loss: 2.4865 - precision: 0.3303
# Epoch 7: val_loss improved from 2.14420 to 2.10389, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.2243 - auc: 0.6788 - f1_score: 0.2140 - loss: 2.4900 - precision: 0.3374 - val_accuracy: 0.3313 - val_auc: 0.7015 - val_f1_score: 0.3022 - val_loss: 2.1039 - val_precision: 0.0000e+00
# Epoch 8/500
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.2157 - auc: 0.6733 - f1_score: 0.2051 - loss: 2.4807 - precision: 0.3098
# Epoch 8: val_loss improved from 2.10389 to 2.06441, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.2242 - auc: 0.6704 - f1_score: 0.2140 - loss: 2.4877 - precision: 0.3213 - val_accuracy: 0.3625 - val_auc: 0.7186 - val_f1_score: 0.3260 - val_loss: 2.0644 - val_precision: 0.0000e+00
# Epoch 9/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3107 - auc: 0.7267 - f1_score: 0.2924 - loss: 2.2006 - precision: 0.4149
# Epoch 9: val_loss improved from 2.06441 to 2.02861, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.3094 - auc: 0.7236 - f1_score: 0.2918 - loss: 2.2168 - precision: 0.4119 - val_accuracy: 0.3688 - val_auc: 0.7332 - val_f1_score: 0.3342 - val_loss: 2.0286 - val_precision: 0.0000e+00
# Epoch 10/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.2717 - auc: 0.7218 - f1_score: 0.2458 - loss: 2.2530 - precision: 0.3741
# Epoch 10: val_loss improved from 2.02861 to 1.99409, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.2710 - auc: 0.7192 - f1_score: 0.2476 - loss: 2.2673 - precision: 0.3741 - val_accuracy: 0.3750 - val_auc: 0.7476 - val_f1_score: 0.3450 - val_loss: 1.9941 - val_precision: 0.0000e+00
# Epoch 11/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.2500 - auc: 0.6947 - f1_score: 0.2397 - loss: 2.3769 - precision: 0.3619
# Epoch 11: val_loss improved from 1.99409 to 1.95821, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.2558 - auc: 0.6982 - f1_score: 0.2456 - loss: 2.3599 - precision: 0.3666 - val_accuracy: 0.3812 - val_auc: 0.7637 - val_f1_score: 0.3554 - val_loss: 1.9582 - val_precision: 1.0000
# Epoch 12/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.2524 - auc: 0.7379 - f1_score: 0.2420 - loss: 2.2081 - precision: 0.3564
# Epoch 12: val_loss improved from 1.95821 to 1.92134, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.2555 - auc: 0.7384 - f1_score: 0.2450 - loss: 2.2036 - precision: 0.3651 - val_accuracy: 0.4000 - val_auc: 0.7759 - val_f1_score: 0.3727 - val_loss: 1.9213 - val_precision: 1.0000
# Epoch 13/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3083 - auc: 0.7447 - f1_score: 0.3008 - loss: 2.1469 - precision: 0.3837
# Epoch 13: val_loss improved from 1.92134 to 1.88625, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.3080 - auc: 0.7450 - f1_score: 0.3006 - loss: 2.1442 - precision: 0.3854 - val_accuracy: 0.4000 - val_auc: 0.7879 - val_f1_score: 0.3746 - val_loss: 1.8863 - val_precision: 1.0000
# Epoch 14/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3313 - auc: 0.7473 - f1_score: 0.3139 - loss: 2.1220 - precision: 0.4641
# Epoch 14: val_loss improved from 1.88625 to 1.85094, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.3277 - auc: 0.7472 - f1_score: 0.3108 - loss: 2.1265 - precision: 0.4606 - val_accuracy: 0.4000 - val_auc: 0.7987 - val_f1_score: 0.3656 - val_loss: 1.8509 - val_precision: 1.0000
# Epoch 15/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3027 - auc: 0.7539 - f1_score: 0.2788 - loss: 2.1370 - precision: 0.4577
# Epoch 15: val_loss improved from 1.85094 to 1.81772, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.3040 - auc: 0.7541 - f1_score: 0.2811 - loss: 2.1344 - precision: 0.4555 - val_accuracy: 0.4187 - val_auc: 0.8103 - val_f1_score: 0.3837 - val_loss: 1.8177 - val_precision: 1.0000
# Epoch 16/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3209 - auc: 0.7702 - f1_score: 0.3018 - loss: 2.0429 - precision: 0.4473
# Epoch 16: val_loss improved from 1.81772 to 1.78448, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.3206 - auc: 0.7685 - f1_score: 0.3022 - loss: 2.0496 - precision: 0.4478 - val_accuracy: 0.4125 - val_auc: 0.8198 - val_f1_score: 0.3729 - val_loss: 1.7845 - val_precision: 1.0000
# Epoch 17/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3635 - auc: 0.7938 - f1_score: 0.3438 - loss: 1.9015 - precision: 0.5118
# Epoch 17: val_loss improved from 1.78448 to 1.75338, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.3631 - auc: 0.7925 - f1_score: 0.3447 - loss: 1.9113 - precision: 0.5036 - val_accuracy: 0.4062 - val_auc: 0.8283 - val_f1_score: 0.3657 - val_loss: 1.7534 - val_precision: 1.0000
# Epoch 18/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3354 - auc: 0.7761 - f1_score: 0.3213 - loss: 2.0036 - precision: 0.5032
# Epoch 18: val_loss improved from 1.75338 to 1.72122, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.3370 - auc: 0.7777 - f1_score: 0.3223 - loss: 1.9988 - precision: 0.5043 - val_accuracy: 0.4313 - val_auc: 0.8364 - val_f1_score: 0.3850 - val_loss: 1.7212 - val_precision: 1.0000
# Epoch 19/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3505 - auc: 0.7851 - f1_score: 0.3340 - loss: 1.9375 - precision: 0.4817
# Epoch 19: val_loss improved from 1.72122 to 1.69031, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.3488 - auc: 0.7848 - f1_score: 0.3324 - loss: 1.9383 - precision: 0.4823 - val_accuracy: 0.4313 - val_auc: 0.8445 - val_f1_score: 0.3877 - val_loss: 1.6903 - val_precision: 1.0000
# Epoch 20/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3563 - auc: 0.7955 - f1_score: 0.3301 - loss: 1.8957 - precision: 0.5087
# Epoch 20: val_loss improved from 1.69031 to 1.65911, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.3567 - auc: 0.7943 - f1_score: 0.3333 - loss: 1.9029 - precision: 0.5071 - val_accuracy: 0.4250 - val_auc: 0.8522 - val_f1_score: 0.3805 - val_loss: 1.6591 - val_precision: 1.0000
# Epoch 21/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3675 - auc: 0.7969 - f1_score: 0.3472 - loss: 1.8975 - precision: 0.5475
# Epoch 21: val_loss improved from 1.65911 to 1.62773, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.3721 - auc: 0.7974 - f1_score: 0.3529 - loss: 1.8940 - precision: 0.5421 - val_accuracy: 0.4187 - val_auc: 0.8608 - val_f1_score: 0.3750 - val_loss: 1.6277 - val_precision: 1.0000
# Epoch 22/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3823 - auc: 0.8054 - f1_score: 0.3644 - loss: 1.8592 - precision: 0.5030
# Epoch 22: val_loss improved from 1.62773 to 1.59712, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.3842 - auc: 0.8075 - f1_score: 0.3673 - loss: 1.8473 - precision: 0.5142 - val_accuracy: 0.4187 - val_auc: 0.8672 - val_f1_score: 0.3746 - val_loss: 1.5971 - val_precision: 1.0000
# Epoch 23/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4115 - auc: 0.8284 - f1_score: 0.3930 - loss: 1.7259 - precision: 0.5487
# Epoch 23: val_loss improved from 1.59712 to 1.56933, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.4127 - auc: 0.8293 - f1_score: 0.3952 - loss: 1.7214 - precision: 0.5570 - val_accuracy: 0.4313 - val_auc: 0.8728 - val_f1_score: 0.3883 - val_loss: 1.5693 - val_precision: 1.0000
# Epoch 24/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3619 - auc: 0.8062 - f1_score: 0.3444 - loss: 1.8514 - precision: 0.5173
# Epoch 24: val_loss improved from 1.56933 to 1.54298, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.3678 - auc: 0.8090 - f1_score: 0.3505 - loss: 1.8361 - precision: 0.5225 - val_accuracy: 0.4375 - val_auc: 0.8787 - val_f1_score: 0.3931 - val_loss: 1.5430 - val_precision: 0.9167
# Epoch 25/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4164 - auc: 0.8440 - f1_score: 0.4077 - loss: 1.6388 - precision: 0.5937
# Epoch 25: val_loss improved from 1.54298 to 1.51767, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4141 - auc: 0.8402 - f1_score: 0.4043 - loss: 1.6597 - precision: 0.5872 - val_accuracy: 0.4625 - val_auc: 0.8833 - val_f1_score: 0.4262 - val_loss: 1.5177 - val_precision: 0.9200
# Epoch 26/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4538 - auc: 0.8374 - f1_score: 0.4247 - loss: 1.6766 - precision: 0.5439
# Epoch 26: val_loss improved from 1.51767 to 1.49306, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4538 - auc: 0.8362 - f1_score: 0.4280 - loss: 1.6818 - precision: 0.5506 - val_accuracy: 0.4688 - val_auc: 0.8875 - val_f1_score: 0.4311 - val_loss: 1.4931 - val_precision: 0.8929
# Epoch 27/500
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.4457 - auc: 0.8418 - f1_score: 0.4197 - loss: 1.6736 - precision: 0.6082
# Epoch 27: val_loss improved from 1.49306 to 1.46971, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.4403 - auc: 0.8387 - f1_score: 0.4195 - loss: 1.6900 - precision: 0.5969 - val_accuracy: 0.4563 - val_auc: 0.8915 - val_f1_score: 0.4161 - val_loss: 1.4697 - val_precision: 0.8485
# Epoch 28/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4382 - auc: 0.8317 - f1_score: 0.4203 - loss: 1.7160 - precision: 0.6028
# Epoch 28: val_loss improved from 1.46971 to 1.44731, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4353 - auc: 0.8308 - f1_score: 0.4182 - loss: 1.7203 - precision: 0.5974 - val_accuracy: 0.4625 - val_auc: 0.8953 - val_f1_score: 0.4249 - val_loss: 1.4473 - val_precision: 0.8571
# Epoch 29/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4688 - auc: 0.8480 - f1_score: 0.4533 - loss: 1.6175 - precision: 0.6398
# Epoch 29: val_loss improved from 1.44731 to 1.42705, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4652 - auc: 0.8479 - f1_score: 0.4502 - loss: 1.6199 - precision: 0.6309 - val_accuracy: 0.4812 - val_auc: 0.8986 - val_f1_score: 0.4482 - val_loss: 1.4270 - val_precision: 0.8649
# Epoch 30/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4840 - auc: 0.8506 - f1_score: 0.4641 - loss: 1.6185 - precision: 0.6204
# Epoch 30: val_loss improved from 1.42705 to 1.40651, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4793 - auc: 0.8495 - f1_score: 0.4609 - loss: 1.6240 - precision: 0.6186 - val_accuracy: 0.4875 - val_auc: 0.9016 - val_f1_score: 0.4558 - val_loss: 1.4065 - val_precision: 0.8462
# Epoch 31/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4848 - auc: 0.8556 - f1_score: 0.4670 - loss: 1.5963 - precision: 0.5943
# Epoch 31: val_loss improved from 1.40651 to 1.38680, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.4729 - auc: 0.8513 - f1_score: 0.4564 - loss: 1.6183 - precision: 0.5919 - val_accuracy: 0.4938 - val_auc: 0.9041 - val_f1_score: 0.4729 - val_loss: 1.3868 - val_precision: 0.8462
# Epoch 32/500
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.3899 - auc: 0.8386 - f1_score: 0.3791 - loss: 1.7034 - precision: 0.5466
# Epoch 32: val_loss improved from 1.38680 to 1.36903, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.3992 - auc: 0.8427 - f1_score: 0.3876 - loss: 1.6787 - precision: 0.5566 - val_accuracy: 0.5188 - val_auc: 0.9064 - val_f1_score: 0.5029 - val_loss: 1.3690 - val_precision: 0.8293
# Epoch 33/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4351 - auc: 0.8562 - f1_score: 0.4141 - loss: 1.5828 - precision: 0.6099
# Epoch 33: val_loss improved from 1.36903 to 1.35203, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.4362 - auc: 0.8574 - f1_score: 0.4160 - loss: 1.5762 - precision: 0.6135 - val_accuracy: 0.5250 - val_auc: 0.9086 - val_f1_score: 0.5114 - val_loss: 1.3520 - val_precision: 0.8140
# Epoch 34/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4314 - auc: 0.8499 - f1_score: 0.4178 - loss: 1.6177 - precision: 0.6129
# Epoch 34: val_loss improved from 1.35203 to 1.33810, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.4318 - auc: 0.8495 - f1_score: 0.4184 - loss: 1.6187 - precision: 0.6143 - val_accuracy: 0.5250 - val_auc: 0.9103 - val_f1_score: 0.5098 - val_loss: 1.3381 - val_precision: 0.8298
# Epoch 35/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4333 - auc: 0.8557 - f1_score: 0.4211 - loss: 1.5776 - precision: 0.6147
# Epoch 35: val_loss improved from 1.33810 to 1.32437, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.4348 - auc: 0.8556 - f1_score: 0.4225 - loss: 1.5784 - precision: 0.6140 - val_accuracy: 0.5188 - val_auc: 0.9123 - val_f1_score: 0.5025 - val_loss: 1.3244 - val_precision: 0.8333
# Epoch 36/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5025 - auc: 0.8674 - f1_score: 0.4905 - loss: 1.5093 - precision: 0.6560
# Epoch 36: val_loss improved from 1.32437 to 1.31021, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.4993 - auc: 0.8660 - f1_score: 0.4870 - loss: 1.5184 - precision: 0.6482 - val_accuracy: 0.5250 - val_auc: 0.9131 - val_f1_score: 0.5102 - val_loss: 1.3102 - val_precision: 0.8200
# Epoch 37/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4388 - auc: 0.8633 - f1_score: 0.4378 - loss: 1.5548 - precision: 0.5894
# Epoch 37: val_loss improved from 1.31021 to 1.29845, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.4447 - auc: 0.8642 - f1_score: 0.4427 - loss: 1.5476 - precision: 0.5927 - val_accuracy: 0.5312 - val_auc: 0.9146 - val_f1_score: 0.5179 - val_loss: 1.2984 - val_precision: 0.8200
# Epoch 38/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4556 - auc: 0.8637 - f1_score: 0.4408 - loss: 1.5371 - precision: 0.6281
# Epoch 38: val_loss improved from 1.29845 to 1.28423, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.4576 - auc: 0.8639 - f1_score: 0.4436 - loss: 1.5352 - precision: 0.6327 - val_accuracy: 0.5437 - val_auc: 0.9157 - val_f1_score: 0.5307 - val_loss: 1.2842 - val_precision: 0.8200
# Epoch 39/500
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.4589 - auc: 0.8546 - f1_score: 0.4577 - loss: 1.5737 - precision: 0.6156
# Epoch 39: val_loss improved from 1.28423 to 1.27043, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.4645 - auc: 0.8592 - f1_score: 0.4602 - loss: 1.5477 - precision: 0.6227 - val_accuracy: 0.5500 - val_auc: 0.9170 - val_f1_score: 0.5374 - val_loss: 1.2704 - val_precision: 0.8269
# Epoch 40/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.4188 - auc: 0.8587 - f1_score: 0.4143 - loss: 1.5707 - precision: 0.6421
# Epoch 40: val_loss improved from 1.27043 to 1.25957, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.4271 - auc: 0.8607 - f1_score: 0.4217 - loss: 1.5584 - precision: 0.6433 - val_accuracy: 0.5500 - val_auc: 0.9181 - val_f1_score: 0.5366 - val_loss: 1.2596 - val_precision: 0.8462
# Epoch 41/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5270 - auc: 0.8898 - f1_score: 0.5122 - loss: 1.3878 - precision: 0.6666
# Epoch 41: val_loss improved from 1.25957 to 1.24962, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5227 - auc: 0.8895 - f1_score: 0.5085 - loss: 1.3894 - precision: 0.6664 - val_accuracy: 0.5688 - val_auc: 0.9195 - val_f1_score: 0.5587 - val_loss: 1.2496 - val_precision: 0.8214
# Epoch 42/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5156 - auc: 0.8834 - f1_score: 0.5116 - loss: 1.4218 - precision: 0.6477
# Epoch 42: val_loss improved from 1.24962 to 1.23845, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5161 - auc: 0.8843 - f1_score: 0.5112 - loss: 1.4172 - precision: 0.6485 - val_accuracy: 0.5625 - val_auc: 0.9207 - val_f1_score: 0.5509 - val_loss: 1.2385 - val_precision: 0.8393
# Epoch 43/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4757 - auc: 0.8748 - f1_score: 0.4646 - loss: 1.4719 - precision: 0.6439
# Epoch 43: val_loss improved from 1.23845 to 1.22748, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.4839 - auc: 0.8765 - f1_score: 0.4730 - loss: 1.4611 - precision: 0.6491 - val_accuracy: 0.5562 - val_auc: 0.9218 - val_f1_score: 0.5445 - val_loss: 1.2275 - val_precision: 0.8421
# Epoch 44/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4955 - auc: 0.8823 - f1_score: 0.4756 - loss: 1.4298 - precision: 0.6256
# Epoch 44: val_loss improved from 1.22748 to 1.21712, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.4959 - auc: 0.8837 - f1_score: 0.4782 - loss: 1.4223 - precision: 0.6324 - val_accuracy: 0.5625 - val_auc: 0.9234 - val_f1_score: 0.5513 - val_loss: 1.2171 - val_precision: 0.8276
# Epoch 45/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5103 - auc: 0.8839 - f1_score: 0.5008 - loss: 1.4083 - precision: 0.6847
# Epoch 45: val_loss improved from 1.21712 to 1.20878, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5083 - auc: 0.8838 - f1_score: 0.4986 - loss: 1.4100 - precision: 0.6831 - val_accuracy: 0.5813 - val_auc: 0.9242 - val_f1_score: 0.5726 - val_loss: 1.2088 - val_precision: 0.8571
# Epoch 46/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5040 - auc: 0.8805 - f1_score: 0.4924 - loss: 1.4515 - precision: 0.6614
# Epoch 46: val_loss improved from 1.20878 to 1.19924, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5048 - auc: 0.8801 - f1_score: 0.4940 - loss: 1.4515 - precision: 0.6668 - val_accuracy: 0.5875 - val_auc: 0.9250 - val_f1_score: 0.5804 - val_loss: 1.1992 - val_precision: 0.8448
# Epoch 47/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4924 - auc: 0.8903 - f1_score: 0.4803 - loss: 1.4002 - precision: 0.5969
# Epoch 47: val_loss improved from 1.19924 to 1.19010, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.4948 - auc: 0.8908 - f1_score: 0.4839 - loss: 1.3946 - precision: 0.6072 - val_accuracy: 0.5813 - val_auc: 0.9256 - val_f1_score: 0.5720 - val_loss: 1.1901 - val_precision: 0.8333
# Epoch 48/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4859 - auc: 0.8735 - f1_score: 0.4688 - loss: 1.4867 - precision: 0.6433
# Epoch 48: val_loss improved from 1.19010 to 1.18283, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.4879 - auc: 0.8762 - f1_score: 0.4730 - loss: 1.4709 - precision: 0.6412 - val_accuracy: 0.5938 - val_auc: 0.9261 - val_f1_score: 0.5852 - val_loss: 1.1828 - val_precision: 0.8361
# Epoch 49/500
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5389 - auc: 0.8982 - f1_score: 0.5252 - loss: 1.3323 - precision: 0.7409
# Epoch 49: val_loss improved from 1.18283 to 1.17713, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.5313 - auc: 0.8962 - f1_score: 0.5194 - loss: 1.3481 - precision: 0.7207 - val_accuracy: 0.5875 - val_auc: 0.9272 - val_f1_score: 0.5797 - val_loss: 1.1771 - val_precision: 0.8226
# Epoch 50/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5115 - auc: 0.8888 - f1_score: 0.4972 - loss: 1.3982 - precision: 0.6495
# Epoch 50: val_loss improved from 1.17713 to 1.17321, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5098 - auc: 0.8880 - f1_score: 0.4958 - loss: 1.4032 - precision: 0.6476 - val_accuracy: 0.6000 - val_auc: 0.9270 - val_f1_score: 0.5940 - val_loss: 1.1732 - val_precision: 0.8382
# Epoch 51/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5666 - auc: 0.9077 - f1_score: 0.5443 - loss: 1.2660 - precision: 0.7161
# Epoch 51: val_loss improved from 1.17321 to 1.16818, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5629 - auc: 0.9064 - f1_score: 0.5430 - loss: 1.2745 - precision: 0.7122 - val_accuracy: 0.6062 - val_auc: 0.9277 - val_f1_score: 0.5997 - val_loss: 1.1682 - val_precision: 0.8286
# Epoch 52/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5527 - auc: 0.9064 - f1_score: 0.5384 - loss: 1.2776 - precision: 0.7049
# Epoch 52: val_loss improved from 1.16818 to 1.16366, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5529 - auc: 0.9049 - f1_score: 0.5401 - loss: 1.2859 - precision: 0.7046 - val_accuracy: 0.6250 - val_auc: 0.9282 - val_f1_score: 0.6178 - val_loss: 1.1637 - val_precision: 0.8310
# Epoch 53/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5470 - auc: 0.9031 - f1_score: 0.5303 - loss: 1.2906 - precision: 0.7021
# Epoch 53: val_loss improved from 1.16366 to 1.15859, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5486 - auc: 0.9029 - f1_score: 0.5333 - loss: 1.2917 - precision: 0.7075 - val_accuracy: 0.6250 - val_auc: 0.9290 - val_f1_score: 0.6173 - val_loss: 1.1586 - val_precision: 0.8451
# Epoch 54/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5855 - auc: 0.8998 - f1_score: 0.5724 - loss: 1.2912 - precision: 0.7369
# Epoch 54: val_loss improved from 1.15859 to 1.15236, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5838 - auc: 0.8995 - f1_score: 0.5718 - loss: 1.2955 - precision: 0.7349 - val_accuracy: 0.6250 - val_auc: 0.9294 - val_f1_score: 0.6178 - val_loss: 1.1524 - val_precision: 0.8472
# Epoch 55/500
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5719 - auc: 0.9073 - f1_score: 0.5449 - loss: 1.2668 - precision: 0.6873
# Epoch 55: val_loss improved from 1.15236 to 1.14559, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.5650 - auc: 0.9047 - f1_score: 0.5453 - loss: 1.2832 - precision: 0.6849 - val_accuracy: 0.6187 - val_auc: 0.9303 - val_f1_score: 0.6125 - val_loss: 1.1456 - val_precision: 0.8493
# Epoch 56/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5416 - auc: 0.8992 - f1_score: 0.5297 - loss: 1.3288 - precision: 0.6547
# Epoch 56: val_loss improved from 1.14559 to 1.14018, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5393 - auc: 0.8987 - f1_score: 0.5283 - loss: 1.3311 - precision: 0.6585 - val_accuracy: 0.6250 - val_auc: 0.9314 - val_f1_score: 0.6184 - val_loss: 1.1402 - val_precision: 0.8400
# Epoch 57/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5529 - auc: 0.9031 - f1_score: 0.5385 - loss: 1.2999 - precision: 0.6657
# Epoch 57: val_loss improved from 1.14018 to 1.13566, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5514 - auc: 0.9021 - f1_score: 0.5379 - loss: 1.3058 - precision: 0.6688 - val_accuracy: 0.6250 - val_auc: 0.9319 - val_f1_score: 0.6179 - val_loss: 1.1357 - val_precision: 0.8400
# Epoch 58/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5606 - auc: 0.9035 - f1_score: 0.5504 - loss: 1.2817 - precision: 0.7141
# Epoch 58: val_loss improved from 1.13566 to 1.12683, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5597 - auc: 0.9036 - f1_score: 0.5503 - loss: 1.2823 - precision: 0.7131 - val_accuracy: 0.6375 - val_auc: 0.9326 - val_f1_score: 0.6293 - val_loss: 1.1268 - val_precision: 0.8400
# Epoch 59/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5229 - auc: 0.9133 - f1_score: 0.5152 - loss: 1.2419 - precision: 0.6752
# Epoch 59: val_loss improved from 1.12683 to 1.12142, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.5251 - auc: 0.9120 - f1_score: 0.5177 - loss: 1.2496 - precision: 0.6755 - val_accuracy: 0.6375 - val_auc: 0.9335 - val_f1_score: 0.6293 - val_loss: 1.1214 - val_precision: 0.8400
# Epoch 60/500
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5278 - auc: 0.9042 - f1_score: 0.5126 - loss: 1.3027 - precision: 0.6784
# Epoch 60: val_loss improved from 1.12142 to 1.11553, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.5342 - auc: 0.9065 - f1_score: 0.5212 - loss: 1.2857 - precision: 0.6862 - val_accuracy: 0.6375 - val_auc: 0.9342 - val_f1_score: 0.6292 - val_loss: 1.1155 - val_precision: 0.8378
# Epoch 61/500
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5593 - auc: 0.9093 - f1_score: 0.5487 - loss: 1.2552 - precision: 0.7129
# Epoch 61: val_loss improved from 1.11553 to 1.11199, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.5595 - auc: 0.9109 - f1_score: 0.5510 - loss: 1.2470 - precision: 0.7167 - val_accuracy: 0.6375 - val_auc: 0.9347 - val_f1_score: 0.6292 - val_loss: 1.1120 - val_precision: 0.8400
# Epoch 62/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5474 - auc: 0.9006 - f1_score: 0.5381 - loss: 1.3149 - precision: 0.7027
# Epoch 62: val_loss improved from 1.11199 to 1.10767, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5483 - auc: 0.9009 - f1_score: 0.5392 - loss: 1.3123 - precision: 0.7042 - val_accuracy: 0.6438 - val_auc: 0.9355 - val_f1_score: 0.6371 - val_loss: 1.1077 - val_precision: 0.8289
# Epoch 63/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6296 - auc: 0.9345 - f1_score: 0.6238 - loss: 1.0805 - precision: 0.7802
# Epoch 63: val_loss improved from 1.10767 to 1.10564, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6221 - auc: 0.9321 - f1_score: 0.6164 - loss: 1.0985 - precision: 0.7726 - val_accuracy: 0.6438 - val_auc: 0.9344 - val_f1_score: 0.6371 - val_loss: 1.1056 - val_precision: 0.8312
# Epoch 64/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6186 - auc: 0.9320 - f1_score: 0.6125 - loss: 1.1091 - precision: 0.7046
# Epoch 64: val_loss improved from 1.10564 to 1.10391, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6143 - auc: 0.9299 - f1_score: 0.6075 - loss: 1.1225 - precision: 0.7044 - val_accuracy: 0.6313 - val_auc: 0.9341 - val_f1_score: 0.6244 - val_loss: 1.1039 - val_precision: 0.8158
# Epoch 65/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5869 - auc: 0.9141 - f1_score: 0.5770 - loss: 1.2079 - precision: 0.7645
# Epoch 65: val_loss improved from 1.10391 to 1.09900, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5829 - auc: 0.9133 - f1_score: 0.5735 - loss: 1.2156 - precision: 0.7611 - val_accuracy: 0.6250 - val_auc: 0.9350 - val_f1_score: 0.6167 - val_loss: 1.0990 - val_precision: 0.8289
# Epoch 66/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5744 - auc: 0.9120 - f1_score: 0.5610 - loss: 1.2282 - precision: 0.7329
# Epoch 66: val_loss improved from 1.09900 to 1.09546, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5744 - auc: 0.9121 - f1_score: 0.5629 - loss: 1.2300 - precision: 0.7273 - val_accuracy: 0.6187 - val_auc: 0.9353 - val_f1_score: 0.6113 - val_loss: 1.0955 - val_precision: 0.8400
# Epoch 67/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5493 - auc: 0.9099 - f1_score: 0.5366 - loss: 1.2509 - precision: 0.7317
# Epoch 67: val_loss improved from 1.09546 to 1.09336, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5516 - auc: 0.9106 - f1_score: 0.5399 - loss: 1.2461 - precision: 0.7327 - val_accuracy: 0.6250 - val_auc: 0.9353 - val_f1_score: 0.6167 - val_loss: 1.0934 - val_precision: 0.8312
# Epoch 68/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5740 - auc: 0.9236 - f1_score: 0.5580 - loss: 1.1639 - precision: 0.7048
# Epoch 68: val_loss improved from 1.09336 to 1.09002, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5743 - auc: 0.9219 - f1_score: 0.5603 - loss: 1.1762 - precision: 0.7058 - val_accuracy: 0.6313 - val_auc: 0.9360 - val_f1_score: 0.6244 - val_loss: 1.0900 - val_precision: 0.8312
# Epoch 69/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5893 - auc: 0.9178 - f1_score: 0.5788 - loss: 1.1987 - precision: 0.7303
# Epoch 69: val_loss improved from 1.09002 to 1.08776, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5877 - auc: 0.9174 - f1_score: 0.5781 - loss: 1.2013 - precision: 0.7313 - val_accuracy: 0.6250 - val_auc: 0.9361 - val_f1_score: 0.6197 - val_loss: 1.0878 - val_precision: 0.8462
# Epoch 70/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5779 - auc: 0.9169 - f1_score: 0.5587 - loss: 1.2060 - precision: 0.7117
# Epoch 70: val_loss improved from 1.08776 to 1.08472, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5804 - auc: 0.9177 - f1_score: 0.5640 - loss: 1.2007 - precision: 0.7163 - val_accuracy: 0.6187 - val_auc: 0.9365 - val_f1_score: 0.6119 - val_loss: 1.0847 - val_precision: 0.8250
# Epoch 71/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6308 - auc: 0.9347 - f1_score: 0.6244 - loss: 1.0770 - precision: 0.8067
# Epoch 71: val_loss improved from 1.08472 to 1.08164, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6285 - auc: 0.9331 - f1_score: 0.6220 - loss: 1.0876 - precision: 0.8025 - val_accuracy: 0.6125 - val_auc: 0.9369 - val_f1_score: 0.6054 - val_loss: 1.0816 - val_precision: 0.8250
# Epoch 72/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6302 - auc: 0.9274 - f1_score: 0.6198 - loss: 1.1283 - precision: 0.7697
# Epoch 72: val_loss improved from 1.08164 to 1.08002, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.6266 - auc: 0.9271 - f1_score: 0.6170 - loss: 1.1316 - precision: 0.7687 - val_accuracy: 0.6125 - val_auc: 0.9369 - val_f1_score: 0.6054 - val_loss: 1.0800 - val_precision: 0.8462
# Epoch 73/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5764 - auc: 0.9145 - f1_score: 0.5705 - loss: 1.2293 - precision: 0.7069
# Epoch 73: val_loss improved from 1.08002 to 1.07749, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5786 - auc: 0.9153 - f1_score: 0.5722 - loss: 1.2229 - precision: 0.7122 - val_accuracy: 0.6125 - val_auc: 0.9371 - val_f1_score: 0.6051 - val_loss: 1.0775 - val_precision: 0.8375
# Epoch 74/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6183 - auc: 0.9314 - f1_score: 0.6084 - loss: 1.0985 - precision: 0.7766
# Epoch 74: val_loss improved from 1.07749 to 1.07401, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6126 - auc: 0.9292 - f1_score: 0.6033 - loss: 1.1149 - precision: 0.7696 - val_accuracy: 0.6187 - val_auc: 0.9376 - val_f1_score: 0.6120 - val_loss: 1.0740 - val_precision: 0.8272
# Epoch 75/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6145 - auc: 0.9455 - f1_score: 0.6049 - loss: 1.0088 - precision: 0.8060
# Epoch 75: val_loss improved from 1.07401 to 1.07158, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6120 - auc: 0.9433 - f1_score: 0.6037 - loss: 1.0231 - precision: 0.8010 - val_accuracy: 0.6250 - val_auc: 0.9383 - val_f1_score: 0.6186 - val_loss: 1.0716 - val_precision: 0.8272
# Epoch 76/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6047 - auc: 0.9267 - f1_score: 0.5983 - loss: 1.1359 - precision: 0.7592
# Epoch 76: val_loss improved from 1.07158 to 1.06524, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6049 - auc: 0.9262 - f1_score: 0.5986 - loss: 1.1394 - precision: 0.7599 - val_accuracy: 0.6313 - val_auc: 0.9387 - val_f1_score: 0.6236 - val_loss: 1.0652 - val_precision: 0.8354
# Epoch 77/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5712 - auc: 0.9182 - f1_score: 0.5587 - loss: 1.1892 - precision: 0.7781
# Epoch 77: val_loss improved from 1.06524 to 1.06148, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5735 - auc: 0.9180 - f1_score: 0.5618 - loss: 1.1903 - precision: 0.7755 - val_accuracy: 0.6313 - val_auc: 0.9391 - val_f1_score: 0.6236 - val_loss: 1.0615 - val_precision: 0.8354
# Epoch 78/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6435 - auc: 0.9428 - f1_score: 0.6293 - loss: 1.0174 - precision: 0.8018
# Epoch 78: val_loss improved from 1.06148 to 1.05803, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6395 - auc: 0.9420 - f1_score: 0.6274 - loss: 1.0243 - precision: 0.7959 - val_accuracy: 0.6313 - val_auc: 0.9403 - val_f1_score: 0.6236 - val_loss: 1.0580 - val_precision: 0.8375
# Epoch 79/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5816 - auc: 0.9237 - f1_score: 0.5760 - loss: 1.1606 - precision: 0.7015
# Epoch 79: val_loss improved from 1.05803 to 1.05627, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5850 - auc: 0.9238 - f1_score: 0.5791 - loss: 1.1596 - precision: 0.7118 - val_accuracy: 0.6313 - val_auc: 0.9402 - val_f1_score: 0.6238 - val_loss: 1.0563 - val_precision: 0.8272
# Epoch 80/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5968 - auc: 0.9303 - f1_score: 0.5844 - loss: 1.1101 - precision: 0.7640
# Epoch 80: val_loss improved from 1.05627 to 1.05465, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5987 - auc: 0.9302 - f1_score: 0.5874 - loss: 1.1096 - precision: 0.7622 - val_accuracy: 0.6375 - val_auc: 0.9398 - val_f1_score: 0.6307 - val_loss: 1.0547 - val_precision: 0.8415
# Epoch 81/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6067 - auc: 0.9289 - f1_score: 0.6010 - loss: 1.1101 - precision: 0.7433
# Epoch 81: val_loss improved from 1.05465 to 1.05394, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6110 - auc: 0.9300 - f1_score: 0.6054 - loss: 1.1022 - precision: 0.7492 - val_accuracy: 0.6438 - val_auc: 0.9398 - val_f1_score: 0.6353 - val_loss: 1.0539 - val_precision: 0.8434
# Epoch 82/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6637 - auc: 0.9399 - f1_score: 0.6503 - loss: 1.0345 - precision: 0.7700
# Epoch 82: val_loss improved from 1.05394 to 1.05036, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6597 - auc: 0.9397 - f1_score: 0.6477 - loss: 1.0369 - precision: 0.7703 - val_accuracy: 0.6375 - val_auc: 0.9401 - val_f1_score: 0.6263 - val_loss: 1.0504 - val_precision: 0.8434
# Epoch 83/500
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6194 - auc: 0.9327 - f1_score: 0.6035 - loss: 1.0850 - precision: 0.7714
# Epoch 83: val_loss improved from 1.05036 to 1.04655, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6157 - auc: 0.9324 - f1_score: 0.6030 - loss: 1.0886 - precision: 0.7664 - val_accuracy: 0.6438 - val_auc: 0.9406 - val_f1_score: 0.6321 - val_loss: 1.0466 - val_precision: 0.8313
# Epoch 84/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6121 - auc: 0.9358 - f1_score: 0.6146 - loss: 1.0654 - precision: 0.7848
# Epoch 84: val_loss improved from 1.04655 to 1.04389, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6144 - auc: 0.9354 - f1_score: 0.6160 - loss: 1.0686 - precision: 0.7817 - val_accuracy: 0.6375 - val_auc: 0.9411 - val_f1_score: 0.6276 - val_loss: 1.0439 - val_precision: 0.8333
# Epoch 85/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6477 - auc: 0.9345 - f1_score: 0.6366 - loss: 1.0585 - precision: 0.8175
# Epoch 85: val_loss improved from 1.04389 to 1.03886, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6435 - auc: 0.9348 - f1_score: 0.6333 - loss: 1.0584 - precision: 0.8098 - val_accuracy: 0.6438 - val_auc: 0.9415 - val_f1_score: 0.6321 - val_loss: 1.0389 - val_precision: 0.8353
# Epoch 86/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6354 - auc: 0.9413 - f1_score: 0.6293 - loss: 1.0284 - precision: 0.7684
# Epoch 86: val_loss improved from 1.03886 to 1.03380, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6377 - auc: 0.9415 - f1_score: 0.6317 - loss: 1.0261 - precision: 0.7717 - val_accuracy: 0.6438 - val_auc: 0.9417 - val_f1_score: 0.6321 - val_loss: 1.0338 - val_precision: 0.8391
# Epoch 87/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6458 - auc: 0.9331 - f1_score: 0.6364 - loss: 1.0733 - precision: 0.7701
# Epoch 87: val_loss improved from 1.03380 to 1.02901, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6408 - auc: 0.9333 - f1_score: 0.6321 - loss: 1.0740 - precision: 0.7663 - val_accuracy: 0.6500 - val_auc: 0.9423 - val_f1_score: 0.6388 - val_loss: 1.0290 - val_precision: 0.8391
# Epoch 88/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6293 - auc: 0.9372 - f1_score: 0.6221 - loss: 1.0583 - precision: 0.7648
# Epoch 88: val_loss improved from 1.02901 to 1.02518, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6284 - auc: 0.9364 - f1_score: 0.6221 - loss: 1.0637 - precision: 0.7638 - val_accuracy: 0.6438 - val_auc: 0.9429 - val_f1_score: 0.6319 - val_loss: 1.0252 - val_precision: 0.8427
# Epoch 89/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6225 - auc: 0.9352 - f1_score: 0.6160 - loss: 1.0802 - precision: 0.7886
# Epoch 89: val_loss improved from 1.02518 to 1.02422, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6251 - auc: 0.9356 - f1_score: 0.6188 - loss: 1.0752 - precision: 0.7927 - val_accuracy: 0.6438 - val_auc: 0.9432 - val_f1_score: 0.6338 - val_loss: 1.0242 - val_precision: 0.8427
# Epoch 90/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6675 - auc: 0.9423 - f1_score: 0.6613 - loss: 1.0131 - precision: 0.7892
# Epoch 90: val_loss improved from 1.02422 to 1.02390, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6662 - auc: 0.9423 - f1_score: 0.6607 - loss: 1.0124 - precision: 0.7883 - val_accuracy: 0.6438 - val_auc: 0.9426 - val_f1_score: 0.6362 - val_loss: 1.0239 - val_precision: 0.8427
# Epoch 91/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6504 - auc: 0.9379 - f1_score: 0.6429 - loss: 1.0537 - precision: 0.7811
# Epoch 91: val_loss did not improve from 1.02390
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6500 - auc: 0.9384 - f1_score: 0.6433 - loss: 1.0493 - precision: 0.7836 - val_accuracy: 0.6375 - val_auc: 0.9425 - val_f1_score: 0.6294 - val_loss: 1.0257 - val_precision: 0.8523
# Epoch 92/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6413 - auc: 0.9338 - f1_score: 0.6339 - loss: 1.0669 - precision: 0.7485
# Epoch 92: val_loss did not improve from 1.02390
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6417 - auc: 0.9351 - f1_score: 0.6345 - loss: 1.0584 - precision: 0.7538 - val_accuracy: 0.6375 - val_auc: 0.9426 - val_f1_score: 0.6294 - val_loss: 1.0251 - val_precision: 0.8523
# Epoch 93/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6355 - auc: 0.9305 - f1_score: 0.6336 - loss: 1.1037 - precision: 0.7744
# Epoch 93: val_loss improved from 1.02390 to 1.01993, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6349 - auc: 0.9315 - f1_score: 0.6327 - loss: 1.0978 - precision: 0.7719 - val_accuracy: 0.6500 - val_auc: 0.9436 - val_f1_score: 0.6417 - val_loss: 1.0199 - val_precision: 0.8444
# Epoch 94/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6363 - auc: 0.9377 - f1_score: 0.6263 - loss: 1.0470 - precision: 0.7604
# Epoch 94: val_loss improved from 1.01993 to 1.01704, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6390 - auc: 0.9387 - f1_score: 0.6299 - loss: 1.0399 - precision: 0.7622 - val_accuracy: 0.6438 - val_auc: 0.9437 - val_f1_score: 0.6362 - val_loss: 1.0170 - val_precision: 0.8444
# Epoch 95/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6114 - auc: 0.9350 - f1_score: 0.6000 - loss: 1.0725 - precision: 0.7724
# Epoch 95: val_loss improved from 1.01704 to 1.01701, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6152 - auc: 0.9354 - f1_score: 0.6056 - loss: 1.0697 - precision: 0.7696 - val_accuracy: 0.6438 - val_auc: 0.9440 - val_f1_score: 0.6362 - val_loss: 1.0170 - val_precision: 0.8444
# Epoch 96/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6373 - auc: 0.9431 - f1_score: 0.6202 - loss: 1.0156 - precision: 0.7904
# Epoch 96: val_loss did not improve from 1.01701
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6384 - auc: 0.9434 - f1_score: 0.6237 - loss: 1.0128 - precision: 0.7895 - val_accuracy: 0.6313 - val_auc: 0.9436 - val_f1_score: 0.6245 - val_loss: 1.0196 - val_precision: 0.8539
# Epoch 97/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6692 - auc: 0.9484 - f1_score: 0.6697 - loss: 0.9600 - precision: 0.7880
# Epoch 97: val_loss did not improve from 1.01701
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6611 - auc: 0.9464 - f1_score: 0.6608 - loss: 0.9769 - precision: 0.7800 - val_accuracy: 0.6438 - val_auc: 0.9436 - val_f1_score: 0.6356 - val_loss: 1.0195 - val_precision: 0.8539
# Epoch 98/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6608 - auc: 0.9405 - f1_score: 0.6571 - loss: 1.0190 - precision: 0.7780
# Epoch 98: val_loss did not improve from 1.01701
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6613 - auc: 0.9413 - f1_score: 0.6577 - loss: 1.0123 - precision: 0.7815 - val_accuracy: 0.6438 - val_auc: 0.9437 - val_f1_score: 0.6356 - val_loss: 1.0176 - val_precision: 0.8478
# Epoch 99/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7005 - auc: 0.9545 - f1_score: 0.6954 - loss: 0.9105 - precision: 0.8230
# Epoch 99: val_loss improved from 1.01701 to 1.01397, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6972 - auc: 0.9529 - f1_score: 0.6926 - loss: 0.9225 - precision: 0.8188 - val_accuracy: 0.6500 - val_auc: 0.9440 - val_f1_score: 0.6429 - val_loss: 1.0140 - val_precision: 0.8462
# Epoch 100/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6792 - auc: 0.9485 - f1_score: 0.6706 - loss: 0.9562 - precision: 0.7985
# Epoch 100: val_loss improved from 1.01397 to 1.01021, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6755 - auc: 0.9482 - f1_score: 0.6678 - loss: 0.9594 - precision: 0.7960 - val_accuracy: 0.6500 - val_auc: 0.9446 - val_f1_score: 0.6429 - val_loss: 1.0102 - val_precision: 0.8298
# Epoch 101/500
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6429 - auc: 0.9396 - f1_score: 0.6382 - loss: 1.0353 - precision: 0.7375
# Epoch 101: val_loss improved from 1.01021 to 1.00965, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6410 - auc: 0.9400 - f1_score: 0.6373 - loss: 1.0323 - precision: 0.7548 - val_accuracy: 0.6500 - val_auc: 0.9444 - val_f1_score: 0.6429 - val_loss: 1.0096 - val_precision: 0.8462
# Epoch 102/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6703 - auc: 0.9510 - f1_score: 0.6578 - loss: 0.9408 - precision: 0.8097
# Epoch 102: val_loss improved from 1.00965 to 1.00797, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6677 - auc: 0.9500 - f1_score: 0.6576 - loss: 0.9492 - precision: 0.8044 - val_accuracy: 0.6375 - val_auc: 0.9445 - val_f1_score: 0.6288 - val_loss: 1.0080 - val_precision: 0.8462
# Epoch 103/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6565 - auc: 0.9466 - f1_score: 0.6518 - loss: 0.9817 - precision: 0.8020
# Epoch 103: val_loss improved from 1.00797 to 1.00346, saving model to najlepszy_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.6617 - auc: 0.9473 - f1_score: 0.6573 - loss: 0.9754 - precision: 0.8026 - val_accuracy: 0.6562 - val_auc: 0.9452 - val_f1_score: 0.6464 - val_loss: 1.0035 - val_precision: 0.8462
# Epoch 104/500
# ...
# Epoch 213/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8164 - auc: 0.9842 - f1_score: 0.8100 - loss: 0.5503 - precision: 0.8825
# Epoch 213: val_loss did not improve from 0.90809
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8162 - auc: 0.9843 - f1_score: 0.8108 - loss: 0.5505 - precision: 0.8841 - val_accuracy: 0.6875 - val_auc: 0.9524 - val_f1_score: 0.6905 - val_loss: 0.9104 - val_precision: 0.7913
# Epoch 214/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8063 - auc: 0.9893 - f1_score: 0.8076 - loss: 0.4909 - precision: 0.9049
# Epoch 214: val_loss did not improve from 0.90809
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8091 - auc: 0.9884 - f1_score: 0.8099 - loss: 0.5005 - precision: 0.9051 - val_accuracy: 0.6875 - val_auc: 0.9523 - val_f1_score: 0.6906 - val_loss: 0.9090 - val_precision: 0.7845
# Epoch 215/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8426 - auc: 0.9883 - f1_score: 0.8353 - loss: 0.5067 - precision: 0.9155
# Epoch 215: val_loss did not improve from 0.90809
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8411 - auc: 0.9881 - f1_score: 0.8343 - loss: 0.5094 - precision: 0.9147 - val_accuracy: 0.6875 - val_auc: 0.9523 - val_f1_score: 0.6906 - val_loss: 0.9093 - val_precision: 0.7863
# Epoch 216/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8215 - auc: 0.9852 - f1_score: 0.8215 - loss: 0.5318 - precision: 0.8994
# Epoch 216: val_loss did not improve from 0.90809
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8216 - auc: 0.9853 - f1_score: 0.8217 - loss: 0.5313 - precision: 0.8995 - val_accuracy: 0.6875 - val_auc: 0.9519 - val_f1_score: 0.6906 - val_loss: 0.9102 - val_precision: 0.7759
# Epoch 217/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8227 - auc: 0.9814 - f1_score: 0.8220 - loss: 0.5985 - precision: 0.8786
# Epoch 217: val_loss did not improve from 0.90809
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8215 - auc: 0.9814 - f1_score: 0.8207 - loss: 0.5983 - precision: 0.8784 - val_accuracy: 0.6875 - val_auc: 0.9512 - val_f1_score: 0.6906 - val_loss: 0.9180 - val_precision: 0.7913
# Epoch 218/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8414 - auc: 0.9844 - f1_score: 0.8430 - loss: 0.5459 - precision: 0.8817
# Epoch 218: val_loss did not improve from 0.90809
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8366 - auc: 0.9838 - f1_score: 0.8375 - loss: 0.5548 - precision: 0.8814 - val_accuracy: 0.6812 - val_auc: 0.9507 - val_f1_score: 0.6842 - val_loss: 0.9247 - val_precision: 0.7778
# Epoch 219/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8430 - auc: 0.9882 - f1_score: 0.8410 - loss: 0.5012 - precision: 0.9295
# Epoch 219: val_loss did not improve from 0.90809
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8411 - auc: 0.9880 - f1_score: 0.8397 - loss: 0.5051 - precision: 0.9262 - val_accuracy: 0.6812 - val_auc: 0.9509 - val_f1_score: 0.6844 - val_loss: 0.9267 - val_precision: 0.7712
# Epoch 220/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8499 - auc: 0.9874 - f1_score: 0.8464 - loss: 0.5159 - precision: 0.8984
# Epoch 220: val_loss did not improve from 0.90809
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8453 - auc: 0.9871 - f1_score: 0.8425 - loss: 0.5201 - precision: 0.8979 - val_accuracy: 0.6750 - val_auc: 0.9507 - val_f1_score: 0.6798 - val_loss: 0.9291 - val_precision: 0.7712
# Epoch 221/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8370 - auc: 0.9879 - f1_score: 0.8311 - loss: 0.4892 - precision: 0.9059
# Epoch 221: val_loss did not improve from 0.90809
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8325 - auc: 0.9871 - f1_score: 0.8274 - loss: 0.4994 - precision: 0.9033 - val_accuracy: 0.6687 - val_auc: 0.9508 - val_f1_score: 0.6722 - val_loss: 0.9276 - val_precision: 0.7826
# Epoch 222/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8227 - auc: 0.9860 - f1_score: 0.8210 - loss: 0.5315 - precision: 0.8899
# Epoch 222: val_loss did not improve from 0.90809
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8265 - auc: 0.9863 - f1_score: 0.8251 - loss: 0.5268 - precision: 0.8917 - val_accuracy: 0.6750 - val_auc: 0.9506 - val_f1_score: 0.6783 - val_loss: 0.9282 - val_precision: 0.7845
# Epoch 223/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8092 - auc: 0.9850 - f1_score: 0.8007 - loss: 0.5413 - precision: 0.8484
# Epoch 223: val_loss did not improve from 0.90809
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8114 - auc: 0.9852 - f1_score: 0.8044 - loss: 0.5374 - precision: 0.8533 - val_accuracy: 0.6750 - val_auc: 0.9512 - val_f1_score: 0.6778 - val_loss: 0.9231 - val_precision: 0.7778
# Epoch 224/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8337 - auc: 0.9849 - f1_score: 0.8288 - loss: 0.5479 - precision: 0.9110
# Epoch 224: val_loss did not improve from 0.90809
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8345 - auc: 0.9850 - f1_score: 0.8312 - loss: 0.5419 - precision: 0.9112 - val_accuracy: 0.6812 - val_auc: 0.9517 - val_f1_score: 0.6854 - val_loss: 0.9190 - val_precision: 0.7778
# Epoch 225/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8431 - auc: 0.9882 - f1_score: 0.8375 - loss: 0.4979 - precision: 0.9086
# Epoch 225: val_loss did not improve from 0.90809
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8423 - auc: 0.9878 - f1_score: 0.8373 - loss: 0.5013 - precision: 0.9076 - val_accuracy: 0.6875 - val_auc: 0.9518 - val_f1_score: 0.6912 - val_loss: 0.9162 - val_precision: 0.7845
# Epoch 226/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8396 - auc: 0.9856 - f1_score: 0.8344 - loss: 0.5357 - precision: 0.9269
# Epoch 226: val_loss did not improve from 0.90809
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8394 - auc: 0.9857 - f1_score: 0.8346 - loss: 0.5348 - precision: 0.9247 - val_accuracy: 0.6938 - val_auc: 0.9523 - val_f1_score: 0.6973 - val_loss: 0.9104 - val_precision: 0.7931
# Epoch 227/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8441 - auc: 0.9882 - f1_score: 0.8423 - loss: 0.4840 - precision: 0.9136
# Epoch 227: val_loss did not improve from 0.90809
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8449 - auc: 0.9882 - f1_score: 0.8433 - loss: 0.4843 - precision: 0.9131 - val_accuracy: 0.6938 - val_auc: 0.9517 - val_f1_score: 0.6969 - val_loss: 0.9115 - val_precision: 0.7949
# Epoch 228/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8099 - auc: 0.9842 - f1_score: 0.8068 - loss: 0.5522 - precision: 0.8891
# Epoch 228: val_loss did not improve from 0.90809
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8134 - auc: 0.9847 - f1_score: 0.8109 - loss: 0.5448 - precision: 0.8903 - val_accuracy: 0.6875 - val_auc: 0.9513 - val_f1_score: 0.6896 - val_loss: 0.9148 - val_precision: 0.7833
# Epoch 229/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8152 - auc: 0.9884 - f1_score: 0.8127 - loss: 0.4979 - precision: 0.8969
# Epoch 229: val_loss did not improve from 0.90809
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8150 - auc: 0.9880 - f1_score: 0.8129 - loss: 0.5027 - precision: 0.8968 - val_accuracy: 0.6938 - val_auc: 0.9508 - val_f1_score: 0.6969 - val_loss: 0.9187 - val_precision: 0.7899
# Epoch 230/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8111 - auc: 0.9871 - f1_score: 0.8049 - loss: 0.5099 - precision: 0.8847
# Epoch 230: val_loss did not improve from 0.90809
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8153 - auc: 0.9869 - f1_score: 0.8101 - loss: 0.5091 - precision: 0.8869 - val_accuracy: 0.6875 - val_auc: 0.9509 - val_f1_score: 0.6905 - val_loss: 0.9204 - val_precision: 0.7863
# Epoch 231/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8672 - auc: 0.9895 - f1_score: 0.8708 - loss: 0.4768 - precision: 0.9286
# Epoch 231: val_loss did not improve from 0.90809
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8631 - auc: 0.9890 - f1_score: 0.8661 - loss: 0.4837 - precision: 0.9240 - val_accuracy: 0.6875 - val_auc: 0.9509 - val_f1_score: 0.6903 - val_loss: 0.9224 - val_precision: 0.7863
# Epoch 232/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8412 - auc: 0.9882 - f1_score: 0.8382 - loss: 0.4967 - precision: 0.9010
# Epoch 232: val_loss did not improve from 0.90809
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8379 - auc: 0.9879 - f1_score: 0.8355 - loss: 0.5004 - precision: 0.8993 - val_accuracy: 0.6875 - val_auc: 0.9513 - val_f1_score: 0.6902 - val_loss: 0.9211 - val_precision: 0.7949
# Epoch 233/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8627 - auc: 0.9857 - f1_score: 0.8639 - loss: 0.5235 - precision: 0.9047
# Epoch 233: val_loss did not improve from 0.90809
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8598 - auc: 0.9860 - f1_score: 0.8606 - loss: 0.5198 - precision: 0.9046 - val_accuracy: 0.6875 - val_auc: 0.9517 - val_f1_score: 0.6912 - val_loss: 0.9161 - val_precision: 0.7863
# Epoch 234/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8367 - auc: 0.9867 - f1_score: 0.8348 - loss: 0.4958 - precision: 0.8870
# Epoch 234: val_loss did not improve from 0.90809
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8377 - auc: 0.9870 - f1_score: 0.8360 - loss: 0.4936 - precision: 0.8894 - val_accuracy: 0.6875 - val_auc: 0.9516 - val_f1_score: 0.6917 - val_loss: 0.9160 - val_precision: 0.7913
# Epoch 235/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8658 - auc: 0.9883 - f1_score: 0.8618 - loss: 0.4708 - precision: 0.9104
# Epoch 235: val_loss did not improve from 0.90809
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8609 - auc: 0.9879 - f1_score: 0.8577 - loss: 0.4776 - precision: 0.9061 - val_accuracy: 0.6875 - val_auc: 0.9513 - val_f1_score: 0.6917 - val_loss: 0.9190 - val_precision: 0.7845
# Epoch 236/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8445 - auc: 0.9867 - f1_score: 0.8421 - loss: 0.4987 - precision: 0.9250
# Epoch 236: val_loss did not improve from 0.90809
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8435 - auc: 0.9866 - f1_score: 0.8415 - loss: 0.5004 - precision: 0.9229 - val_accuracy: 0.6875 - val_auc: 0.9511 - val_f1_score: 0.6912 - val_loss: 0.9202 - val_precision: 0.7845
# Epoch 237/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8689 - auc: 0.9911 - f1_score: 0.8695 - loss: 0.4453 - precision: 0.9195
# Epoch 237: val_loss did not improve from 0.90809
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8683 - auc: 0.9911 - f1_score: 0.8689 - loss: 0.4446 - precision: 0.9189 - val_accuracy: 0.6875 - val_auc: 0.9508 - val_f1_score: 0.6912 - val_loss: 0.9218 - val_precision: 0.7863
# Epoch 238/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8306 - auc: 0.9886 - f1_score: 0.8258 - loss: 0.4858 - precision: 0.9060
# Epoch 238: val_loss did not improve from 0.90809
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8273 - auc: 0.9883 - f1_score: 0.8235 - loss: 0.4900 - precision: 0.9019 - val_accuracy: 0.6875 - val_auc: 0.9516 - val_f1_score: 0.6912 - val_loss: 0.9185 - val_precision: 0.7845
# Epoch 239/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8575 - auc: 0.9885 - f1_score: 0.8566 - loss: 0.4701 - precision: 0.9158
# Epoch 239: val_loss did not improve from 0.90809
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8568 - auc: 0.9888 - f1_score: 0.8563 - loss: 0.4660 - precision: 0.9176 - val_accuracy: 0.6875 - val_auc: 0.9515 - val_f1_score: 0.6912 - val_loss: 0.9191 - val_precision: 0.7899
# Epoch 240/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8507 - auc: 0.9898 - f1_score: 0.8461 - loss: 0.4719 - precision: 0.9054
# Epoch 240: val_loss did not improve from 0.90809
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8468 - auc: 0.9895 - f1_score: 0.8429 - loss: 0.4751 - precision: 0.9045 - val_accuracy: 0.6875 - val_auc: 0.9506 - val_f1_score: 0.6928 - val_loss: 0.9233 - val_precision: 0.7966
# Epoch 241/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8638 - auc: 0.9880 - f1_score: 0.8645 - loss: 0.4787 - precision: 0.9232
# Epoch 241: val_loss did not improve from 0.90809
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8595 - auc: 0.9879 - f1_score: 0.8603 - loss: 0.4799 - precision: 0.9207 - val_accuracy: 0.6938 - val_auc: 0.9517 - val_f1_score: 0.6995 - val_loss: 0.9206 - val_precision: 0.7983
# Epoch 242/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8637 - auc: 0.9841 - f1_score: 0.8653 - loss: 0.5079 - precision: 0.9176
# Epoch 242: val_loss did not improve from 0.90809
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8623 - auc: 0.9847 - f1_score: 0.8636 - loss: 0.5032 - precision: 0.9162 - val_accuracy: 0.6938 - val_auc: 0.9514 - val_f1_score: 0.6977 - val_loss: 0.9175 - val_precision: 0.7983
# Epoch 243/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8262 - auc: 0.9860 - f1_score: 0.8227 - loss: 0.5212 - precision: 0.8890
# Epoch 243: val_loss did not improve from 0.90809
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8296 - auc: 0.9865 - f1_score: 0.8267 - loss: 0.5131 - precision: 0.8904 - val_accuracy: 0.6938 - val_auc: 0.9519 - val_f1_score: 0.6977 - val_loss: 0.9179 - val_precision: 0.7966
# Epoch 244/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8289 - auc: 0.9883 - f1_score: 0.8308 - loss: 0.4910 - precision: 0.8959
# Epoch 244: val_loss did not improve from 0.90809
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8310 - auc: 0.9885 - f1_score: 0.8326 - loss: 0.4867 - precision: 0.8972 - val_accuracy: 0.6938 - val_auc: 0.9519 - val_f1_score: 0.6966 - val_loss: 0.9196 - val_precision: 0.7899
# Epoch 245/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8646 - auc: 0.9898 - f1_score: 0.8633 - loss: 0.4459 - precision: 0.9223
# Epoch 245: val_loss did not improve from 0.90809
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8630 - auc: 0.9897 - f1_score: 0.8621 - loss: 0.4486 - precision: 0.9234 - val_accuracy: 0.6938 - val_auc: 0.9514 - val_f1_score: 0.6977 - val_loss: 0.9174 - val_precision: 0.7863
# Epoch 246/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8647 - auc: 0.9903 - f1_score: 0.8591 - loss: 0.4337 - precision: 0.9122
# Epoch 246: val_loss did not improve from 0.90809
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8631 - auc: 0.9900 - f1_score: 0.8586 - loss: 0.4398 - precision: 0.9107 - val_accuracy: 0.7000 - val_auc: 0.9516 - val_f1_score: 0.7042 - val_loss: 0.9154 - val_precision: 0.7863
# Epoch 247/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8472 - auc: 0.9893 - f1_score: 0.8434 - loss: 0.4665 - precision: 0.8859
# Epoch 247: val_loss did not improve from 0.90809
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8477 - auc: 0.9894 - f1_score: 0.8444 - loss: 0.4650 - precision: 0.8876 - val_accuracy: 0.7000 - val_auc: 0.9514 - val_f1_score: 0.7038 - val_loss: 0.9156 - val_precision: 0.7787
# Epoch 248/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8398 - auc: 0.9898 - f1_score: 0.8304 - loss: 0.4757 - precision: 0.9012
# Epoch 248: val_loss did not improve from 0.90809
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8433 - auc: 0.9899 - f1_score: 0.8356 - loss: 0.4721 - precision: 0.9033 - val_accuracy: 0.7000 - val_auc: 0.9521 - val_f1_score: 0.7038 - val_loss: 0.9129 - val_precision: 0.7815
# Epoch 249/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8321 - auc: 0.9892 - f1_score: 0.8287 - loss: 0.4802 - precision: 0.8982
# Epoch 249: val_loss did not improve from 0.90809
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8376 - auc: 0.9895 - f1_score: 0.8347 - loss: 0.4736 - precision: 0.9019 - val_accuracy: 0.7000 - val_auc: 0.9522 - val_f1_score: 0.7038 - val_loss: 0.9168 - val_precision: 0.7899
# Epoch 249: early stopping
# Restoring model weights from the end of the best epoch: 199.

# %%
plt.figure(figsize=(20, 6))

# Plot training and validation accuracy
plt.subplot(1, 3, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot training and validation loss
plt.subplot(1, 3, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 3, 3)
plt.plot(history.history['precision'], label='Training Precision')
plt.plot(history.history['val_precision'], label='Validation Precision')
plt.title('Precision over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
y_pred_probs = model.predict(X_test)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = np.argmax(y_test, axis=1) if y_test.ndim > 1 else y_test

accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred, average='macro', zero_division=0)
f1 = f1_score(y_true, y_pred, average='macro')
conf_matrix = confusion_matrix(y_true, y_pred)

print("Dokładność:", accuracy)
print("Precyzja (macro):", precision)
print("F1 score (macro):", f1)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Dokładność: 0.685
# Precyzja (macro): 0.6871995122853247
# F1 score (macro): 0.6758176618405363

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix Heatmap')
plt.show()

# %%
y_true_bin = label_binarize(y_true, classes=range(10))
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(10):
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_pred_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])


plt.figure(figsize=(10, 8))
for i in range(10):
    plt.plot(fpr[i], tpr[i], label=f'Klasa {i} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Krzywe ROC dla klas')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()
