# %% [markdown]
# # Music Genre Classification using Neural Network

# %%
import pandas as pd
import numpy as np
import platform
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, LeakyReLU, ReLU, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import LearningRateScheduler, EarlyStopping, ModelCheckpoint
from tensorflow.keras.metrics import Precision, Accuracy, AUC, F1Score
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import accuracy_score, precision_score, f1_score, confusion_matrix, roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    try:
        for device in physical_devices:
            tf.config.experimental.set_memory_growth(device, True)
        if tf.test.is_built_with_cuda():
            print(
                f"CUDA is enabled. Using GPU(s) with CUDA: {physical_devices}")
        elif platform.system() == 'Darwin':
            print(
                f"Metal is enabled. Using Metal-enabled GPU on macOS: {physical_devices}")
        else:
            print(
                f"GPU detected but neither CUDA nor Metal is enabled: {physical_devices}")
    except RuntimeError as e:
        print(f"Error enabling GPU acceleration: {e}")
else:
    print("No GPU found. Running on CPU.")
# Out:
# Metal is enabled. Using Metal-enabled GPU on macOS: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Load MFCC data
mfcc_df = pd.read_csv('mfcc_data_gtzan_v2.csv', header=[0, 1, 2], index_col=0)
labels = pd.read_csv('../project_data/tracks.csv')['genre']

# Encode labels
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(labels)

# Drop non-numeric columns
mfcc_df = mfcc_df.drop(columns=['file_name'])

# Flatten multi-index columns and scale features
mfcc_df.columns = ['_'.join(map(str, col)) for col in mfcc_df.columns]
scaler = StandardScaler()
X = scaler.fit_transform(mfcc_df)
# Out:
# /var/folders/42/12p7rrgx3zj15zz7yc0tm30w0000gn/T/ipykernel_38277/2032037441.py:10: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   mfcc_df = mfcc_df.drop(columns=['file_name'])

# %%
mfcc_df.hist(bins=30, figsize=(16, 14), edgecolor='black')
plt.tight_layout()
plt.show()

# %%
y = to_categorical(y, num_classes=10)

# %%
X_train_full, X_test, y_train_full, y_test = train_test_split(
    X, y,
    test_size=0.2,
    stratify=y.argmax(axis=1),
    random_state=42
)

X_train, X_val, y_train, y_val = train_test_split(
    X_train_full, y_train_full,
    test_size=0.2,
    stratify=y_train_full.argmax(axis=1),
    random_state=42
)

# %%
x_train_nan = np.isnan(X_train).sum()  # Liczba NaN w X_train
y_train_nan = np.isnan(y_train).sum()  # Liczba NaN w y_train

print(f"NaN values in X_train: {x_train_nan}")
print(f"NaN values in y_train: {y_train_nan}")
# Out:
# NaN values in X_train: 0
# NaN values in y_train: 0

# %%
def build_and_train_model(X_train, y_train, X_val, y_val,
                          hidden_layers=[64, 32],
                          output_activation='softmax',
                          loss='categorical_crossentropy',
                          optimizer='adam',
                          metrics=['accuracy', Precision(name='precision')],
                          monitor_metric='val_precision',
                          model_path='best_model.h5',
                          epochs=20,
                          batch_size=32,
                          patience=5,
                          dropout=0.2):

    model = Sequential()
    model.add(Input(shape=(X_train.shape[1],)))
    model.add(Dense(hidden_layers[0]))
    model.add(LeakyReLU(negative_slope=0.1))
    for units in hidden_layers[1:]:
        model.add(Dense(units))
        model.add(LeakyReLU(negative_slope=0.1))
        model.add(BatchNormalization())
        model.add(Dropout(dropout)),
    model.add(Dense(10, activation=output_activation))

    model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

    checkpoint = ModelCheckpoint(
        model_path,
        monitor=monitor_metric,
        mode='min',
        save_best_only=True,
        verbose=1
    )

    early_stopping = EarlyStopping(
        monitor=monitor_metric,
        patience=patience,
        mode='min',
        verbose=1,
        restore_best_weights=True
    )

    history = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=epochs,
        batch_size=batch_size,
        callbacks=[checkpoint, early_stopping]
    )

    return model, history
# Out:
# 2025-05-21 15:26:40.143068: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2
# 2025-05-21 15:26:40.143133: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2025-05-21 15:26:40.143142: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1747834000.143201  813514 pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# I0000 00:00:1747834000.143278  813514 pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
model, history = build_and_train_model(
    X_train, y_train,
    X_val, y_val,
    hidden_layers=[256, 128, 64],
    optimizer=Adam(learning_rate=0.0001),
    metrics=[AUC(), F1Score(), 'accuracy', Precision(name='precision')],
    monitor_metric='val_loss',
    model_path='best_model_gtzan_v2.keras',
    epochs=500,
    batch_size=64,
    patience=50,
    dropout=0.45
)
# Out:
# Epoch 1/500
# 2025-05-21 15:26:41.351983: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.0747 - auc: 0.5113 - f1_score: 0.0745 - loss: 3.4015 - precision: 0.0870
# Epoch 1: val_loss improved from inf to 2.32325, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 151ms/step - accuracy: 0.0762 - auc: 0.5118 - f1_score: 0.0759 - loss: 3.3951 - precision: 0.0904 - val_accuracy: 0.1000 - val_auc: 0.5405 - val_f1_score: 0.0815 - val_loss: 2.3232 - val_precision: 0.0000e+00
# Epoch 2/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.1211 - auc: 0.5567 - f1_score: 0.1175 - loss: 3.1726 - precision: 0.1274
# Epoch 2: val_loss improved from 2.32325 to 2.27267, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.1218 - auc: 0.5565 - f1_score: 0.1184 - loss: 3.1745 - precision: 0.1253 - val_accuracy: 0.1625 - val_auc: 0.5844 - val_f1_score: 0.1358 - val_loss: 2.2727 - val_precision: 0.0000e+00
# Epoch 3/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.1293 - auc: 0.5734 - f1_score: 0.1225 - loss: 2.9699 - precision: 0.1487
# Epoch 3: val_loss improved from 2.27267 to 2.22073, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.1320 - auc: 0.5764 - f1_score: 0.1261 - loss: 2.9566 - precision: 0.1523 - val_accuracy: 0.2062 - val_auc: 0.6206 - val_f1_score: 0.1639 - val_loss: 2.2207 - val_precision: 0.0000e+00
# Epoch 4/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.1739 - auc: 0.6216 - f1_score: 0.1706 - loss: 2.7286 - precision: 0.2370
# Epoch 4: val_loss improved from 2.22073 to 2.16936, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.1738 - auc: 0.6201 - f1_score: 0.1716 - loss: 2.7358 - precision: 0.2334 - val_accuracy: 0.2750 - val_auc: 0.6477 - val_f1_score: 0.2105 - val_loss: 2.1694 - val_precision: 0.0000e+00
# Epoch 5/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.1847 - auc: 0.6445 - f1_score: 0.1864 - loss: 2.6398 - precision: 0.2272
# Epoch 5: val_loss improved from 2.16936 to 2.12244, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.1856 - auc: 0.6449 - f1_score: 0.1872 - loss: 2.6367 - precision: 0.2341 - val_accuracy: 0.3125 - val_auc: 0.6718 - val_f1_score: 0.2384 - val_loss: 2.1224 - val_precision: 0.0000e+00
# Epoch 6/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.2156 - auc: 0.6415 - f1_score: 0.2095 - loss: 2.6238 - precision: 0.2448
# Epoch 6: val_loss improved from 2.12244 to 2.07380, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.2200 - auc: 0.6458 - f1_score: 0.2143 - loss: 2.6058 - precision: 0.2540 - val_accuracy: 0.3438 - val_auc: 0.6955 - val_f1_score: 0.2621 - val_loss: 2.0738 - val_precision: 0.0000e+00
# Epoch 7/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.2924 - auc: 0.6932 - f1_score: 0.2892 - loss: 2.4051 - precision: 0.3743
# Epoch 7: val_loss improved from 2.07380 to 2.02594, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.2919 - auc: 0.6949 - f1_score: 0.2891 - loss: 2.3908 - precision: 0.3819 - val_accuracy: 0.3562 - val_auc: 0.7174 - val_f1_score: 0.2766 - val_loss: 2.0259 - val_precision: 0.0000e+00
# Epoch 8/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.2627 - auc: 0.6974 - f1_score: 0.2550 - loss: 2.3549 - precision: 0.4366
# Epoch 8: val_loss improved from 2.02594 to 1.97997, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.2661 - auc: 0.6987 - f1_score: 0.2589 - loss: 2.3494 - precision: 0.4392 - val_accuracy: 0.3750 - val_auc: 0.7361 - val_f1_score: 0.2942 - val_loss: 1.9800 - val_precision: 0.0000e+00
# Epoch 9/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3449 - auc: 0.7304 - f1_score: 0.3395 - loss: 2.2048 - precision: 0.4082
# Epoch 9: val_loss improved from 1.97997 to 1.93385, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.3374 - auc: 0.7294 - f1_score: 0.3319 - loss: 2.2104 - precision: 0.4047 - val_accuracy: 0.3938 - val_auc: 0.7546 - val_f1_score: 0.3161 - val_loss: 1.9339 - val_precision: 1.0000
# Epoch 10/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3099 - auc: 0.7432 - f1_score: 0.3042 - loss: 2.2016 - precision: 0.3902
# Epoch 10: val_loss improved from 1.93385 to 1.88800, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.3087 - auc: 0.7424 - f1_score: 0.3028 - loss: 2.2015 - precision: 0.3912 - val_accuracy: 0.4000 - val_auc: 0.7714 - val_f1_score: 0.3234 - val_loss: 1.8880 - val_precision: 1.0000
# Epoch 11/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3334 - auc: 0.7598 - f1_score: 0.3162 - loss: 2.0846 - precision: 0.4873
# Epoch 11: val_loss improved from 1.88800 to 1.84429, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.3305 - auc: 0.7590 - f1_score: 0.3145 - loss: 2.0883 - precision: 0.4822 - val_accuracy: 0.4062 - val_auc: 0.7887 - val_f1_score: 0.3373 - val_loss: 1.8443 - val_precision: 1.0000
# Epoch 12/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3322 - auc: 0.7632 - f1_score: 0.3234 - loss: 2.0480 - precision: 0.4707
# Epoch 12: val_loss improved from 1.84429 to 1.80095, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.3324 - auc: 0.7624 - f1_score: 0.3236 - loss: 2.0498 - precision: 0.4714 - val_accuracy: 0.4187 - val_auc: 0.8029 - val_f1_score: 0.3505 - val_loss: 1.8010 - val_precision: 1.0000
# Epoch 13/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3839 - auc: 0.7786 - f1_score: 0.3680 - loss: 1.9724 - precision: 0.5336
# Epoch 13: val_loss improved from 1.80095 to 1.75991, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.3764 - auc: 0.7775 - f1_score: 0.3621 - loss: 1.9782 - precision: 0.5242 - val_accuracy: 0.4375 - val_auc: 0.8169 - val_f1_score: 0.3715 - val_loss: 1.7599 - val_precision: 1.0000
# Epoch 14/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3535 - auc: 0.7936 - f1_score: 0.3348 - loss: 1.9097 - precision: 0.5386
# Epoch 14: val_loss improved from 1.75991 to 1.72128, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.3541 - auc: 0.7938 - f1_score: 0.3368 - loss: 1.9053 - precision: 0.5363 - val_accuracy: 0.4375 - val_auc: 0.8272 - val_f1_score: 0.3723 - val_loss: 1.7213 - val_precision: 1.0000
# Epoch 15/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3924 - auc: 0.8006 - f1_score: 0.3823 - loss: 1.8398 - precision: 0.5287
# Epoch 15: val_loss improved from 1.72128 to 1.68192, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.3913 - auc: 0.8000 - f1_score: 0.3815 - loss: 1.8452 - precision: 0.5218 - val_accuracy: 0.4437 - val_auc: 0.8390 - val_f1_score: 0.3767 - val_loss: 1.6819 - val_precision: 0.9500
# Epoch 16/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3724 - auc: 0.7974 - f1_score: 0.3752 - loss: 1.8940 - precision: 0.5068
# Epoch 16: val_loss improved from 1.68192 to 1.64342, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.3781 - auc: 0.7996 - f1_score: 0.3794 - loss: 1.8823 - precision: 0.5096 - val_accuracy: 0.4563 - val_auc: 0.8509 - val_f1_score: 0.3865 - val_loss: 1.6434 - val_precision: 0.9500
# Epoch 17/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3868 - auc: 0.8050 - f1_score: 0.3695 - loss: 1.8420 - precision: 0.4790
# Epoch 17: val_loss improved from 1.64342 to 1.60555, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.3868 - auc: 0.8049 - f1_score: 0.3704 - loss: 1.8430 - precision: 0.4855 - val_accuracy: 0.4750 - val_auc: 0.8595 - val_f1_score: 0.4139 - val_loss: 1.6055 - val_precision: 0.8929
# Epoch 18/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3687 - auc: 0.8099 - f1_score: 0.3578 - loss: 1.8320 - precision: 0.4894
# Epoch 18: val_loss improved from 1.60555 to 1.56896, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.3711 - auc: 0.8116 - f1_score: 0.3613 - loss: 1.8224 - precision: 0.4954 - val_accuracy: 0.4750 - val_auc: 0.8686 - val_f1_score: 0.4184 - val_loss: 1.5690 - val_precision: 0.9062
# Epoch 19/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4219 - auc: 0.8236 - f1_score: 0.4075 - loss: 1.7542 - precision: 0.5890
# Epoch 19: val_loss improved from 1.56896 to 1.53372, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4212 - auc: 0.8230 - f1_score: 0.4080 - loss: 1.7579 - precision: 0.5867 - val_accuracy: 0.4812 - val_auc: 0.8763 - val_f1_score: 0.4231 - val_loss: 1.5337 - val_precision: 0.9091
# Epoch 20/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4070 - auc: 0.8199 - f1_score: 0.3942 - loss: 1.7563 - precision: 0.5745
# Epoch 20: val_loss improved from 1.53372 to 1.50044, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4130 - auc: 0.8222 - f1_score: 0.4009 - loss: 1.7430 - precision: 0.5815 - val_accuracy: 0.4812 - val_auc: 0.8838 - val_f1_score: 0.4258 - val_loss: 1.5004 - val_precision: 0.9118
# Epoch 21/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4790 - auc: 0.8479 - f1_score: 0.4719 - loss: 1.6025 - precision: 0.6249
# Epoch 21: val_loss improved from 1.50044 to 1.46896, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.4721 - auc: 0.8455 - f1_score: 0.4657 - loss: 1.6159 - precision: 0.6177 - val_accuracy: 0.4750 - val_auc: 0.8895 - val_f1_score: 0.4195 - val_loss: 1.4690 - val_precision: 0.9167
# Epoch 22/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4119 - auc: 0.8226 - f1_score: 0.3975 - loss: 1.7451 - precision: 0.5863
# Epoch 22: val_loss improved from 1.46896 to 1.43631, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4133 - auc: 0.8241 - f1_score: 0.4002 - loss: 1.7389 - precision: 0.5890 - val_accuracy: 0.4812 - val_auc: 0.8966 - val_f1_score: 0.4323 - val_loss: 1.4363 - val_precision: 0.9211
# Epoch 23/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4496 - auc: 0.8484 - f1_score: 0.4323 - loss: 1.6031 - precision: 0.6312
# Epoch 23: val_loss improved from 1.43631 to 1.40588, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4473 - auc: 0.8483 - f1_score: 0.4312 - loss: 1.6055 - precision: 0.6294 - val_accuracy: 0.5188 - val_auc: 0.9022 - val_f1_score: 0.4869 - val_loss: 1.4059 - val_precision: 0.8974
# Epoch 24/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4945 - auc: 0.8594 - f1_score: 0.4880 - loss: 1.5649 - precision: 0.6081
# Epoch 24: val_loss improved from 1.40588 to 1.37693, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4950 - auc: 0.8606 - f1_score: 0.4890 - loss: 1.5574 - precision: 0.6135 - val_accuracy: 0.5312 - val_auc: 0.9073 - val_f1_score: 0.5034 - val_loss: 1.3769 - val_precision: 0.9048
# Epoch 25/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4452 - auc: 0.8471 - f1_score: 0.4303 - loss: 1.6259 - precision: 0.5356
# Epoch 25: val_loss improved from 1.37693 to 1.35003, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.4493 - auc: 0.8491 - f1_score: 0.4351 - loss: 1.6151 - precision: 0.5484 - val_accuracy: 0.5312 - val_auc: 0.9117 - val_f1_score: 0.5022 - val_loss: 1.3500 - val_precision: 0.8776
# Epoch 26/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4830 - auc: 0.8715 - f1_score: 0.4704 - loss: 1.4878 - precision: 0.6640
# Epoch 26: val_loss improved from 1.35003 to 1.32230, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4786 - auc: 0.8690 - f1_score: 0.4673 - loss: 1.5024 - precision: 0.6583 - val_accuracy: 0.5312 - val_auc: 0.9167 - val_f1_score: 0.4989 - val_loss: 1.3223 - val_precision: 0.8776
# Epoch 27/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4879 - auc: 0.8740 - f1_score: 0.4796 - loss: 1.4710 - precision: 0.6525
# Epoch 27: val_loss improved from 1.32230 to 1.29662, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4871 - auc: 0.8728 - f1_score: 0.4792 - loss: 1.4775 - precision: 0.6539 - val_accuracy: 0.5500 - val_auc: 0.9208 - val_f1_score: 0.5193 - val_loss: 1.2966 - val_precision: 0.8654
# Epoch 28/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4514 - auc: 0.8551 - f1_score: 0.4415 - loss: 1.5945 - precision: 0.6038
# Epoch 28: val_loss improved from 1.29662 to 1.27295, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.4521 - auc: 0.8561 - f1_score: 0.4436 - loss: 1.5897 - precision: 0.6076 - val_accuracy: 0.5625 - val_auc: 0.9244 - val_f1_score: 0.5363 - val_loss: 1.2729 - val_precision: 0.8545
# Epoch 29/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5330 - auc: 0.8927 - f1_score: 0.5215 - loss: 1.3522 - precision: 0.7139
# Epoch 29: val_loss improved from 1.27295 to 1.25112, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5249 - auc: 0.8908 - f1_score: 0.5135 - loss: 1.3663 - precision: 0.7065 - val_accuracy: 0.5688 - val_auc: 0.9275 - val_f1_score: 0.5425 - val_loss: 1.2511 - val_precision: 0.8421
# Epoch 30/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5219 - auc: 0.8870 - f1_score: 0.5166 - loss: 1.3803 - precision: 0.7374
# Epoch 30: val_loss improved from 1.25112 to 1.22884, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5212 - auc: 0.8865 - f1_score: 0.5150 - loss: 1.3841 - precision: 0.7342 - val_accuracy: 0.5688 - val_auc: 0.9302 - val_f1_score: 0.5436 - val_loss: 1.2288 - val_precision: 0.8500
# Epoch 31/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5147 - auc: 0.8940 - f1_score: 0.4923 - loss: 1.3536 - precision: 0.6888
# Epoch 31: val_loss improved from 1.22884 to 1.20686, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5156 - auc: 0.8931 - f1_score: 0.4954 - loss: 1.3588 - precision: 0.6832 - val_accuracy: 0.5875 - val_auc: 0.9337 - val_f1_score: 0.5639 - val_loss: 1.2069 - val_precision: 0.8387
# Epoch 32/500
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4976 - auc: 0.8734 - f1_score: 0.4821 - loss: 1.4711 - precision: 0.6363
# Epoch 32: val_loss improved from 1.20686 to 1.18712, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.4983 - auc: 0.8741 - f1_score: 0.4855 - loss: 1.4706 - precision: 0.6372 - val_accuracy: 0.6125 - val_auc: 0.9358 - val_f1_score: 0.5931 - val_loss: 1.1871 - val_precision: 0.8413
# Epoch 33/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5305 - auc: 0.8910 - f1_score: 0.5231 - loss: 1.3717 - precision: 0.6861
# Epoch 33: val_loss improved from 1.18712 to 1.17056, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5291 - auc: 0.8915 - f1_score: 0.5218 - loss: 1.3683 - precision: 0.6893 - val_accuracy: 0.6125 - val_auc: 0.9377 - val_f1_score: 0.5947 - val_loss: 1.1706 - val_precision: 0.8438
# Epoch 34/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5253 - auc: 0.8950 - f1_score: 0.5168 - loss: 1.3527 - precision: 0.6975
# Epoch 34: val_loss improved from 1.17056 to 1.15319, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5223 - auc: 0.8944 - f1_score: 0.5147 - loss: 1.3563 - precision: 0.6969 - val_accuracy: 0.6000 - val_auc: 0.9394 - val_f1_score: 0.5797 - val_loss: 1.1532 - val_precision: 0.8529
# Epoch 35/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4831 - auc: 0.8754 - f1_score: 0.4849 - loss: 1.4861 - precision: 0.6300
# Epoch 35: val_loss improved from 1.15319 to 1.13570, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4926 - auc: 0.8781 - f1_score: 0.4933 - loss: 1.4677 - precision: 0.6414 - val_accuracy: 0.6125 - val_auc: 0.9409 - val_f1_score: 0.5921 - val_loss: 1.1357 - val_precision: 0.8571
# Epoch 36/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5414 - auc: 0.8804 - f1_score: 0.5440 - loss: 1.4312 - precision: 0.6822
# Epoch 36: val_loss improved from 1.13570 to 1.11956, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5446 - auc: 0.8839 - f1_score: 0.5462 - loss: 1.4096 - precision: 0.6909 - val_accuracy: 0.6187 - val_auc: 0.9424 - val_f1_score: 0.5984 - val_loss: 1.1196 - val_precision: 0.8611
# Epoch 37/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5300 - auc: 0.8950 - f1_score: 0.5175 - loss: 1.3581 - precision: 0.6978
# Epoch 37: val_loss improved from 1.11956 to 1.10604, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5304 - auc: 0.8939 - f1_score: 0.5193 - loss: 1.3638 - precision: 0.6959 - val_accuracy: 0.6187 - val_auc: 0.9435 - val_f1_score: 0.6001 - val_loss: 1.1060 - val_precision: 0.8514
# Epoch 38/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5280 - auc: 0.9077 - f1_score: 0.5260 - loss: 1.2791 - precision: 0.6912
# Epoch 38: val_loss improved from 1.10604 to 1.09169, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5336 - auc: 0.9080 - f1_score: 0.5318 - loss: 1.2763 - precision: 0.6967 - val_accuracy: 0.6250 - val_auc: 0.9448 - val_f1_score: 0.6085 - val_loss: 1.0917 - val_precision: 0.8533
# Epoch 39/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5100 - auc: 0.8962 - f1_score: 0.5021 - loss: 1.3371 - precision: 0.7121
# Epoch 39: val_loss improved from 1.09169 to 1.07785, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5152 - auc: 0.8967 - f1_score: 0.5079 - loss: 1.3332 - precision: 0.7106 - val_accuracy: 0.6313 - val_auc: 0.9464 - val_f1_score: 0.6176 - val_loss: 1.0779 - val_precision: 0.8571
# Epoch 40/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5557 - auc: 0.9080 - f1_score: 0.5477 - loss: 1.2747 - precision: 0.7320
# Epoch 40: val_loss improved from 1.07785 to 1.06469, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5580 - auc: 0.9090 - f1_score: 0.5502 - loss: 1.2681 - precision: 0.7344 - val_accuracy: 0.6250 - val_auc: 0.9478 - val_f1_score: 0.6117 - val_loss: 1.0647 - val_precision: 0.8608
# Epoch 41/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5518 - auc: 0.9145 - f1_score: 0.5452 - loss: 1.2270 - precision: 0.7265
# Epoch 41: val_loss improved from 1.06469 to 1.05431, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5542 - auc: 0.9138 - f1_score: 0.5483 - loss: 1.2314 - precision: 0.7239 - val_accuracy: 0.6438 - val_auc: 0.9486 - val_f1_score: 0.6350 - val_loss: 1.0543 - val_precision: 0.8625
# Epoch 42/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5616 - auc: 0.9066 - f1_score: 0.5533 - loss: 1.2691 - precision: 0.7784
# Epoch 42: val_loss improved from 1.05431 to 1.04168, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5614 - auc: 0.9072 - f1_score: 0.5531 - loss: 1.2663 - precision: 0.7751 - val_accuracy: 0.6438 - val_auc: 0.9498 - val_f1_score: 0.6337 - val_loss: 1.0417 - val_precision: 0.8608
# Epoch 43/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5835 - auc: 0.9074 - f1_score: 0.5699 - loss: 1.2633 - precision: 0.6924
# Epoch 43: val_loss improved from 1.04168 to 1.02857, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5830 - auc: 0.9088 - f1_score: 0.5703 - loss: 1.2551 - precision: 0.6941 - val_accuracy: 0.6500 - val_auc: 0.9517 - val_f1_score: 0.6383 - val_loss: 1.0286 - val_precision: 0.8519
# Epoch 44/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5533 - auc: 0.9051 - f1_score: 0.5481 - loss: 1.2711 - precision: 0.7111
# Epoch 44: val_loss improved from 1.02857 to 1.01542, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5597 - auc: 0.9068 - f1_score: 0.5550 - loss: 1.2600 - precision: 0.7159 - val_accuracy: 0.6500 - val_auc: 0.9533 - val_f1_score: 0.6383 - val_loss: 1.0154 - val_precision: 0.8519
# Epoch 45/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5873 - auc: 0.9178 - f1_score: 0.5777 - loss: 1.2012 - precision: 0.7308
# Epoch 45: val_loss improved from 1.01542 to 1.00440, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5867 - auc: 0.9181 - f1_score: 0.5780 - loss: 1.1989 - precision: 0.7327 - val_accuracy: 0.6500 - val_auc: 0.9545 - val_f1_score: 0.6420 - val_loss: 1.0044 - val_precision: 0.8434
# Epoch 46/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5275 - auc: 0.9109 - f1_score: 0.5138 - loss: 1.2544 - precision: 0.6957
# Epoch 46: val_loss improved from 1.00440 to 0.99557, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5408 - auc: 0.9139 - f1_score: 0.5285 - loss: 1.2330 - precision: 0.7067 - val_accuracy: 0.6500 - val_auc: 0.9554 - val_f1_score: 0.6420 - val_loss: 0.9956 - val_precision: 0.8452
# Epoch 47/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6168 - auc: 0.9132 - f1_score: 0.6129 - loss: 1.2207 - precision: 0.7199
# Epoch 47: val_loss improved from 0.99557 to 0.98701, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6139 - auc: 0.9139 - f1_score: 0.6102 - loss: 1.2171 - precision: 0.7227 - val_accuracy: 0.6625 - val_auc: 0.9561 - val_f1_score: 0.6576 - val_loss: 0.9870 - val_precision: 0.8554
# Epoch 48/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6359 - auc: 0.9323 - f1_score: 0.6233 - loss: 1.0928 - precision: 0.7627
# Epoch 48: val_loss improved from 0.98701 to 0.97860, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.6319 - auc: 0.9302 - f1_score: 0.6207 - loss: 1.1079 - precision: 0.7577 - val_accuracy: 0.6750 - val_auc: 0.9564 - val_f1_score: 0.6696 - val_loss: 0.9786 - val_precision: 0.8488
# Epoch 49/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6669 - auc: 0.9437 - f1_score: 0.6638 - loss: 1.0060 - precision: 0.8042
# Epoch 49: val_loss improved from 0.97860 to 0.97090, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6617 - auc: 0.9424 - f1_score: 0.6586 - loss: 1.0176 - precision: 0.7972 - val_accuracy: 0.6750 - val_auc: 0.9570 - val_f1_score: 0.6675 - val_loss: 0.9709 - val_precision: 0.8523
# Epoch 50/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6071 - auc: 0.9243 - f1_score: 0.6017 - loss: 1.1471 - precision: 0.7697
# Epoch 50: val_loss improved from 0.97090 to 0.96238, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6120 - auc: 0.9258 - f1_score: 0.6071 - loss: 1.1360 - precision: 0.7761 - val_accuracy: 0.6812 - val_auc: 0.9580 - val_f1_score: 0.6743 - val_loss: 0.9624 - val_precision: 0.8523
# Epoch 51/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6050 - auc: 0.9224 - f1_score: 0.5973 - loss: 1.1588 - precision: 0.7821
# Epoch 51: val_loss improved from 0.96238 to 0.95580, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6046 - auc: 0.9227 - f1_score: 0.5973 - loss: 1.1572 - precision: 0.7828 - val_accuracy: 0.6812 - val_auc: 0.9583 - val_f1_score: 0.6747 - val_loss: 0.9558 - val_precision: 0.8556
# Epoch 52/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6208 - auc: 0.9298 - f1_score: 0.6118 - loss: 1.1091 - precision: 0.7763
# Epoch 52: val_loss improved from 0.95580 to 0.94633, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6212 - auc: 0.9302 - f1_score: 0.6126 - loss: 1.1067 - precision: 0.7768 - val_accuracy: 0.6875 - val_auc: 0.9590 - val_f1_score: 0.6813 - val_loss: 0.9463 - val_precision: 0.8587
# Epoch 53/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6369 - auc: 0.9400 - f1_score: 0.6244 - loss: 1.0370 - precision: 0.7842
# Epoch 53: val_loss improved from 0.94633 to 0.93954, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6340 - auc: 0.9398 - f1_score: 0.6228 - loss: 1.0392 - precision: 0.7856 - val_accuracy: 0.6875 - val_auc: 0.9592 - val_f1_score: 0.6815 - val_loss: 0.9395 - val_precision: 0.8602
# Epoch 54/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6124 - auc: 0.9234 - f1_score: 0.6072 - loss: 1.1521 - precision: 0.7296
# Epoch 54: val_loss improved from 0.93954 to 0.93300, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6137 - auc: 0.9242 - f1_score: 0.6088 - loss: 1.1478 - precision: 0.7336 - val_accuracy: 0.6938 - val_auc: 0.9595 - val_f1_score: 0.6877 - val_loss: 0.9330 - val_precision: 0.8511
# Epoch 55/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6120 - auc: 0.9284 - f1_score: 0.6073 - loss: 1.1459 - precision: 0.7595
# Epoch 55: val_loss improved from 0.93300 to 0.92264, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6171 - auc: 0.9293 - f1_score: 0.6125 - loss: 1.1353 - precision: 0.7660 - val_accuracy: 0.7000 - val_auc: 0.9604 - val_f1_score: 0.6923 - val_loss: 0.9226 - val_precision: 0.8526
# Epoch 56/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6474 - auc: 0.9431 - f1_score: 0.6390 - loss: 1.0190 - precision: 0.7527
# Epoch 56: val_loss improved from 0.92264 to 0.91475, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6447 - auc: 0.9421 - f1_score: 0.6375 - loss: 1.0262 - precision: 0.7494 - val_accuracy: 0.7000 - val_auc: 0.9611 - val_f1_score: 0.6923 - val_loss: 0.9147 - val_precision: 0.8557
# Epoch 57/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5981 - auc: 0.9260 - f1_score: 0.5894 - loss: 1.1382 - precision: 0.7144
# Epoch 57: val_loss improved from 0.91475 to 0.90858, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5983 - auc: 0.9269 - f1_score: 0.5911 - loss: 1.1322 - precision: 0.7176 - val_accuracy: 0.6938 - val_auc: 0.9617 - val_f1_score: 0.6868 - val_loss: 0.9086 - val_precision: 0.8557
# Epoch 58/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6229 - auc: 0.9283 - f1_score: 0.6216 - loss: 1.1045 - precision: 0.7647
# Epoch 58: val_loss improved from 0.90858 to 0.90335, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6266 - auc: 0.9301 - f1_score: 0.6253 - loss: 1.0940 - precision: 0.7646 - val_accuracy: 0.7000 - val_auc: 0.9619 - val_f1_score: 0.6929 - val_loss: 0.9034 - val_precision: 0.8454
# Epoch 59/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6972 - auc: 0.9540 - f1_score: 0.6954 - loss: 0.9266 - precision: 0.8415
# Epoch 59: val_loss improved from 0.90335 to 0.89509, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6925 - auc: 0.9525 - f1_score: 0.6909 - loss: 0.9382 - precision: 0.8354 - val_accuracy: 0.7063 - val_auc: 0.9628 - val_f1_score: 0.6994 - val_loss: 0.8951 - val_precision: 0.8542
# Epoch 60/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6042 - auc: 0.9368 - f1_score: 0.6005 - loss: 1.0580 - precision: 0.7641
# Epoch 60: val_loss improved from 0.89509 to 0.89090, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6116 - auc: 0.9377 - f1_score: 0.6081 - loss: 1.0506 - precision: 0.7700 - val_accuracy: 0.7063 - val_auc: 0.9631 - val_f1_score: 0.6980 - val_loss: 0.8909 - val_precision: 0.8485
# Epoch 61/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6388 - auc: 0.9355 - f1_score: 0.6342 - loss: 1.0593 - precision: 0.7938
# Epoch 61: val_loss improved from 0.89090 to 0.88626, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6416 - auc: 0.9372 - f1_score: 0.6374 - loss: 1.0474 - precision: 0.7959 - val_accuracy: 0.7063 - val_auc: 0.9632 - val_f1_score: 0.6975 - val_loss: 0.8863 - val_precision: 0.8431
# Epoch 62/500
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6620 - auc: 0.9480 - f1_score: 0.6544 - loss: 0.9730 - precision: 0.7744
# Epoch 62: val_loss improved from 0.88626 to 0.88208, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6678 - auc: 0.9483 - f1_score: 0.6621 - loss: 0.9664 - precision: 0.7901 - val_accuracy: 0.7000 - val_auc: 0.9630 - val_f1_score: 0.6933 - val_loss: 0.8821 - val_precision: 0.8431
# Epoch 63/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6792 - auc: 0.9473 - f1_score: 0.6774 - loss: 0.9642 - precision: 0.7839
# Epoch 63: val_loss improved from 0.88208 to 0.88171, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6783 - auc: 0.9474 - f1_score: 0.6767 - loss: 0.9648 - precision: 0.7862 - val_accuracy: 0.7125 - val_auc: 0.9629 - val_f1_score: 0.7047 - val_loss: 0.8817 - val_precision: 0.8462
# Epoch 64/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6355 - auc: 0.9488 - f1_score: 0.6342 - loss: 0.9646 - precision: 0.7789
# Epoch 64: val_loss improved from 0.88171 to 0.87877, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6332 - auc: 0.9469 - f1_score: 0.6319 - loss: 0.9784 - precision: 0.7787 - val_accuracy: 0.7125 - val_auc: 0.9631 - val_f1_score: 0.7047 - val_loss: 0.8788 - val_precision: 0.8431
# Epoch 65/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6544 - auc: 0.9454 - f1_score: 0.6446 - loss: 0.9831 - precision: 0.8015
# Epoch 65: val_loss improved from 0.87877 to 0.87205, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6578 - auc: 0.9459 - f1_score: 0.6496 - loss: 0.9794 - precision: 0.8035 - val_accuracy: 0.7188 - val_auc: 0.9638 - val_f1_score: 0.7104 - val_loss: 0.8720 - val_precision: 0.8614
# Epoch 66/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6701 - auc: 0.9409 - f1_score: 0.6560 - loss: 1.0120 - precision: 0.8109
# Epoch 66: val_loss improved from 0.87205 to 0.86457, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6732 - auc: 0.9422 - f1_score: 0.6611 - loss: 1.0023 - precision: 0.8102 - val_accuracy: 0.7250 - val_auc: 0.9643 - val_f1_score: 0.7151 - val_loss: 0.8646 - val_precision: 0.8641
# Epoch 67/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6792 - auc: 0.9506 - f1_score: 0.6701 - loss: 0.9435 - precision: 0.8017
# Epoch 67: val_loss improved from 0.86457 to 0.85651, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6781 - auc: 0.9506 - f1_score: 0.6701 - loss: 0.9448 - precision: 0.8048 - val_accuracy: 0.7250 - val_auc: 0.9649 - val_f1_score: 0.7157 - val_loss: 0.8565 - val_precision: 0.8585
# Epoch 68/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6852 - auc: 0.9486 - f1_score: 0.6831 - loss: 0.9615 - precision: 0.8101
# Epoch 68: val_loss improved from 0.85651 to 0.84948, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6849 - auc: 0.9489 - f1_score: 0.6831 - loss: 0.9592 - precision: 0.8094 - val_accuracy: 0.7250 - val_auc: 0.9655 - val_f1_score: 0.7146 - val_loss: 0.8495 - val_precision: 0.8598
# Epoch 69/500
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7091 - auc: 0.9626 - f1_score: 0.7031 - loss: 0.8379 - precision: 0.8776
# Epoch 69: val_loss improved from 0.84948 to 0.84087, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.7030 - auc: 0.9596 - f1_score: 0.6985 - loss: 0.8645 - precision: 0.8631 - val_accuracy: 0.7250 - val_auc: 0.9660 - val_f1_score: 0.7146 - val_loss: 0.8409 - val_precision: 0.8692
# Epoch 70/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6904 - auc: 0.9480 - f1_score: 0.6834 - loss: 0.9454 - precision: 0.8170
# Epoch 70: val_loss improved from 0.84087 to 0.83408, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6904 - auc: 0.9488 - f1_score: 0.6842 - loss: 0.9419 - precision: 0.8160 - val_accuracy: 0.7188 - val_auc: 0.9668 - val_f1_score: 0.7091 - val_loss: 0.8341 - val_precision: 0.8692
# Epoch 71/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6568 - auc: 0.9465 - f1_score: 0.6514 - loss: 0.9833 - precision: 0.7573
# Epoch 71: val_loss improved from 0.83408 to 0.82757, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6617 - auc: 0.9475 - f1_score: 0.6570 - loss: 0.9745 - precision: 0.7647 - val_accuracy: 0.7250 - val_auc: 0.9672 - val_f1_score: 0.7156 - val_loss: 0.8276 - val_precision: 0.8692
# Epoch 72/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.
saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7282 - auc: 0.9656 - f1_score: 0.7290 - loss: 0.7963 - precision: 0.8514 - val_accuracy: 0.7437 - val_auc: 0.9695 - val_f1_score: 0.7367 - val_loss: 0.7764 - val_precision: 0.8522
# Epoch 89/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7355 - auc: 0.9652 - f1_score: 0.7305 - loss: 0.7992 - precision: 0.8581
# Epoch 89: val_loss improved from 0.77644 to 0.77378, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.7349 - auc: 0.9651 - f1_score: 0.7301 - loss: 0.8001 - precision: 0.8572 - val_accuracy: 0.7500 - val_auc: 0.9699 - val_f1_score: 0.7435 - val_loss: 0.7738 - val_precision: 0.8462
# Epoch 90/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7589 - auc: 0.9690 - f1_score: 0.7576 - loss: 0.7593 - precision: 0.8496
# Epoch 90: val_loss improved from 0.77378 to 0.77112, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.7580 - auc: 0.9688 - f1_score: 0.7569 - loss: 0.7613 - precision: 0.8493 - val_accuracy: 0.7500 - val_auc: 0.9701 - val_f1_score: 0.7435 - val_loss: 0.7711 - val_precision: 0.8462
# Epoch 91/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7629 - auc: 0.9710 - f1_score: 0.7578 - loss: 0.7366 - precision: 0.8766
# Epoch 91: val_loss improved from 0.77112 to 0.76843, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.7617 - auc: 0.9709 - f1_score: 0.7571 - loss: 0.7380 - precision: 0.8759 - val_accuracy: 0.7500 - val_auc: 0.9699 - val_f1_score: 0.7435 - val_loss: 0.7684 - val_precision: 0.8547
# Epoch 92/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7221 - auc: 0.9622 - f1_score: 0.7239 - loss: 0.8222 - precision: 0.8308
# Epoch 92: val_loss improved from 0.76843 to 0.76653, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7245 - auc: 0.9632 - f1_score: 0.7258 - loss: 0.8128 - precision: 0.8313 - val_accuracy: 0.7500 - val_auc: 0.9704 - val_f1_score: 0.7435 - val_loss: 0.7665 - val_precision: 0.8559
# Epoch 93/500
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7555 - auc: 0.9712 - f1_score: 0.7486 - loss: 0.7403 - precision: 0.8355
# Epoch 93: val_loss improved from 0.76653 to 0.76168, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7556 - auc: 0.9716 - f1_score: 0.7512 - loss: 0.7355 - precision: 0.8421 - val_accuracy: 0.7500 - val_auc: 0.9705 - val_f1_score: 0.7435 - val_loss: 0.7617 - val_precision: 0.8547
# Epoch 94/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7733 - auc: 0.9623 - f1_score: 0.7705 - loss: 0.7857 - precision: 0.8735
# Epoch 94: val_loss improved from 0.76168 to 0.75873, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.7660 - auc: 0.9638 - f1_score: 0.7633 - loss: 0.7788 - precision: 0.8714 - val_accuracy: 0.7563 - val_auc: 0.9708 - val_f1_score: 0.7489 - val_loss: 0.7587 - val_precision: 0.8559
# Epoch 95/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7561 - auc: 0.9696 - f1_score: 0.7538 - loss: 0.7542 - precision: 0.8208
# Epoch 95: val_loss improved from 0.75873 to 0.75790, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7545 - auc: 0.9695 - f1_score: 0.7524 - loss: 0.7555 - precision: 0.8220 - val_accuracy: 0.7750 - val_auc: 0.9711 - val_f1_score: 0.7666 - val_loss: 0.7579 - val_precision: 0.8571
# Epoch 96/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7731 - auc: 0.9734 - f1_score: 0.7749 - loss: 0.7124 - precision: 0.8630
# Epoch 96: val_loss improved from 0.75790 to 0.75790, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7743 - auc: 0.9736 - f1_score: 0.7758 - loss: 0.7106 - precision: 0.8647 - val_accuracy: 0.7750 - val_auc: 0.9709 - val_f1_score: 0.7666 - val_loss: 0.7579 - val_precision: 0.8525
# Epoch 97/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7763 - auc: 0.9686 - f1_score: 0.7713 - loss: 0.7410 - precision: 0.8516
# Epoch 97: val_loss improved from 0.75790 to 0.75750, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.7717 - auc: 0.9677 - f1_score: 0.7676 - loss: 0.7513 - precision: 0.8505 - val_accuracy: 0.7688 - val_auc: 0.9707 - val_f1_score: 0.7611 - val_loss: 0.7575 - val_precision: 0.8512
# Epoch 98/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7437 - auc: 0.9762 - f1_score: 0.7407 - loss: 0.6802 - precision: 0.8822
# Epoch 98: val_loss improved from 0.75750 to 0.75700, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.7462 - auc: 0.9759 - f1_score: 0.7437 - loss: 0.6840 - precision: 0.8807 - val_accuracy: 0.7625 - val_auc: 0.9712 - val_f1_score: 0.7557 - val_loss: 0.7570 - val_precision: 0.8500
# Epoch 99/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7618 - auc: 0.9696 - f1_score: 0.7591 - loss: 0.7500 - precision: 0.8743
# Epoch 99: val_loss improved from 0.75700 to 0.75582, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7629 - auc: 0.9703 - f1_score: 0.7606 - loss: 0.7432 - precision: 0.8732 - val_accuracy: 0.7563 - val_auc: 0.9710 - val_f1_score: 0.7502 - val_loss: 0.7558 - val_precision: 0.8443
# Epoch 100/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7567 - auc: 0.9698 - f1_score: 0.7468 - loss: 0.7413 - precision: 0.8504
# Epoch 100: val_loss improved from 0.75582 to 0.75322, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7579 - auc: 0.9698 - f1_score: 0.7505 - loss: 0.7406 - precision: 0.8511 - val_accuracy: 0.7500 - val_auc: 0.9713 - val_f1_score: 0.7444 - val_loss: 0.7532 - val_precision: 0.8361
# Epoch 101/500
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7667 - auc: 0.9811 - f1_score: 0.7649 - loss: 0.6435 - precision: 0.8819
# Epoch 101: val_loss improved from 0.75322 to 0.74990, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7731 - auc: 0.9799 - f1_score: 0.7719 - loss: 0.6545 - precision: 0.8783 - val_accuracy: 0.7563 - val_auc: 0.9715 - val_f1_score: 0.7498 - val_loss: 0.7499 - val_precision: 0.8320
# Epoch 102/500
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7708 - auc: 0.9780 - f1_score: 0.7652 - loss: 0.6629 - precision: 0.8823
# Epoch 102: val_loss improved from 0.74990 to 0.74833, saving model to best_model_gtzan_v2.keras
# ...
# Epoch 191/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9212 - auc: 0.9935 - f1_score: 0.9181 - loss: 0.3301 - precision: 0.9493
# Epoch 191: val_loss did not improve from 0.68197
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9176 - auc: 0.9934 - f1_score: 0.9150 - loss: 0.3357 - precision: 0.9483 - val_accuracy: 0.7437 - val_auc: 0.9719 - val_f1_score: 0.7418 - val_loss: 0.7068 - val_precision: 0.8129
# Epoch 192/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8691 - auc: 0.9926 - f1_score: 0.8599 - loss: 0.3953 - precision: 0.9371
# Epoch 192: val_loss did not improve from 0.68197
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8697 - auc: 0.9927 - f1_score: 0.8613 - loss: 0.3943 - precision: 0.9366 - val_accuracy: 0.7563 - val_auc: 0.9718 - val_f1_score: 0.7519 - val_loss: 0.7057 - val_precision: 0.8227
# Epoch 193/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8798 - auc: 0.9937 - f1_score: 0.8794 - loss: 0.3701 - precision: 0.9430
# Epoch 193: val_loss did not improve from 0.68197
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.
val_loss did not improve from 0.68197
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9333 - auc: 0.9966 - f1_score: 0.9311 - loss: 0.2935 - precision: 0.9600 - val_accuracy: 0.7688 - val_auc: 0.9703 - val_f1_score: 0.7661 - val_loss: 0.7133 - val_precision: 0.8000
# Epoch 222/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9463 - auc: 0.9983 - f1_score: 0.9438 - loss: 0.2411 - precision: 0.9688
# Epoch 222: val_loss did not improve from 0.68197
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9441 - auc: 0.9981 - f1_score: 0.9418 - loss: 0.2449 - precision: 0.9672 - val_accuracy: 0.7500 - val_auc: 0.9700 - val_f1_score: 0.7498 - val_loss: 0.7159 - val_precision: 0.7986
# Epoch 223/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9301 - auc: 0.9979 - f1_score: 0.9295 - loss: 0.2678 - precision: 0.9702
# Epoch 223: val_loss did not improve from 0.68197
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9287 - auc: 0.9978 - f1_score: 0.9283 - loss: 0.2698 - precision: 0.9689 - val_accuracy: 0.7688 - val_auc: 0.9699 - val_f1_score: 0.7658 - val_loss: 0.7204 - val_precision: 0.7929
# Epoch 224/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9482 - auc: 0.9981 - f1_score: 0.9470 - loss: 0.2491 - precision: 0.9713
# Epoch 224: val_loss did not improve from 0.68197
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9449 - auc: 0.9980 - f1_score: 0.9440 - loss: 0.2528 - precision: 0.9700 - val_accuracy: 0.7688 - val_auc: 0.9697 - val_f1_score: 0.7658 - val_loss: 0.7222 - val_precision: 0.7832
# Epoch 225/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9435 - auc: 0.9964 - f1_score: 0.9433 - loss: 0.2837 - precision: 0.9692
# Epoch 225: val_loss did not improve from 0.68197
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9379 - auc: 0.9961 - f1_score: 0.9378 - loss: 0.2873 - precision: 0.9674 - val_accuracy: 0.7688 - val_auc: 0.9697 - val_f1_score: 0.7658 - val_loss: 0.7229 - val_precision: 0.7847
# Epoch 226/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9137 - auc: 0.9975 - f1_score: 0.9132 - loss: 0.2925 - precision: 0.9745
# Epoch 226: val_loss did not improve from 0.68197
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9140 - auc: 0.9974 - f1_score: 0.9135 - loss: 0.2923 - precision: 0.9744 - val_accuracy: 0.7688 - val_auc: 0.9697 - val_f1_score: 0.7658 - val_loss: 0.7257 - val_precision: 0.7902
# Epoch 227/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9272 - auc: 0.9974 - f1_score: 0.9258 - loss: 0.2844 - precision: 0.9578
# Epoch 227: val_loss did not improve from 0.68197
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9270 - auc: 0.9974 - f1_score: 0.9257 - loss: 0.2832 - precision: 0.9568 - val_accuracy: 0.7812 - val_auc: 0.9694 - val_f1_score: 0.7798 - val_loss: 0.7282 - val_precision: 0.7958
# Epoch 227: early stopping
# Restoring model weights from the end of the best epoch: 177.

# %%
plt.figure(figsize=(20, 6))

# Plot training and validation accuracy
plt.subplot(1, 3, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot training and validation loss
plt.subplot(1, 3, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 3, 3)
plt.plot(history.history['precision'], label='Training Precision')
plt.plot(history.history['val_precision'], label='Validation Precision')
plt.title('Precision over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
y_pred_probs = model.predict(X_test)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = np.argmax(y_test, axis=1) if y_test.ndim > 1 else y_test

accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred, average='macro', zero_division=0)
f1 = f1_score(y_true, y_pred, average='macro')
conf_matrix = confusion_matrix(y_true, y_pred)

print("Dokładność:", accuracy)
print("Precyzja (macro):", precision)
print("F1 score (macro):", f1)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step
# Dokładność: 0.78
# Precyzja (macro): 0.7871147128846685
# F1 score (macro): 0.7800962944795228

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix Heatmap')
plt.show()

# %%
y_true_bin = label_binarize(y_true, classes=range(10))
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(10):
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_pred_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])


plt.figure(figsize=(10, 8))
for i in range(10):
    plt.plot(fpr[i], tpr[i], label=f'Klasa {i} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Krzywe ROC dla klas')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()
