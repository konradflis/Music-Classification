# %% [markdown]
# # Music Genre Classification using Neural Network

# %%
import pandas as pd
import numpy as np
import platform
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, LeakyReLU, ReLU, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import LearningRateScheduler, EarlyStopping, ModelCheckpoint
from tensorflow.keras.metrics import Precision, Accuracy, AUC, F1Score
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import accuracy_score, precision_score, f1_score, confusion_matrix, roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    try:
        for device in physical_devices:
            tf.config.experimental.set_memory_growth(device, True)
        if tf.test.is_built_with_cuda():
            print(
                f"CUDA is enabled. Using GPU(s) with CUDA: {physical_devices}")
        elif platform.system() == 'Darwin':
            print(
                f"Metal is enabled. Using Metal-enabled GPU on macOS: {physical_devices}")
        else:
            print(
                f"GPU detected but neither CUDA nor Metal is enabled: {physical_devices}")
    except RuntimeError as e:
        print(f"Error enabling GPU acceleration: {e}")
else:
    print("No GPU found. Running on CPU.")
# Out:
# Metal is enabled. Using Metal-enabled GPU on macOS: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Load MFCC data
mfcc_df = pd.read_csv('mfcc_data_gtzan_v2.csv', header=[0, 1, 2], index_col=0)
labels = pd.read_csv('../project_data/tracks.csv')['genre']

# Encode labels
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(labels)

# Drop non-numeric columns
mfcc_df = mfcc_df.drop(columns=['file_name'])

# Flatten multi-index columns and scale features
mfcc_df.columns = ['_'.join(map(str, col)) for col in mfcc_df.columns]
scaler = StandardScaler()
X = scaler.fit_transform(mfcc_df)
# Out:
# /var/folders/42/12p7rrgx3zj15zz7yc0tm30w0000gn/T/ipykernel_24737/2032037441.py:10: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   mfcc_df = mfcc_df.drop(columns=['file_name'])

# %%
mfcc_df.hist(bins=30, figsize=(16, 14), edgecolor='black')
plt.tight_layout()
plt.show()

# %%
y = to_categorical(y, num_classes=10)

# %%
X_train_full, X_test, y_train_full, y_test = train_test_split(
    X, y,
    test_size=0.2,
    stratify=y.argmax(axis=1),
    random_state=42
)

X_train, X_val, y_train, y_val = train_test_split(
    X_train_full, y_train_full,
    test_size=0.2,
    stratify=y_train_full.argmax(axis=1),
    random_state=42
)

# %%
x_train_nan = np.isnan(X_train).sum()  # Liczba NaN w X_train
y_train_nan = np.isnan(y_train).sum()  # Liczba NaN w y_train

print(f"NaN values in X_train: {x_train_nan}")
print(f"NaN values in y_train: {y_train_nan}")
# Out:
# NaN values in X_train: 0
# NaN values in y_train: 0

# %%
def build_and_train_model(X_train, y_train, X_val, y_val,
                          hidden_layers=[64, 32],
                          output_activation='softmax',
                          loss='categorical_crossentropy',
                          optimizer='adam',
                          metrics=['accuracy', Precision(name='precision')],
                          monitor_metric='val_precision',
                          model_path='best_model.h5',
                          epochs=20,
                          batch_size=32,
                          patience=5,
                          dropout=0.2):

    model = Sequential()
    model.add(Input(shape=(X_train.shape[1],)))
    model.add(Dense(hidden_layers[0]))
    model.add(LeakyReLU(negative_slope=0.1))
    for units in hidden_layers[1:]:
        model.add(Dense(units))
        model.add(LeakyReLU(negative_slope=0.1))
        model.add(BatchNormalization())
        model.add(Dropout(dropout)),
    model.add(Dense(10, activation=output_activation))

    model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

    checkpoint = ModelCheckpoint(
        model_path,
        monitor=monitor_metric,
        mode='min',
        save_best_only=True,
        verbose=1
    )

    early_stopping = EarlyStopping(
        monitor=monitor_metric,
        patience=patience,
        mode='min',
        verbose=1,
        restore_best_weights=True
    )

    history = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=epochs,
        batch_size=batch_size,
        callbacks=[checkpoint, early_stopping]
    )

    return model, history
# Out:
# 2025-05-14 22:12:18.222623: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2
# 2025-05-14 22:12:18.222840: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2025-05-14 22:12:18.222847: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1747253538.223457 12882298 pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# I0000 00:00:1747253538.223950 12882298 pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
model, history = build_and_train_model(
    X_train, y_train,
    X_val, y_val,
    hidden_layers=[256, 128, 64],
    optimizer=Adam(learning_rate=0.0001),
    metrics=[AUC(), F1Score(), 'accuracy', Precision(name='precision')],
    monitor_metric='val_loss',
    model_path='best_model_gtzan_v2.keras',
    epochs=500,
    batch_size=64,
    patience=50,
    dropout=0.45
)
# Out:
# Epoch 1/500
# 2025-05-14 22:12:29.879040: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.0990 - auc: 0.5004 - f1_score: 0.0979 - loss: 3.5986 - precision: 0.1068
# Epoch 1: val_loss improved from inf to 2.33253, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - accuracy: 0.0996 - auc: 0.5009 - f1_score: 0.0987 - loss: 3.5948 - precision: 0.1052 - val_accuracy: 0.0875 - val_auc: 0.5061 - val_f1_score: 0.0495 - val_loss: 2.3325 - val_precision: 0.0000e+00
# Epoch 2/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1317 - auc: 0.5491 - f1_score: 0.1276 - loss: 3.2936 - precision: 0.1143
# Epoch 2: val_loss improved from 2.33253 to 2.26886, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.1348 - auc: 0.5478 - f1_score: 0.1314 - loss: 3.2832 - precision: 0.1279 - val_accuracy: 0.1437 - val_auc: 0.5700 - val_f1_score: 0.1096 - val_loss: 2.2689 - val_precision: 0.0000e+00
# Epoch 3/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.1347 - auc: 0.5782 - f1_score: 0.1292 - loss: 3.0586 - precision: 0.1642
# Epoch 3: val_loss improved from 2.26886 to 2.20657, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.1390 - auc: 0.5819 - f1_score: 0.1337 - loss: 3.0445 - precision: 0.1742 - val_accuracy: 0.2000 - val_auc: 0.6300 - val_f1_score: 0.1527 - val_loss: 2.2066 - val_precision: 0.0000e+00
# Epoch 4/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1945 - auc: 0.6251 - f1_score: 0.1847 - loss: 2.8244 - precision: 0.2529
# Epoch 4: val_loss improved from 2.20657 to 2.15049, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.1939 - auc: 0.6251 - f1_score: 0.1854 - loss: 2.8298 - precision: 0.2522 - val_accuracy: 0.2688 - val_auc: 0.6748 - val_f1_score: 0.2125 - val_loss: 2.1505 - val_precision: 0.0000e+00
# Epoch 5/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.1883 - auc: 0.6424 - f1_score: 0.1769 - loss: 2.7575 - precision: 0.2494
# Epoch 5: val_loss improved from 2.15049 to 2.10231, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.1887 - auc: 0.6428 - f1_score: 0.1776 - loss: 2.7550 - precision: 0.2503 - val_accuracy: 0.3063 - val_auc: 0.7069 - val_f1_score: 0.2448 - val_loss: 2.1023 - val_precision: 1.0000
# Epoch 6/500
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.2540 - auc: 0.6583 - f1_score: 0.2396 - loss: 2.7198 - precision: 0.3024
# Epoch 6: val_loss improved from 2.10231 to 2.05790, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.2554 - auc: 0.6691 - f1_score: 0.2419 - loss: 2.6508 - precision: 0.3213 - val_accuracy: 0.3187 - val_auc: 0.7289 - val_f1_score: 0.2588 - val_loss: 2.0579 - val_precision: 1.0000
# Epoch 7/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.2867 - auc: 0.7015 - f1_score: 0.2694 - loss: 2.4393 - precision: 0.3868
# Epoch 7: val_loss improved from 2.05790 to 2.01818, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.2874 - auc: 0.7019 - f1_score: 0.2706 - loss: 2.4373 - precision: 0.3878 - val_accuracy: 0.3250 - val_auc: 0.7469 - val_f1_score: 0.2485 - val_loss: 2.0182 - val_precision: 1.0000
# Epoch 8/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3035 - auc: 0.7084 - f1_score: 0.2957 - loss: 2.3884 - precision: 0.4093
# Epoch 8: val_loss improved from 2.01818 to 1.98007, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.3021 - auc: 0.7087 - f1_score: 0.2943 - loss: 2.3874 - precision: 0.4114 - val_accuracy: 0.3375 - val_auc: 0.7624 - val_f1_score: 0.2594 - val_loss: 1.9801 - val_precision: 1.0000
# Epoch 9/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3013 - auc: 0.7434 - f1_score: 0.2790 - loss: 2.2067 - precision: 0.4154
# Epoch 9: val_loss improved from 1.98007 to 1.94156, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.3006 - auc: 0.7420 - f1_score: 0.2797 - loss: 2.2129 - precision: 0.4161 - val_accuracy: 0.3375 - val_auc: 0.7756 - val_f1_score: 0.2523 - val_loss: 1.9416 - val_precision: 1.0000
# Epoch 10/500
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.3163 - auc: 0.7324 - f1_score: 0.3030 - loss: 2.2828 - precision: 0.3991
# Epoch 10: val_loss improved from 1.94156 to 1.90590, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.3194 - auc: 0.7347 - f1_score: 0.3077 - loss: 2.2631 - precision: 0.4150 - val_accuracy: 0.3750 - val_auc: 0.7883 - val_f1_score: 0.2948 - val_loss: 1.9059 - val_precision: 1.0000
# Epoch 11/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3749 - auc: 0.7576 - f1_score: 0.3638 - loss: 2.1319 - precision: 0.4765
# Epoch 11: val_loss improved from 1.90590 to 1.86856, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.3677 - auc: 0.7550 - f1_score: 0.3564 - loss: 2.1446 - precision: 0.4729 - val_accuracy: 0.3750 - val_auc: 0.8004 - val_f1_score: 0.2971 - val_loss: 1.8686 - val_precision: 1.0000
# Epoch 12/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3476 - auc: 0.7534 - f1_score: 0.3282 - loss: 2.1598 - precision: 0.4594
# Epoch 12: val_loss improved from 1.86856 to 1.83703, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.3530 - auc: 0.7571 - f1_score: 0.3336 - loss: 2.1404 - precision: 0.4700 - val_accuracy: 0.3875 - val_auc: 0.8100 - val_f1_score: 0.3098 - val_loss: 1.8370 - val_precision: 1.0000
# Epoch 13/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3432 - auc: 0.7698 - f1_score: 0.3243 - loss: 2.0703 - precision: 0.4547
# Epoch 13: val_loss improved from 1.83703 to 1.80730, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.3439 - auc: 0.7687 - f1_score: 0.3241 - loss: 2.0781 - precision: 0.4549 - val_accuracy: 0.4000 - val_auc: 0.8172 - val_f1_score: 0.3282 - val_loss: 1.8073 - val_precision: 1.0000
# Epoch 14/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.3674 - auc: 0.7901 - f1_score: 0.3467 - loss: 1.9610 - precision: 0.5272
# Epoch 14: val_loss improved from 1.80730 to 1.77745, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.3673 - auc: 0.7908 - f1_score: 0.3470 - loss: 1.9566 - precision: 0.5277 - val_accuracy: 0.4000 - val_auc: 0.8259 - val_f1_score: 0.3352 - val_loss: 1.7774 - val_precision: 0.9333
# Epoch 15/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.3425 - auc: 0.7777 - f1_score: 0.3226 - loss: 2.0312 - precision: 0.4939
# Epoch 15: val_loss improved from 1.77745 to 1.74869, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.3429 - auc: 0.7779 - f1_score: 0.3235 - loss: 2.0302 - precision: 0.4935 - val_accuracy: 0.4125 - val_auc: 0.8348 - val_f1_score: 0.3521 - val_loss: 1.7487 - val_precision: 0.8750
# Epoch 16/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3676 - auc: 0.7823 - f1_score: 0.3468 - loss: 2.0149 - precision: 0.5273
# Epoch 16: val_loss improved from 1.74869 to 1.71842, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.3707 - auc: 0.7836 - f1_score: 0.3515 - loss: 2.0079 - precision: 0.5269 - val_accuracy: 0.4062 - val_auc: 0.8419 - val_f1_score: 0.3463 - val_loss: 1.7184 - val_precision: 0.8333
# Epoch 17/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.3946 - auc: 0.8072 - f1_score: 0.3740 - loss: 1.8701 - precision: 0.5080
# Epoch 17: val_loss improved from 1.71842 to 1.68879, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.3923 - auc: 0.8058 - f1_score: 0.3723 - loss: 1.8785 - precision: 0.5064 - val_accuracy: 0.4187 - val_auc: 0.8479 - val_f1_score: 0.3574 - val_loss: 1.6888 - val_precision: 0.8421
# Epoch 18/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3830 - auc: 0.7934 - f1_score: 0.3670 - loss: 1.9322 - precision: 0.5501
# Epoch 18: val_loss improved from 1.68879 to 1.65936, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.3854 - auc: 0.7951 - f1_score: 0.3698 - loss: 1.9260 - precision: 0.5452 - val_accuracy: 0.4313 - val_auc: 0.8546 - val_f1_score: 0.3713 - val_loss: 1.6594 - val_precision: 0.8095
# Epoch 19/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4075 - auc: 0.8223 - f1_score: 0.3977 - loss: 1.7760 - precision: 0.5409
# Epoch 19: val_loss improved from 1.65936 to 1.63110, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.4054 - auc: 0.8198 - f1_score: 0.3943 - loss: 1.7935 - precision: 0.5400 - val_accuracy: 0.4375 - val_auc: 0.8602 - val_f1_score: 0.3770 - val_loss: 1.6311 - val_precision: 0.7826
# Epoch 20/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4377 - auc: 0.8274 - f1_score: 0.4227 - loss: 1.7805 - precision: 0.5691
# Epoch 20: val_loss improved from 1.63110 to 1.60281, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.4325 - auc: 0.8262 - f1_score: 0.4180 - loss: 1.7863 - precision: 0.5632 - val_accuracy: 0.4500 - val_auc: 0.8652 - val_f1_score: 0.3980 - val_loss: 1.6028 - val_precision: 0.7500
# Epoch 21/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3849 - auc: 0.7953 - f1_score: 0.3705 - loss: 1.9495 - precision: 0.5062
# Epoch 21: val_loss improved from 1.60281 to 1.57714, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.3892 - auc: 0.7983 - f1_score: 0.3754 - loss: 1.9293 - precision: 0.5142 - val_accuracy: 0.4563 - val_auc: 0.8709 - val_f1_score: 0.4060 - val_loss: 1.5771 - val_precision: 0.7600
# Epoch 22/500
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.4225 - auc: 0.8145 - f1_score: 0.4124 - loss: 1.8411 - precision: 0.5197
# Epoch 22: val_loss improved from 1.57714 to 1.55059, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.4145 - auc: 0.8163 - f1_score: 0.4033 - loss: 1.8277 - precision: 0.5307 - val_accuracy: 0.4875 - val_auc: 0.8769 - val_f1_score: 0.4354 - val_loss: 1.5506 - val_precision: 0.7857
# Epoch 23/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3467 - auc: 0.7988 - f1_score: 0.3352 - loss: 1.9224 - precision: 0.5314
# Epoch 23: val_loss improved from 1.55059 to 1.52340, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.3514 - auc: 0.8022 - f1_score: 0.3392 - loss: 1.9061 - precision: 0.5349 - val_accuracy: 0.5000 - val_auc: 0.8813 - val_f1_score: 0.4528 - val_loss: 1.5234 - val_precision: 0.7879
# Epoch 24/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.4617 - auc: 0.8219 - f1_score: 0.4507 - loss: 1.7746 - precision: 0.6192
# Epoch 24: val_loss improved from 1.52340 to 1.49510, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.4639 - auc: 0.8249 - f1_score: 0.4531 - loss: 1.7580 - precision: 0.6187 - val_accuracy: 0.5063 - val_auc: 0.8868 - val_f1_score: 0.4652 - val_loss: 1.4951 - val_precision: 0.7838
# Epoch 25/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4633 - auc: 0.8434 - f1_score: 0.4468 - loss: 1.6665 - precision: 0.5763
# Epoch 25: val_loss improved from 1.49510 to 1.46954, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.4556 - auc: 0.8419 - f1_score: 0.4399 - loss: 1.6756 - precision: 0.5724 - val_accuracy: 0.5125 - val_auc: 0.8905 - val_f1_score: 0.4689 - val_loss: 1.4695 - val_precision: 0.7895
# Epoch 26/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.4626 - auc: 0.8646 - f1_score: 0.4450 - loss: 1.5332 - precision: 0.6210
# Epoch 26: val_loss improved from 1.46954 to 1.44726, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.4616 - auc: 0.8608 - f1_score: 0.4451 - loss: 1.5544 - precision: 0.6191 - val_accuracy: 0.5188 - val_auc: 0.8939 - val_f1_score: 0.4741 - val_loss: 1.4473 - val_precision: 0.8000
# Epoch 27/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4541 - auc: 0.8554 - f1_score: 0.4384 - loss: 1.6118 - precision: 0.5633
# Epoch 27: val_loss improved from 1.44726 to 1.42445, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.4540 - auc: 0.8546 - f1_score: 0.4391 - loss: 1.6136 - precision: 0.5681 - val_accuracy: 0.5188 - val_auc: 0.8970 - val_f1_score: 0.4743 - val_loss: 1.4245 - val_precision: 0.8049
# Epoch 28/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4505 - auc: 0.8475 - f1_score: 0.4380 - loss: 1.6692 - precision: 0.6270
# Epoch 28: val_loss improved from 1.42445 to 1.40121, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.4488 - auc: 0.8486 - f1_score: 0.4375 - loss: 1.6587 - precision: 0.6249 - val_accuracy: 0.5250 - val_auc: 0.9007 - val_f1_score: 0.4798 - val_loss: 1.4012 - val_precision: 0.8095
# Epoch 29/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4623 - auc: 0.8511 - f1_score: 0.4540 - loss: 1.6120 - precision: 0.6445
# Epoch 29: val_loss improved from 1.40121 to 1.38019, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.4649 - auc: 0.8550 - f1_score: 0.4561 - loss: 1.5903 - precision: 0.6401 - val_accuracy: 0.5250 - val_auc: 0.9034 - val_f1_score: 0.4786 - val_loss: 1.3802 - val_precision: 0.8222
# Epoch 30/500
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.4765 - auc: 0.8706 - f1_score: 0.4506 - loss: 1.5194 - precision: 0.6241
# Epoch 30: val_loss improved from 1.38019 to 1.36180, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.4775 - auc: 0.8687 - f1_score: 0.4562 - loss: 1.5295 - precision: 0.6240 - val_accuracy: 0.5125 - val_auc: 0.9055 - val_f1_score: 0.4700 - val_loss: 1.3618 - val_precision: 0.7755
# Epoch 31/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4912 - auc: 0.8680 - f1_score: 0.4842 - loss: 1.5174 - precision: 0.6799
# Epoch 31: val_loss improved from 1.36180 to 1.34394, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.4909 - auc: 0.8680 - f1_score: 0.4840 - loss: 1.5170 - precision: 0.6759 - val_accuracy: 0.5312 - val_auc: 0.9076 - val_f1_score: 0.4900 - val_loss: 1.3439 - val_precision: 0.7551
# Epoch 32/500
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.4908 - auc: 0.8569 - f1_score: 0.4692 - loss: 1.5652 - precision: 0.6994
# Epoch 32: val_loss improved from 1.34394 to 1.32728, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.4881 - auc: 0.8566 - f1_score: 0.4699 - loss: 1.5695 - precision: 0.6852 - val_accuracy: 0.5312 - val_auc: 0.9098 - val_f1_score: 0.4900 - val_loss: 1.3273 - val_precision: 0.7600
# Epoch 33/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4902 - auc: 0.8836 - f1_score: 0.4704 - loss: 1.4442 - precision: 0.6233
# Epoch 33: val_loss improved from 1.32728 to 1.31096, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.4910 - auc: 0.8841 - f1_score: 0.4722 - loss: 1.4414 - precision: 0.6259 - val_accuracy: 0.5500 - val_auc: 0.9120 - val_f1_score: 0.5121 - val_loss: 1.3110 - val_precision: 0.7647
# Epoch 34/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5056 - auc: 0.8637 - f1_score: 0.4878 - loss: 1.5447 - precision: 0.6666
# Epoch 34: val_loss improved from 1.31096 to 1.29460, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5016 - auc: 0.8620 - f1_score: 0.4854 - loss: 1.5557 - precision: 0.6621 - val_accuracy: 0.5500 - val_auc: 0.9140 - val_f1_score: 0.5145 - val_loss: 1.2946 - val_precision: 0.7778
# Epoch 35/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4896 - auc: 0.8724 - f1_score: 0.4747 - loss: 1.5073 - precision: 0.6416
# Epoch 35: val_loss improved from 1.29460 to 1.27713, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.4888 - auc: 0.8723 - f1_score: 0.4745 - loss: 1.5065 - precision: 0.6451 - val_accuracy: 0.5625 - val_auc: 0.9165 - val_f1_score: 0.5270 - val_loss: 1.2771 - val_precision: 0.7719
# Epoch 36/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4883 - auc: 0.8633 - f1_score: 0.4759 - loss: 1.5551 - precision: 0.5971
# Epoch 36: val_loss improved from 1.27713 to 1.26058, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.4926 - auc: 0.8673 - f1_score: 0.4812 - loss: 1.5306 - precision: 0.6080 - val_accuracy: 0.5625 - val_auc: 0.9188 - val_f1_score: 0.5276 - val_loss: 1.2606 - val_precision: 0.7833
# Epoch 37/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.4675 - auc: 0.8734 - f1_score: 0.4545 - loss: 1.4957 - precision: 0.6019
# Epoch 37: val_loss improved from 1.26058 to 1.24525, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.4695 - auc: 0.8740 - f1_score: 0.4570 - loss: 1.4938 - precision: 0.6043 - val_accuracy: 0.5562 - val_auc: 0.9207 - val_f1_score: 0.5227 - val_loss: 1.2453 - val_precision: 0.7903
# Epoch 38/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5076 - auc: 0.8694 - f1_score: 0.4986 - loss: 1.5097 - precision: 0.6389
# Epoch 38: val_loss improved from 1.24525 to 1.22977, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5109 - auc: 0.8717 - f1_score: 0.5020 - loss: 1.4957 - precision: 0.6433 - val_accuracy: 0.5437 - val_auc: 0.9229 - val_f1_score: 0.5113 - val_loss: 1.2298 - val_precision: 0.7937
# Epoch 39/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5484 - auc: 0.8863 - f1_score: 0.5266 - loss: 1.4008 - precision: 0.6941
# Epoch 39: val_loss improved from 1.22977 to 1.21345, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5380 - auc: 0.8858 - f1_score: 0.5190 - loss: 1.4040 - precision: 0.6914 - val_accuracy: 0.5500 - val_auc: 0.9251 - val_f1_score: 0.5185 - val_loss: 1.2134 - val_precision: 0.7647
# Epoch 40/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5476 - auc: 0.8986 - f1_score: 0.5352 - loss: 1.3132 - precision: 0.7398
# Epoch 40: val_loss improved from 1.21345 to 1.19792, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5373 - auc: 0.8952 - f1_score: 0.5259 - loss: 1.3377 - precision: 0.7226 - val_accuracy: 0.5562 - val_auc: 0.9271 - val_f1_score: 0.5266 - val_loss: 1.1979 - val_precision: 0.7714
# Epoch 41/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5318 - auc: 0.8796 - f1_score: 0.5206 - loss: 1.4315 - precision: 0.6937
# Epoch 41: val_loss improved from 1.19792 to 1.18514, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5324 - auc: 0.8808 - f1_score: 0.5213 - loss: 1.4257 - precision: 0.6919 - val_accuracy: 0.5562 - val_auc: 0.9284 - val_f1_score: 0.5291 - val_loss: 1.1851 - val_precision: 0.7778
# Epoch 42/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5407 - auc: 0.8883 - f1_score: 0.5372 - loss: 1.3859 - precision: 0.7029
# Epoch 42: val_loss improved from 1.18514 to 1.17101, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5414 - auc: 0.8893 - f1_score: 0.5371 - loss: 1.3805 - precision: 0.7025 - val_accuracy: 0.5688 - val_auc: 0.9300 - val_f1_score: 0.5385 - val_loss: 1.1710 - val_precision: 0.8028
# Epoch 43/500
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5159 - auc: 0.8895 - f1_score: 0.4909 - loss: 1.3784 - precision: 0.7050
# Epoch 43: val_loss improved from 1.17101 to 1.15657, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.5251 - auc: 0.8906 - f1_score: 0.5060 - loss: 1.3719 - precision: 0.6990 - val_accuracy: 0.5938 - val_auc: 0.9311 - val_f1_score: 0.5661 - val_loss: 1.1566 - val_precision: 0.7917
# Epoch 44/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5769 - auc: 0.8983 - f1_score: 0.5660 - loss: 1.3187 - precision: 0.7022
# Epoch 44: val_loss improved from 1.15657 to 1.14459, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5673 - auc: 0.8966 - f1_score: 0.5568 - loss: 1.3326 - precision: 0.6898 - val_accuracy: 0.5938 - val_auc: 0.9326 - val_f1_score: 0.5651 - val_loss: 1.1446 - val_precision: 0.7838
# Epoch 45/500
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5594 - auc: 0.9042 - f1_score: 0.5515 - loss: 1.2703 - precision: 0.7145
# Epoch 45: val_loss improved from 1.14459 to 1.13280, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.5551 - auc: 0.9037 - f1_score: 0.5466 - loss: 1.2764 - precision: 0.7097 - val_accuracy: 0.6125 - val_auc: 0.9341 - val_f1_score: 0.5853 - val_loss: 1.1328 - val_precision: 0.7821
# Epoch 46/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5277 - auc: 0.8890 - f1_score: 0.5107 - loss: 1.3867 - precision: 0.6723
# Epoch 46: val_loss improved from 1.13280 to 1.12400, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5325 - auc: 0.8912 - f1_score: 0.5176 - loss: 1.3727 - precision: 0.6758 - val_accuracy: 0.6125 - val_auc: 0.9349 - val_f1_score: 0.5853 - val_loss: 1.1240 - val_precision: 0.7722
# Epoch 47/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5763 - auc: 0.9093 - f1_score: 0.5612 - loss: 1.2418 - precision: 0.7445
# Epoch 47: val_loss improved from 1.12400 to 1.11854, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5728 - auc: 0.9069 - f1_score: 0.5588 - loss: 1.2596 - precision: 0.7352 - val_accuracy: 0.6187 - val_auc: 0.9351 - val_f1_score: 0.5915 - val_loss: 1.1185 - val_precision: 0.7750
# Epoch 48/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5596 - auc: 0.9016 - f1_score: 0.5479 - loss: 1.3122 - precision: 0.7018
# Epoch 48: val_loss improved from 1.11854 to 1.11235, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5583 - auc: 0.9012 - f1_score: 0.5475 - loss: 1.3136 - precision: 0.7007 - val_accuracy: 0.6125 - val_auc: 0.9357 - val_f1_score: 0.5868 - val_loss: 1.1124 - val_precision: 0.7805
# Epoch 49/500
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5526 - auc: 0.9027 - f1_score: 0.5281 - loss: 1.3173 - precision: 0.6807
# Epoch 49: val_loss improved from 1.11235 to 1.10775, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.5513 - auc: 0.9020 - f1_score: 0.5318 - loss: 1.3201 - precision: 0.6840 - val_accuracy: 0.6125 - val_auc: 0.9359 - val_f1_score: 0.5907 - val_loss: 1.1077 - val_precision: 0.7765
# Epoch 50/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5684 - auc: 0.8964 - f1_score: 0.5600 - loss: 1.3385 - precision: 0.6496
# Epoch 50: val_loss improved from 1.10775 to 1.09775, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5633 - auc: 0.8973 - f1_score: 0.5553 - loss: 1.3355 - precision: 0.6521 - val_accuracy: 0.6187 - val_auc: 0.9372 - val_f1_score: 0.5930 - val_loss: 1.0977 - val_precision: 0.7765
# Epoch 51/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5783 - auc: 0.9111 - f1_score: 0.5684 - loss: 1.2361 - precision: 0.7341
# Epoch 51: val_loss improved from 1.09775 to 1.08780, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5776 - auc: 0.9102 - f1_score: 0.5686 - loss: 1.2419 - precision: 0.7322 - val_accuracy: 0.6375 - val_auc: 0.9383 - val_f1_score: 0.6177 - val_loss: 1.0878 - val_precision: 0.7701
# Epoch 52/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5079 - auc: 0.8886 - f1_score: 0.4911 - loss: 1.4087 - precision: 0.6572
# Epoch 52: val_loss improved from 1.08780 to 1.07843, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5118 - auc: 0.8911 - f1_score: 0.4968 - loss: 1.3922 - precision: 0.6597 - val_accuracy: 0.6375 - val_auc: 0.9393 - val_f1_score: 0.6177 - val_loss: 1.0784 - val_precision: 0.7882
# Epoch 53/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5482 - auc: 0.9085 - f1_score: 0.5400 - loss: 1.2714 - precision: 0.6797
# Epoch 53: val_loss improved from 1.07843 to 1.07063, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5487 - auc: 0.9091 - f1_score: 0.5397 - loss: 1.2686 - precision: 0.6784 - val_accuracy: 0.6375 - val_auc: 0.9401 - val_f1_score: 0.6189 - val_loss: 1.0706 - val_precision: 0.7882
# Epoch 54/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5779 - auc: 0.9143 - f1_score: 0.5689 - loss: 1.2222 - precision: 0.7436
# Epoch 54: val_loss improved from 1.07063 to 1.06314, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.5787 - auc: 0.9151 - f1_score: 0.5705 - loss: 1.2158 - precision: 0.7425 - val_accuracy: 0.6313 - val_auc: 0.9404 - val_f1_score: 0.6126 - val_loss: 1.0631 - val_precision: 0.7674
# Epoch 55/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6088 - auc: 0.9272 - f1_score: 0.5866 - loss: 1.1265 - precision: 0.7559
# Epoch 55: val_loss improved from 1.06314 to 1.05480, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6059 - auc: 0.9256 - f1_score: 0.5859 - loss: 1.1385 - precision: 0.7500 - val_accuracy: 0.6438 - val_auc: 0.9421 - val_f1_score: 0.6217 - val_loss: 1.0548 - val_precision: 0.7640
# Epoch 56/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5073 - auc: 0.8949 - f1_score: 0.5001 - loss: 1.3908 - precision: 0.6133
# Epoch 56: val_loss improved from 1.05480 to 1.04412, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.5230 - auc: 0.8994 - f1_score: 0.5154 - loss: 1.3543 - precision: 0.6319 - val_accuracy: 0.6438 - val_auc: 0.9432 - val_f1_score: 0.6217 - val_loss: 1.0441 - val_precision: 0.7692
# Epoch 57/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6259 - auc: 0.9182 - f1_score: 0.6048 - loss: 1.1764 - precision: 0.7469
# Epoch 57: val_loss improved from 1.04412 to 1.03550, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6228 - auc: 0.9176 - f1_score: 0.6043 - loss: 1.1815 - precision: 0.7440 - val_accuracy: 0.6438 - val_auc: 0.9440 - val_f1_score: 0.6209 - val_loss: 1.0355 - val_precision: 0.7766
# Epoch 58/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6151 - auc: 0.9293 - f1_score: 0.6083 - loss: 1.1051 - precision: 0.7915
# Epoch 58: val_loss improved from 1.03550 to 1.03009, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.6118 - auc: 0.9277 - f1_score: 0.6049 - loss: 1.1181 - precision: 0.7822 - val_accuracy: 0.6438 - val_auc: 0.9445 - val_f1_score: 0.6209 - val_loss: 1.0301 - val_precision: 0.7789
# Epoch 59/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5971 - auc: 0.9227 - f1_score: 0.5864 - loss: 1.1616 - precision: 0.7570
# Epoch 59: val_loss improved from 1.03009 to 1.02749, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5975 - auc: 0.9231 - f1_score: 0.5878 - loss: 1.1584 - precision: 0.7576 - val_accuracy: 0.6438 - val_auc: 0.9443 - val_f1_score: 0.6209 - val_loss: 1.0275 - val_precision: 0.7708
# Epoch 60/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5655 - auc: 0.9150 - f1_score: 0.5499 - loss: 1.2264 - precision: 0.7157
# Epoch 60: val_loss improved from 1.02749 to 1.02159, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.5665 - auc: 0.9154 - f1_score: 0.5511 - loss: 1.2232 - precision: 0.7175 - val_accuracy: 0.6438 - val_auc: 0.9453 - val_f1_score: 0.6209 - val_loss: 1.0216 - val_precision: 0.7732
# Epoch 61/500
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5661 - auc: 0.9237 - f1_score: 0.5540 - loss: 1.1565 - precision: 0.7417
# Epoch 61: val_loss improved from 1.02159 to 1.01638, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.5775 - auc: 0.9247 - f1_score: 0.5661 - loss: 1.1475 - precision: 0.7409 - val_accuracy: 0.6500 - val_auc: 0.9458 - val_f1_score: 0.6261 - val_loss: 1.0164 - val_precision: 0.7857
# Epoch 62/500
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6236 - auc: 0.9328 - f1_score: 0.6007 - loss: 1.0793 - precision: 0.7509
# Epoch 62: val_loss improved from 1.01638 to 1.00952, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.6153 - auc: 0.9324 - f1_score: 0.5984 - loss: 1.0861 - precision: 0.7468 - val_accuracy: 0.6500 - val_auc: 0.9468 - val_f1_score: 0.6261 - val_loss: 1.0095 - val_precision: 0.7879
# Epoch 63/500
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6583 - auc: 0.9327 - f1_score: 0.6399 - loss: 1.0683 - precision: 0.7495
# Epoch 63: val_loss improved from 1.00952 to 1.00374, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.6397 - auc: 0.9295 - f1_score: 0.6256 - loss: 1.0982 - precision: 0.7422 - val_accuracy: 0.6500 - val_auc: 0.9475 - val_f1_score: 0.6265 - val_loss: 1.0037 - val_precision: 0.7959
# Epoch 64/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5885 - auc: 0.9134 - f1_score: 0.5777 - loss: 1.2106 - precision: 0.7454
# Epoch 64: val_loss improved from 1.00374 to 0.99956, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5824 - auc: 0.9144 - f1_score: 0.5733 - loss: 1.2065 - precision: 0.7437 - val_accuracy: 0.6562 - val_auc: 0.9477 - val_f1_score: 0.6322 - val_loss: 0.9996 - val_precision: 0.7879
# Epoch 65/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6504 - auc: 0.9362 - f1_score: 0.6384 - loss: 1.0580 - precision: 0.7917
# Epoch 65: val_loss improved from 0.99956 to 0.99608, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6444 - auc: 0.9325 - f1_score: 0.6342 - loss: 1.0848 - precision: 0.7819 - val_accuracy: 0.6562 - val_auc: 0.9482 - val_f1_score: 0.6322 - val_loss: 0.9961 - val_precision: 0.7900
# Epoch 66/500
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6194 - auc: 0.9216 - f1_score: 0.5964 - loss: 1.1647 - precision: 0.7677
# Epoch 66: val_loss improved from 0.99608 to 0.99179, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.6092 - auc: 0.9213 - f1_score: 0.5908 - loss: 1.1707 - precision: 0.7551 - val_accuracy: 0.6500 - val_auc: 0.9485 - val_f1_score: 0.6264 - val_loss: 0.9918 - val_precision: 0.7900
# Epoch 67/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6103 - auc: 0.9192 - f1_score: 0.5803 - loss: 1.1857 - precision: 0.7487
# Epoch 67: val_loss improved from 0.99179 to 0.98904, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6103 - auc: 0.9208 - f1_score: 0.5854 - loss: 1.1743 - precision: 0.7495 - val_accuracy: 0.6500 - val_auc: 0.9485 - val_f1_score: 0.6264 - val_loss: 0.9890 - val_precision: 0.7900
# Epoch 68/500
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6119 - auc: 0.9222 - f1_score: 0.5971 - loss: 1.1630 - precision: 0.7807
# Epoch 68: val_loss improved from 0.98904 to 0.98485, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.6163 - auc: 0.9246 - f1_score: 0.6044 - loss: 1.1448 - precision: 0.7757 - val_accuracy: 0.6562 - val_auc: 0.9493 - val_f1_score: 0.6320 - val_loss: 0.9849 - val_precision: 0.7900
# Epoch 69/500
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5906 - auc: 0.9296 - f1_score: 0.5880 - loss: 1.1210 - precision: 0.7194
# Epoch 69: val_loss improved from 0.98485 to 0.98253, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6019 - auc: 0.9317 - f1_score: 0.5986 - loss: 1.1015 - precision: 0.7312 - val_accuracy: 0.6562 - val_auc: 0.9492 - val_f1_score: 0.6332 - val_loss: 0.9825 - val_precision: 0.7900
# Epoch 70/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6388 - auc: 0.9332 - f1_score: 0.6276 - loss: 1.0748 - precision: 0.7845
# Epoch 70: val_loss improved from 0.98253 to 0.98169, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6359 - auc: 0.9332 - f1_score: 0.6255 - loss: 1.0768 - precision: 0.7806 - val_accuracy: 0.6625 - val_auc: 0.9492 - val_f1_score: 0.6386 - val_loss: 0.9817 - val_precision: 0.7900
# Epoch 71/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6190 - auc: 0.9333 - f1_score: 0.6077 - loss: 1.0823 - precision: 0.7556
# Epoch 71: val_loss improved from 0.98169 to 0.97968, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6191 - auc: 0.9323 - f1_score: 0.6090 - loss: 1.0886 - precision: 0.7539 - val_accuracy: 0.6500 - val_auc: 0.9492 - val_f1_score: 0.6272 - val_loss: 0.9797 - val_precision: 0.7900
# Epoch 72/500
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6512 - auc: 0.9408 - f1_score: 0.6391 - loss: 1.0275 - precision: 0.7894
# Epoch 72: val_loss improved from 0.97968 to 0.97578, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6475 - auc: 0.9403 - f1_score: 0.6383 - loss: 1.0329 - precision: 0.7839 - val_accuracy: 0.6500 - val_auc: 0.9490 - val_f1_score: 0.6272 - val_loss: 0.9758 - val_precision: 0.7900
# Epoch 73/500
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6035 - auc: 0.9445 - f1_score: 0.5922 - loss: 1.0090 - precision: 0.7262
# Epoch 73: val_loss improved from 0.97578 to 0.96822, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6038 - auc: 0.9407 - f1_score: 0.5940 - loss: 1.0338 - precision: 0.7332 - val_accuracy: 0.6625 - val_auc: 0.9499 - val_f1_score: 0.6371 - val_loss: 0.9682 - val_precision: 0.7921
# Epoch 74/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6454 - auc: 0.9389 - f1_score: 0.6314 - loss: 1.0357 - precision: 0.7683
# Epoch 74: val_loss improved from 0.96822 to 0.96225, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6424 - auc: 0.9382 - f1_score: 0.6301 - loss: 1.0398 - precision: 0.7669 - val_accuracy: 0.6687 - val_auc: 0.9504 - val_f1_score: 0.6441 - val_loss: 0.9623 - val_precision: 0.7921
# Epoch 75/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6859 - auc: 0.9520 - f1_score: 0.6834 - loss: 0.9224 - precision: 0.8005
# Epoch 75: val_loss improved from 0.96225 to 0.95765, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.6818 - auc: 0.9507 - f1_score: 0.6790 - loss: 0.9321 - precision: 0.7994 - val_accuracy: 0.6750 - val_auc: 0.9510 - val_f1_score: 0.6496 - val_loss: 0.9576 - val_precision: 0.7961
# Epoch 76/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6641 - auc: 0.9464 - f1_score: 0.6410 - loss: 0.9737 - precision: 0.7846
# Epoch 76: val_loss improved from 0.95765 to 0.95447, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.6635 - auc: 0.9449 - f1_score: 0.6448 - loss: 0.9860 - precision: 0.7801 - val_accuracy: 0.6750 - val_auc: 0.9511 - val_f1_score: 0.6496 - val_loss: 0.9545 - val_precision: 0.7961
# Epoch 77/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6827 - auc: 0.9471 - f1_score: 0.6790 - loss: 0.9648 - precision: 0.8052
# Epoch 77: val_loss improved from 0.95447 to 0.95393, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.6789 - auc: 0.9465 - f1_score: 0.6741 - loss: 0.9689 - precision: 0.8005 - val_accuracy: 0.6750 - val_auc: 0.9513 - val_f1_score: 0.6491 - val_loss: 0.9539 - val_precision: 0.7941
# Epoch 78/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6539 - auc: 0.9339 - f1_score: 0.6502 - loss: 1.0590 - precision: 0.7479
# Epoch 78: val_loss improved from 0.95393 to 0.95281, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6516 - auc: 0.9349 - f1_score: 0.6480 - loss: 1.0534 - precision: 0.7506 - val_accuracy: 0.6750 - val_auc: 0.9510 - val_f1_score: 0.6491 - val_loss: 0.9528 - val_precision: 0.7961
# Epoch 79/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5950 - auc: 0.9240 - f1_score: 0.5901 - loss: 1.1518 - precision: 0.7089
# Epoch 79: val_loss improved from 0.95281 to 0.94909, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.6041 - auc: 0.9279 - f1_score: 0.5986 - loss: 1.1230 - precision: 0.7162 - val_accuracy: 0.6750 - val_auc: 0.9518 - val_f1_score: 0.6489 - val_loss: 0.9491 - val_precision: 0.8077
# Epoch 80/500
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6134 - auc: 0.9388 - f1_score: 0.5933 - loss: 1.0505 - precision: 0.7510
# Epoch 80: val_loss improved from 0.94909 to 0.94515, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.6235 - auc: 0.9385 - f1_score: 0.6089 - loss: 1.0462 - precision: 0.7577 - val_accuracy: 0.6750 - val_auc: 0.9523 - val_f1_score: 0.6500 - val_loss: 0.9452 - val_precision: 0.7963
# Epoch 81/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.
saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.6723 - auc: 0.9538 - f1_score: 0.6655 - loss: 0.9098 - precision: 0.8043 - val_accuracy: 0.6687 - val_auc: 0.9546 - val_f1_score: 0.6422 - val_loss: 0.9145 - val_precision: 0.7965
# Epoch 90/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6840 - auc: 0.9591 - f1_score: 0.6790 - loss: 0.8717 - precision: 0.8204
# Epoch 90: val_loss improved from 0.91451 to 0.91199, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.6880 - auc: 0.9587 - f1_score: 0.6832 - loss: 0.8723 - precision: 0.8226 - val_accuracy: 0.6687 - val_auc: 0.9549 - val_f1_score: 0.6422 - val_loss: 0.9120 - val_precision: 0.7895
# Epoch 91/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6611 - auc: 0.9476 - f1_score: 0.6522 - loss: 0.9597 - precision: 0.7891
# Epoch 91: val_loss improved from 0.91199 to 0.91091, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6607 - auc: 0.9490 - f1_score: 0.6531 - loss: 0.9493 - precision: 0.7886 - val_accuracy: 0.6687 - val_auc: 0.9545 - val_f1_score: 0.6422 - val_loss: 0.9109 - val_precision: 0.7826
# Epoch 92/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6670 - auc: 0.9473 - f1_score: 0.6613 - loss: 0.9673 - precision: 0.7955
# Epoch 92: val_loss did not improve from 0.91091
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6644 - auc: 0.9473 - f1_score: 0.6593 - loss: 0.9666 - precision: 0.7942 - val_accuracy: 0.6687 - val_auc: 0.9544 - val_f1_score: 0.6422 - val_loss: 0.9113 - val_precision: 0.7826
# Epoch 93/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7105 - auc: 0.9569 - f1_score: 0.7032 - loss: 0.8800 - precision: 0.8335
# Epoch 93: val_loss improved from 0.91091 to 0.90855, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.7054 - auc: 0.9564 - f1_score: 0.6986 - loss: 0.8842 - precision: 0.8298 - val_accuracy: 0.6625 - val_auc: 0.9547 - val_f1_score: 0.6372 - val_loss: 0.9085 - val_precision: 0.7863
# Epoch 94/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6719 - auc: 0.9435 - f1_score: 0.6691 - loss: 0.9824 - precision: 0.7928
# Epoch 94: val_loss did not improve from 0.90855
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6701 - auc: 0.9433 - f1_score: 0.6662 - loss: 0.9827 - precision: 0.7943 - val_accuracy: 0.6625 - val_auc: 0.9546 - val_f1_score: 0.6372 - val_loss: 0.9089 - val_precision: 0.7863
# Epoch 95/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7178 - auc: 0.9581 - f1_score: 0.7091 - loss: 0.8674 - precision: 0.8236
# Epoch 95: val_loss improved from 0.90855 to 0.90647, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.7161 - auc: 0.9580 - f1_score: 0.7078 - loss: 0.8695 - precision: 0.8229 - val_accuracy: 0.6625 - val_auc: 0.9551 - val_f1_score: 0.6389 - val_loss: 0.9065 - val_precision: 0.7913
# Epoch 96/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6996 - auc: 0.9603 - f1_score: 0.6954 - loss: 0.8530 - precision: 0.8551
# Epoch 96: val_loss improved from 0.90647 to 0.90290, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7050 - auc: 0.9614 - f1_score: 0.7014 - loss: 0.8425 - precision: 0.8533 - val_accuracy: 0.6625 - val_auc: 0.9553 - val_f1_score: 0.6406 - val_loss: 0.9029 - val_precision: 0.7845
# Epoch 97/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7027 - auc: 0.9487 - f1_score: 0.6961 - loss: 0.9390 - precision: 0.8134
# Epoch 97: val_loss improved from 0.90290 to 0.90050, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7027 - auc: 0.9505 - f1_score: 0.6972 - loss: 0.9264 - precision: 0.8143 - val_accuracy: 0.6625 - val_auc: 0.9554 - val_f1_score: 0.6406 - val_loss: 0.9005 - val_precision: 0.7778
# Epoch 98/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6880 - auc: 0.9598 - f1_score: 0.6817 - loss: 0.8610 - precision: 0.8325
# Epoch 98: val_loss improved from 0.90050 to 0.89894, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6881 - auc: 0.9596 - f1_score: 0.6823 - loss: 0.8625 - precision: 0.8294 - val_accuracy: 0.6687 - val_auc: 0.9556 - val_f1_score: 0.6478 - val_loss: 0.8989 - val_precision: 0.7913
# Epoch 99/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7195 - auc: 0.9614 - f1_score: 0.7074 - loss: 0.8430 - precision: 0.8097
# Epoch 99: val_loss did not improve from 0.89894
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7106 - auc: 0.9596 - f1_score: 0.7007 - loss: 0.8591 - precision: 0.8063 - val_accuracy: 0.6625 - val_auc: 0.9553 - val_f1_score: 0.6435 - val_loss: 0.9008 - val_precision: 0.7982
# Epoch 100/500
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7065 - auc: 0.9553 - f1_score: 0.7027 - loss: 0.8849 - precision: 0.8240
# Epoch 100: val_loss improved from 0.89894 to 0.89704, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7069 - auc: 0.9562 - f1_score: 0.7038 - loss: 0.8764 - precision: 0.8230 - val_accuracy: 0.6687 - val_auc: 0.9557 - val_f1_score: 0.6507 - val_loss: 0.8970 - val_precision: 0.8000
# Epoch 101/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7074 - auc: 0.9578 - f1_score: 0.6994 - loss: 0.8674 - precision: 0.7913
# Epoch 101: val_loss improved from 0.89704 to 0.89187, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7062 - auc: 0.9574 - f1_score: 0.6989 - loss: 0.8708 - precision: 0.7957 - val_accuracy: 0.6687 - val_auc: 0.9564 - val_f1_score: 0.6508 - val_loss: 0.8919 - val_precision: 0.8000
# Epoch 102/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6720 - auc: 0.9447 - f1_score: 0.6617 - loss: 0.9796 - precision: 0.7831
# Epoch 102: val_loss improved from 0.89187 to 0.88466, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6733 - auc: 0.9465 - f1_score: 0.6644 - loss: 0.9648 - precision: 0.7890 - val_accuracy: 0.6750 - val_auc: 0.9572 - val_f1_score: 0.6555 - val_loss: 0.8847 - val_precision: 0.7966
# Epoch 103/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6886 - auc: 0.9594 - f1_score: 0.6837 - loss: 0.8443 - precision: 0.8111
# ...
# Epoch 237/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8403 - auc: 0.9905 - f1_score: 0.8424 - loss: 0.4251 - precision: 0.9023
# Epoch 237: val_loss did not improve from 0.80851
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8417 - auc: 0.9906 - f1_score: 0.8437 - loss: 0.4252 - precision: 0.9033 - val_accuracy: 0.7312 - val_auc: 0.9572 - val_f1_score: 0.7314 - val_loss: 0.8271 - val_precision: 0.8077
# Epoch 238/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8824 - auc: 0.9913 - f1_score: 0.8751 - loss: 0.4018 - precision: 0.9198
# Epoch 238: val_loss did not improve from 0.80851
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8819 - auc: 0.9912 - f1_score: 0.8750 - loss: 0.4033 - precision: 0.9195 - val_accuracy: 0.7312 - val_auc: 0.9574 - val_f1_score: 0.7323 - val_loss: 0.8273 - val_precision: 0.8203
# Epoch 239/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8279 - auc: 0.9886 - f1_score: 0.8243 - loss: 0.4736 - precision: 0.8937
# Epoch 239: val_loss did not improve from 0.80851
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.
val_loss did not improve from 0.80851
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8957 - auc: 0.9951 - f1_score: 0.8961 - loss: 0.3407 - precision: 0.9302 - val_accuracy: 0.7375 - val_auc: 0.9581 - val_f1_score: 0.7377 - val_loss: 0.8282 - val_precision: 0.7970
# Epoch 268/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8784 - auc: 0.9923 - f1_score: 0.8763 - loss: 0.3921 - precision: 0.9245
# Epoch 268: val_loss did not improve from 0.80851
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8791 - auc: 0.9925 - f1_score: 0.8770 - loss: 0.3894 - precision: 0.9252 - val_accuracy: 0.7250 - val_auc: 0.9584 - val_f1_score: 0.7258 - val_loss: 0.8284 - val_precision: 0.7926
# Epoch 269/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8957 - auc: 0.9952 - f1_score: 0.8966 - loss: 0.3370 - precision: 0.9397
# Epoch 269: val_loss did not improve from 0.80851
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8969 - auc: 0.9953 - f1_score: 0.8978 - loss: 0.3359 - precision: 0.9399 - val_accuracy: 0.7250 - val_auc: 0.9584 - val_f1_score: 0.7258 - val_loss: 0.8275 - val_precision: 0.7852
# Epoch 270/500
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8586 - auc: 0.9922 - f1_score: 0.8588 - loss: 0.3982 - precision: 0.9228
# Epoch 270: val_loss did not improve from 0.80851
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8650 - auc: 0.9929 - f1_score: 0.8656 - loss: 0.3843 - precision: 0.9273 - val_accuracy: 0.7437 - val_auc: 0.9589 - val_f1_score: 0.7440 - val_loss: 0.8225 - val_precision: 0.8000
# Epoch 271/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8925 - auc: 0.9949 - f1_score: 0.8903 - loss: 0.3369 - precision: 0.9348
# Epoch 271: val_loss did not improve from 0.80851
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8933 - auc: 0.9949 - f1_score: 0.8913 - loss: 0.3363 - precision: 0.9354 - val_accuracy: 0.7375 - val_auc: 0.9587 - val_f1_score: 0.7375 - val_loss: 0.8230 - val_precision: 0.7970
# Epoch 272/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8904 - auc: 0.9937 - f1_score: 0.8873 - loss: 0.3567 - precision: 0.9429
# Epoch 272: val_loss did not improve from 0.80851
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8902 - auc: 0.9937 - f1_score: 0.8874 - loss: 0.3564 - precision: 0.9426 - val_accuracy: 0.7375 - val_auc: 0.9586 - val_f1_score: 0.7371 - val_loss: 0.8232 - val_precision: 0.8030
# Epoch 273/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8764 - auc: 0.9943 - f1_score: 0.8769 - loss: 0.3589 - precision: 0.9172
# Epoch 273: val_loss did not improve from 0.80851
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8802 - auc: 0.9948 - f1_score: 0.8805 - loss: 0.3460 - precision: 0.9234 - val_accuracy: 0.7312 - val_auc: 0.9587 - val_f1_score: 0.7324 - val_loss: 0.8232 - val_precision: 0.7970
# Epoch 273: early stopping
# Restoring model weights from the end of the best epoch: 223.

# %%
plt.figure(figsize=(20, 6))

# Plot training and validation accuracy
plt.subplot(1, 3, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot training and validation loss
plt.subplot(1, 3, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 3, 3)
plt.plot(history.history['precision'], label='Training Precision')
plt.plot(history.history['val_precision'], label='Validation Precision')
plt.title('Precision over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
y_pred_probs = model.predict(X_test)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = np.argmax(y_test, axis=1) if y_test.ndim > 1 else y_test

accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred, average='macro', zero_division=0)
f1 = f1_score(y_true, y_pred, average='macro')
conf_matrix = confusion_matrix(y_true, y_pred)

print("Dokładność:", accuracy)
print("Precyzja (macro):", precision)
print("F1 score (macro):", f1)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Dokładność: 0.68
# Precyzja (macro): 0.6836829178658497
# F1 score (macro): 0.6788422188049877

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix Heatmap')
plt.show()

# %%
y_true_bin = label_binarize(y_true, classes=range(10))
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(10):
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_pred_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])


plt.figure(figsize=(10, 8))
for i in range(10):
    plt.plot(fpr[i], tpr[i], label=f'Klasa {i} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Krzywe ROC dla klas')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()
