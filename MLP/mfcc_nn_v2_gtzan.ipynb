# %% [markdown]
# # Music Genre Classification using Neural Network

# %%
import pandas as pd
import numpy as np
import platform
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, LeakyReLU, ReLU, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import LearningRateScheduler, EarlyStopping, ModelCheckpoint
from tensorflow.keras.metrics import Precision, Accuracy, AUC, F1Score
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import accuracy_score, precision_score, f1_score, confusion_matrix, roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    try:
        for device in physical_devices:
            tf.config.experimental.set_memory_growth(device, True)
        if tf.test.is_built_with_cuda():
            print(
                f"CUDA is enabled. Using GPU(s) with CUDA: {physical_devices}")
        elif platform.system() == 'Darwin':
            print(
                f"Metal is enabled. Using Metal-enabled GPU on macOS: {physical_devices}")
        else:
            print(
                f"GPU detected but neither CUDA nor Metal is enabled: {physical_devices}")
    except RuntimeError as e:
        print(f"Error enabling GPU acceleration: {e}")
else:
    print("No GPU found. Running on CPU.")
# Out:
# Metal is enabled. Using Metal-enabled GPU on macOS: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Load MFCC data
mfcc_df = pd.read_csv('mfcc_data_gtzan_v2.csv', header=[0, 1, 2], index_col=0)
labels = pd.read_csv('../project_data/tracks.csv')['genre']

# Encode labels
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(labels)

# Drop non-numeric columns
mfcc_df = mfcc_df.drop(columns=['file_name'])

# Flatten multi-index columns and scale features
mfcc_df.columns = ['_'.join(map(str, col)) for col in mfcc_df.columns]
scaler = StandardScaler()
X = scaler.fit_transform(mfcc_df)
# Out:
# /var/folders/42/12p7rrgx3zj15zz7yc0tm30w0000gn/T/ipykernel_72281/2032037441.py:10: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   mfcc_df = mfcc_df.drop(columns=['file_name'])

# %%
mfcc_df.hist(bins=30, figsize=(16, 14), edgecolor='black')
plt.tight_layout()
plt.show()

# %%
y = to_categorical(y, num_classes=10)

# %%
X_train_full, X_test, y_train_full, y_test = train_test_split(
    X, y,
    test_size=0.2,
    stratify=y.argmax(axis=1),
    random_state=42
)

X_train, X_val, y_train, y_val = train_test_split(
    X_train_full, y_train_full,
    test_size=0.2,
    stratify=y_train_full.argmax(axis=1),
    random_state=42
)

# %%
x_train_nan = np.isnan(X_train).sum()  # Liczba NaN w X_train
y_train_nan = np.isnan(y_train).sum()  # Liczba NaN w y_train

print(f"NaN values in X_train: {x_train_nan}")
print(f"NaN values in y_train: {y_train_nan}")
# Out:
# NaN values in X_train: 0
# NaN values in y_train: 0

# %%
def build_and_train_model(X_train, y_train, X_val, y_val,
                          hidden_layers=[64, 32],
                          output_activation='softmax',
                          loss='categorical_crossentropy',
                          optimizer='adam',
                          metrics=['accuracy', Precision(name='precision')],
                          monitor_metric='val_precision',
                          model_path='best_model.h5',
                          epochs=20,
                          batch_size=32,
                          patience=5,
                          dropout=0.2):

    model = Sequential()
    model.add(Input(shape=(X_train.shape[1],)))
    model.add(Dense(hidden_layers[0]))
    model.add(LeakyReLU(negative_slope=0.1))
    for units in hidden_layers[1:]:
        model.add(Dense(units))
        model.add(LeakyReLU(negative_slope=0.1))
        model.add(BatchNormalization())
        model.add(Dropout(dropout)),
    model.add(Dense(10, activation=output_activation))

    model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

    checkpoint = ModelCheckpoint(
        model_path,
        monitor=monitor_metric,
        mode='min',
        save_best_only=True,
        verbose=1
    )

    early_stopping = EarlyStopping(
        monitor=monitor_metric,
        patience=patience,
        mode='min',
        verbose=1,
        restore_best_weights=True
    )

    history = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=epochs,
        batch_size=batch_size,
        callbacks=[checkpoint, early_stopping]
    )

    return model, history
# Out:
# 2025-05-17 17:23:22.430645: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2
# 2025-05-17 17:23:22.430693: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2025-05-17 17:23:22.430701: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1747495402.430717 13848175 pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# I0000 00:00:1747495402.430740 13848175 pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
model, history = build_and_train_model(
    X_train, y_train,
    X_val, y_val,
    hidden_layers=[256, 128, 64],
    optimizer=Adam(learning_rate=0.0001),
    metrics=[AUC(), F1Score(), 'accuracy', Precision(name='precision')],
    monitor_metric='val_loss',
    model_path='best_model_gtzan_v2.keras',
    epochs=500,
    batch_size=64,
    patience=50,
    dropout=0.45
)
# Out:
# Epoch 1/500
# 2025-05-17 17:23:23.204543: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.0680 - auc: 0.4704 - f1_score: 0.0685 - loss: 3.6153 - precision: 0.0619
# Epoch 1: val_loss improved from inf to 2.33070, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step - accuracy: 0.0691 - auc: 0.4720 - f1_score: 0.0696 - loss: 3.6083 - precision: 0.0642 - val_accuracy: 0.1312 - val_auc: 0.5229 - val_f1_score: 0.1027 - val_loss: 2.3307 - val_precision: 0.0000e+00
# Epoch 2/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.0873 - auc: 0.5124 - f1_score: 0.0859 - loss: 3.4167 - precision: 0.0737
# Epoch 2: val_loss improved from 2.33070 to 2.26618, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.0897 - auc: 0.5140 - f1_score: 0.0885 - loss: 3.4052 - precision: 0.0762 - val_accuracy: 0.2125 - val_auc: 0.5843 - val_f1_score: 0.1922 - val_loss: 2.2662 - val_precision: 0.0000e+00
# Epoch 3/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.1359 - auc: 0.5777 - f1_score: 0.1326 - loss: 3.0026 - precision: 0.2295
# Epoch 3: val_loss improved from 2.26618 to 2.20019, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.1365 - auc: 0.5768 - f1_score: 0.1337 - loss: 3.0123 - precision: 0.2248 - val_accuracy: 0.2688 - val_auc: 0.6456 - val_f1_score: 0.2468 - val_loss: 2.2002 - val_precision: 0.0000e+00
# Epoch 4/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.1694 - auc: 0.5861 - f1_score: 0.1692 - loss: 3.0313 - precision: 0.2159
# Epoch 4: val_loss improved from 2.20019 to 2.13968, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.1719 - auc: 0.5907 - f1_score: 0.1715 - loss: 2.9950 - precision: 0.2198 - val_accuracy: 0.3000 - val_auc: 0.6961 - val_f1_score: 0.2830 - val_loss: 2.1397 - val_precision: 0.0000e+00
# Epoch 5/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.1846 - auc: 0.6270 - f1_score: 0.1840 - loss: 2.7581 - precision: 0.2133
# Epoch 5: val_loss improved from 2.13968 to 2.08136, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.1851 - auc: 0.6272 - f1_score: 0.1844 - loss: 2.7559 - precision: 0.2152 - val_accuracy: 0.3375 - val_auc: 0.7366 - val_f1_score: 0.3189 - val_loss: 2.0814 - val_precision: 0.0000e+00
# Epoch 6/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.1872 - auc: 0.6455 - f1_score: 0.1840 - loss: 2.6624 - precision: 0.2119
# Epoch 6: val_loss improved from 2.08136 to 2.02399, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.1889 - auc: 0.6456 - f1_score: 0.1858 - loss: 2.6644 - precision: 0.2124 - val_accuracy: 0.3688 - val_auc: 0.7673 - val_f1_score: 0.3455 - val_loss: 2.0240 - val_precision: 0.0000e+00
# Epoch 7/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.2297 - auc: 0.6770 - f1_score: 0.2276 - loss: 2.5107 - precision: 0.2681
# Epoch 7: val_loss improved from 2.02399 to 1.97296, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.2312 - auc: 0.6782 - f1_score: 0.2290 - loss: 2.5059 - precision: 0.2725 - val_accuracy: 0.3938 - val_auc: 0.7891 - val_f1_score: 0.3717 - val_loss: 1.9730 - val_precision: 0.0000e+00
# Epoch 8/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.2370 - auc: 0.6853 - f1_score: 0.2395 - loss: 2.4932 - precision: 0.3211
# Epoch 8: val_loss improved from 1.97296 to 1.92209, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.2368 - auc: 0.6854 - f1_score: 0.2390 - loss: 2.4927 - precision: 0.3200 - val_accuracy: 0.4437 - val_auc: 0.8057 - val_f1_score: 0.4248 - val_loss: 1.9221 - val_precision: 1.0000
# Epoch 9/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.2608 - auc: 0.7102 - f1_score: 0.2537 - loss: 2.3335 - precision: 0.3903
# Epoch 9: val_loss improved from 1.92209 to 1.87266, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.2583 - auc: 0.7089 - f1_score: 0.2519 - loss: 2.3405 - precision: 0.3855 - val_accuracy: 0.4688 - val_auc: 0.8208 - val_f1_score: 0.4452 - val_loss: 1.8727 - val_precision: 1.0000
# Epoch 10/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.2653 - auc: 0.7287 - f1_score: 0.2573 - loss: 2.2487 - precision: 0.3403
# Epoch 10: val_loss improved from 1.87266 to 1.82481, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.2648 - auc: 0.7289 - f1_score: 0.2573 - loss: 2.2488 - precision: 0.3401 - val_accuracy: 0.4750 - val_auc: 0.8333 - val_f1_score: 0.4508 - val_loss: 1.8248 - val_precision: 1.0000
# Epoch 11/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.2947 - auc: 0.7187 - f1_score: 0.2793 - loss: 2.3032 - precision: 0.4064
# Epoch 11: val_loss improved from 1.82481 to 1.77714, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.2935 - auc: 0.7196 - f1_score: 0.2796 - loss: 2.3052 - precision: 0.4001 - val_accuracy: 0.4938 - val_auc: 0.8449 - val_f1_score: 0.4703 - val_loss: 1.7771 - val_precision: 1.0000
# Epoch 12/500
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.2873 - auc: 0.7486 - f1_score: 0.2807 - loss: 2.1701 - precision: 0.3842
# Epoch 12: val_loss improved from 1.77714 to 1.73289, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.2886 - auc: 0.7472 - f1_score: 0.2804 - loss: 2.1748 - precision: 0.3882 - val_accuracy: 0.5000 - val_auc: 0.8564 - val_f1_score: 0.4775 - val_loss: 1.7329 - val_precision: 1.0000
# Epoch 13/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.2761 - auc: 0.7479 - f1_score: 0.2742 - loss: 2.1783 - precision: 0.3356
# Epoch 13: val_loss improved from 1.73289 to 1.68772, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.2776 - auc: 0.7486 - f1_score: 0.2758 - loss: 2.1743 - precision: 0.3383 - val_accuracy: 0.5125 - val_auc: 0.8655 - val_f1_score: 0.4877 - val_loss: 1.6877 - val_precision: 1.0000
# Epoch 14/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.2995 - auc: 0.7505 - f1_score: 0.2869 - loss: 2.1558 - precision: 0.3858
# Epoch 14: val_loss improved from 1.68772 to 1.64409, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.3071 - auc: 0.7543 - f1_score: 0.2954 - loss: 2.1386 - precision: 0.3992 - val_accuracy: 0.5125 - val_auc: 0.8744 - val_f1_score: 0.4895 - val_loss: 1.6441 - val_precision: 1.0000
# Epoch 15/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.3401 - auc: 0.7674 - f1_score: 0.3424 - loss: 2.0785 - precision: 0.4654
# Epoch 15: val_loss improved from 1.64409 to 1.60276, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.3420 - auc: 0.7681 - f1_score: 0.3435 - loss: 2.0735 - precision: 0.4664 - val_accuracy: 0.5312 - val_auc: 0.8819 - val_f1_score: 0.5100 - val_loss: 1.6028 - val_precision: 1.0000
# Epoch 16/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.3984 - auc: 0.7937 - f1_score: 0.3913 - loss: 1.8886 - precision: 0.5507
# Epoch 16: val_loss improved from 1.60276 to 1.56360, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.3968 - auc: 0.7938 - f1_score: 0.3897 - loss: 1.8887 - precision: 0.5497 - val_accuracy: 0.5312 - val_auc: 0.8892 - val_f1_score: 0.5099 - val_loss: 1.5636 - val_precision: 1.0000
# Epoch 17/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.3723 - auc: 0.8089 - f1_score: 0.3598 - loss: 1.8336 - precision: 0.5153
# Epoch 17: val_loss improved from 1.56360 to 1.52553, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.3712 - auc: 0.8086 - f1_score: 0.3593 - loss: 1.8374 - precision: 0.5128 - val_accuracy: 0.5375 - val_auc: 0.8940 - val_f1_score: 0.5161 - val_loss: 1.5255 - val_precision: 1.0000
# Epoch 18/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3738 - auc: 0.8148 - f1_score: 0.3641 - loss: 1.8204 - precision: 0.5194
# Epoch 18: val_loss improved from 1.52553 to 1.49087, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.3750 - auc: 0.8128 - f1_score: 0.3660 - loss: 1.8306 - precision: 0.5190 - val_accuracy: 0.5562 - val_auc: 0.9004 - val_f1_score: 0.5366 - val_loss: 1.4909 - val_precision: 1.0000
# Epoch 19/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.4329 - auc: 0.8198 - f1_score: 0.4179 - loss: 1.7772 - precision: 0.5597
# Epoch 19: val_loss improved from 1.49087 to 1.45584, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.4310 - auc: 0.8194 - f1_score: 0.4172 - loss: 1.7801 - precision: 0.5576 - val_accuracy: 0.5625 - val_auc: 0.9054 - val_f1_score: 0.5389 - val_loss: 1.4558 - val_precision: 1.0000
# Epoch 20/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3649 - auc: 0.7958 - f1_score: 0.3534 - loss: 1.9414 - precision: 0.4344
# Epoch 20: val_loss improved from 1.45584 to 1.42003, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.3654 - auc: 0.7971 - f1_score: 0.3548 - loss: 1.9332 - precision: 0.4422 - val_accuracy: 0.5688 - val_auc: 0.9109 - val_f1_score: 0.5472 - val_loss: 1.4200 - val_precision: 0.9615
# Epoch 21/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4255 - auc: 0.8406 - f1_score: 0.4103 - loss: 1.6760 - precision: 0.5455
# Epoch 21: val_loss improved from 1.42003 to 1.38753, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.4198 - auc: 0.8367 - f1_score: 0.4065 - loss: 1.6974 - precision: 0.5428 - val_accuracy: 0.5750 - val_auc: 0.9157 - val_f1_score: 0.5490 - val_loss: 1.3875 - val_precision: 0.9697
# Epoch 22/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.4566 - auc: 0.8437 - f1_score: 0.4390 - loss: 1.6552 - precision: 0.5828
# Epoch 22: val_loss improved from 1.38753 to 1.35431, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.4458 - auc: 0.8381 - f1_score: 0.4309 - loss: 1.6894 - precision: 0.5689 - val_accuracy: 0.5813 - val_auc: 0.9199 - val_f1_score: 0.5564 - val_loss: 1.3543 - val_precision: 0.9697
# Epoch 23/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4253 - auc: 0.8354 - f1_score: 0.4095 - loss: 1.7105 - precision: 0.5481
# Epoch 23: val_loss improved from 1.35431 to 1.32392, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.4225 - auc: 0.8343 - f1_score: 0.4085 - loss: 1.7157 - precision: 0.5489 - val_accuracy: 0.5750 - val_auc: 0.9246 - val_f1_score: 0.5521 - val_loss: 1.3239 - val_precision: 0.9730
# Epoch 24/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4368 - auc: 0.8359 - f1_score: 0.4223 - loss: 1.7091 - precision: 0.5587
# Epoch 24: val_loss improved from 1.32392 to 1.29542, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.4356 - auc: 0.8364 - f1_score: 0.4224 - loss: 1.7067 - precision: 0.5588 - val_accuracy: 0.5875 - val_auc: 0.9280 - val_f1_score: 0.5616 - val_loss: 1.2954 - val_precision: 0.9487
# Epoch 25/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.4421 - auc: 0.8309 - f1_score: 0.4223 - loss: 1.7092 - precision: 0.6091
# Epoch 25: val_loss improved from 1.29542 to 1.26629, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.4384 - auc: 0.8308 - f1_score: 0.4212 - loss: 1.7121 - precision: 0.6067 - val_accuracy: 0.5813 - val_auc: 0.9318 - val_f1_score: 0.5547 - val_loss: 1.2663 - val_precision: 0.9487
# Epoch 26/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4588 - auc: 0.8431 - f1_score: 0.4422 - loss: 1.6619 - precision: 0.6048
# Epoch 26: val_loss improved from 1.26629 to 1.24147, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.4579 - auc: 0.8435 - f1_score: 0.4422 - loss: 1.6593 - precision: 0.6022 - val_accuracy: 0.5875 - val_auc: 0.9346 - val_f1_score: 0.5647 - val_loss: 1.2415 - val_precision: 0.9286
# Epoch 27/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.4453 - auc: 0.8424 - f1_score: 0.4297 - loss: 1.6690 - precision: 0.5493
# Epoch 27: val_loss improved from 1.24147 to 1.21712, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.4465 - auc: 0.8440 - f1_score: 0.4340 - loss: 1.6587 - precision: 0.5573 - val_accuracy: 0.5875 - val_auc: 0.9374 - val_f1_score: 0.5637 - val_loss: 1.2171 - val_precision: 0.9333
# Epoch 28/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4842 - auc: 0.8676 - f1_score: 0.4673 - loss: 1.5042 - precision: 0.6479
# Epoch 28: val_loss improved from 1.21712 to 1.19466, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.4798 - auc: 0.8662 - f1_score: 0.4641 - loss: 1.5144 - precision: 0.6393 - val_accuracy: 0.5938 - val_auc: 0.9397 - val_f1_score: 0.5694 - val_loss: 1.1947 - val_precision: 0.9149
# Epoch 29/500
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.4511 - auc: 0.8589 - f1_score: 0.4442 - loss: 1.5784 - precision: 0.6290
# Epoch 29: val_loss improved from 1.19466 to 1.17307, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.4605 - auc: 0.8603 - f1_score: 0.4534 - loss: 1.5651 - precision: 0.6334 - val_accuracy: 0.6062 - val_auc: 0.9420 - val_f1_score: 0.5807 - val_loss: 1.1731 - val_precision: 0.9020
# Epoch 30/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4216 - auc: 0.8487 - f1_score: 0.4031 - loss: 1.6456 - precision: 0.5591
# Epoch 30: val_loss improved from 1.17307 to 1.15499, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.4278 - auc: 0.8510 - f1_score: 0.4117 - loss: 1.6310 - precision: 0.5618 - val_accuracy: 0.6187 - val_auc: 0.9434 - val_f1_score: 0.5968 - val_loss: 1.1550 - val_precision: 0.9057
# Epoch 31/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4873 - auc: 0.8685 - f1_score: 0.4769 - loss: 1.5111 - precision: 0.6164
# Epoch 31: val_loss improved from 1.15499 to 1.13589, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.4835 - auc: 0.8679 - f1_score: 0.4750 - loss: 1.5140 - precision: 0.6179 - val_accuracy: 0.6125 - val_auc: 0.9453 - val_f1_score: 0.5906 - val_loss: 1.1359 - val_precision: 0.9138
# Epoch 32/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4415 - auc: 0.8654 - f1_score: 0.4295 - loss: 1.5594 - precision: 0.5856
# Epoch 32: val_loss improved from 1.13589 to 1.11460, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.4423 - auc: 0.8660 - f1_score: 0.4317 - loss: 1.5544 - precision: 0.5879 - val_accuracy: 0.6187 - val_auc: 0.9471 - val_f1_score: 0.5983 - val_loss: 1.1146 - val_precision: 0.9138
# Epoch 33/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5111 - auc: 0.8792 - f1_score: 0.5007 - loss: 1.4403 - precision: 0.6801
# Epoch 33: val_loss improved from 1.11460 to 1.09612, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5030 - auc: 0.8763 - f1_score: 0.4925 - loss: 1.4613 - precision: 0.6633 - val_accuracy: 0.6375 - val_auc: 0.9486 - val_f1_score: 0.6216 - val_loss: 1.0961 - val_precision: 0.9206
# Epoch 34/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5033 - auc: 0.8795 - f1_score: 0.4728 - loss: 1.4452 - precision: 0.6597
# Epoch 34: val_loss improved from 1.09612 to 1.07784, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5017 - auc: 0.8798 - f1_score: 0.4747 - loss: 1.4432 - precision: 0.6568 - val_accuracy: 0.6250 - val_auc: 0.9508 - val_f1_score: 0.6082 - val_loss: 1.0778 - val_precision: 0.9242
# Epoch 35/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5040 - auc: 0.8864 - f1_score: 0.4991 - loss: 1.4226 - precision: 0.6241
# Epoch 35: val_loss improved from 1.07784 to 1.06224, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.5057 - auc: 0.8869 - f1_score: 0.5007 - loss: 1.4184 - precision: 0.6361 - val_accuracy: 0.6438 - val_auc: 0.9520 - val_f1_score: 0.6258 - val_loss: 1.0622 - val_precision: 0.9118
# Epoch 36/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5219 - auc: 0.8765 - f1_score: 0.4954 - loss: 1.4589 - precision: 0.6635
# Epoch 36: val_loss improved from 1.06224 to 1.04903, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5163 - auc: 0.8765 - f1_score: 0.4958 - loss: 1.4600 - precision: 0.6596 - val_accuracy: 0.6438 - val_auc: 0.9531 - val_f1_score: 0.6258 - val_loss: 1.0490 - val_precision: 0.9118
# Epoch 37/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5033 - auc: 0.8579 - f1_score: 0.4913 - loss: 1.5889 - precision: 0.6578
# Epoch 37: val_loss improved from 1.04903 to 1.03373, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5066 - auc: 0.8613 - f1_score: 0.4956 - loss: 1.5663 - precision: 0.6608 - val_accuracy: 0.6375 - val_auc: 0.9548 - val_f1_score: 0.6197 - val_loss: 1.0337 - val_precision: 0.9167
# Epoch 38/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4895 - auc: 0.8895 - f1_score: 0.4827 - loss: 1.3927 - precision: 0.6650
# Epoch 38: val_loss improved from 1.03373 to 1.02065, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.4898 - auc: 0.8894 - f1_score: 0.4838 - loss: 1.3927 - precision: 0.6651 - val_accuracy: 0.6438 - val_auc: 0.9558 - val_f1_score: 0.6253 - val_loss: 1.0207 - val_precision: 0.9178
# Epoch 39/500
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5100 - auc: 0.8713 - f1_score: 0.4898 - loss: 1.4877 - precision: 0.6186
# Epoch 39: val_loss improved from 1.02065 to 1.01045, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.5112 - auc: 0.8736 - f1_score: 0.4962 - loss: 1.4747 - precision: 0.6285 - val_accuracy: 0.6438 - val_auc: 0.9564 - val_f1_score: 0.6258 - val_loss: 1.0105 - val_precision: 0.9189
# Epoch 40/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5401 - auc: 0.8821 - f1_score: 0.5305 - loss: 1.4052 - precision: 0.6877
# Epoch 40: val_loss improved from 1.01045 to 0.99949, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5406 - auc: 0.8842 - f1_score: 0.5316 - loss: 1.3951 - precision: 0.6886 - val_accuracy: 0.6438 - val_auc: 0.9572 - val_f1_score: 0.6258 - val_loss: 0.9995 - val_precision: 0.9067
# Epoch 41/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5401 - auc: 0.8943 - f1_score: 0.5217 - loss: 1.3624 - precision: 0.6737
# Epoch 41: val_loss improved from 0.99949 to 0.99022, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5408 - auc: 0.8952 - f1_score: 0.5248 - loss: 1.3556 - precision: 0.6793 - val_accuracy: 0.6438 - val_auc: 0.9577 - val_f1_score: 0.6268 - val_loss: 0.9902 - val_precision: 0.9067
# Epoch 42/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5416 - auc: 0.8989 - f1_score: 0.5339 - loss: 1.3250 - precision: 0.6834
# Epoch 42: val_loss improved from 0.99022 to 0.97951, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5444 - auc: 0.9007 - f1_score: 0.5365 - loss: 1.3120 - precision: 0.6915 - val_accuracy: 0.6438 - val_auc: 0.9586 - val_f1_score: 0.6268 - val_loss: 0.9795 - val_precision: 0.9067
# Epoch 43/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5520 - auc: 0.8973 - f1_score: 0.5448 - loss: 1.3306 - precision: 0.6998
# Epoch 43: val_loss improved from 0.97951 to 0.96700, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5526 - auc: 0.8975 - f1_score: 0.5458 - loss: 1.3297 - precision: 0.6992 - val_accuracy: 0.6375 - val_auc: 0.9597 - val_f1_score: 0.6208 - val_loss: 0.9670 - val_precision: 0.8974
# Epoch 44/500
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5400 - auc: 0.9003 - f1_score: 0.5227 - loss: 1.3218 - precision: 0.6834
# Epoch 44: val_loss improved from 0.96700 to 0.95531, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5357 - auc: 0.8997 - f1_score: 0.5222 - loss: 1.3261 - precision: 0.6757 - val_accuracy: 0.6438 - val_auc: 0.9606 - val_f1_score: 0.6265 - val_loss: 0.9553 - val_precision: 0.9103
# Epoch 45/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5497 - auc: 0.9123 - f1_score: 0.5466 - loss: 1.2347 - precision: 0.7457
# Epoch 45: val_loss improved from 0.95531 to 0.94407, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5482 - auc: 0.9111 - f1_score: 0.5447 - loss: 1.2441 - precision: 0.7374 - val_accuracy: 0.6562 - val_auc: 0.9618 - val_f1_score: 0.6406 - val_loss: 0.9441 - val_precision: 0.9231
# Epoch 46/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5792 - auc: 0.9107 - f1_score: 0.5873 - loss: 1.2552 - precision: 0.7175
# Epoch 46: val_loss improved from 0.94407 to 0.93552, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5751 - auc: 0.9099 - f1_score: 0.5804 - loss: 1.2610 - precision: 0.7132 - val_accuracy: 0.6687 - val_auc: 0.9623 - val_f1_score: 0.6545 - val_loss: 0.9355 - val_precision: 0.9231
# Epoch 47/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6184 - auc: 0.9238 - f1_score: 0.6119 - loss: 1.1548 - precision: 0.7646
# Epoch 47: val_loss improved from 0.93552 to 0.92707, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6070 - auc: 0.9193 - f1_score: 0.6015 - loss: 1.1859 - precision: 0.7499 - val_accuracy: 0.6687 - val_auc: 0.9630 - val_f1_score: 0.6550 - val_loss: 0.9271 - val_precision: 0.9241
# Epoch 48/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5541 - auc: 0.9078 - f1_score: 0.5343 - loss: 1.2589 - precision: 0.7166
# Epoch 48: val_loss improved from 0.92707 to 0.91719, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5561 - auc: 0.9079 - f1_score: 0.5409 - loss: 1.2606 - precision: 0.7132 - val_accuracy: 0.6687 - val_auc: 0.9638 - val_f1_score: 0.6532 - val_loss: 0.9172 - val_precision: 0.9241
# Epoch 49/500
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6037 - auc: 0.9241 - f1_score: 0.5879 - loss: 1.1416 - precision: 0.7466
# Epoch 49: val_loss improved from 0.91719 to 0.90839, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5941 - auc: 0.9212 - f1_score: 0.5813 - loss: 1.1666 - precision: 0.7342 - val_accuracy: 0.6687 - val_auc: 0.9643 - val_f1_score: 0.6532 - val_loss: 0.9084 - val_precision: 0.9125
# Epoch 50/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5611 - auc: 0.9026 - f1_score: 0.5520 - loss: 1.2981 - precision: 0.6778
# Epoch 50: val_loss improved from 0.90839 to 0.89724, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5601 - auc: 0.9037 - f1_score: 0.5516 - loss: 1.2914 - precision: 0.6812 - val_accuracy: 0.6687 - val_auc: 0.9653 - val_f1_score: 0.6565 - val_loss: 0.8972 - val_precision: 0.9259
# Epoch 51/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5755 - auc: 0.9098 - f1_score: 0.5803 - loss: 1.2322 - precision: 0.7746
# Epoch 51: val_loss improved from 0.89724 to 0.89011, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5763 - auc: 0.9118 - f1_score: 0.5786 - loss: 1.2233 - precision: 0.7679 - val_accuracy: 0.6625 - val_auc: 0.9657 - val_f1_score: 0.6522 - val_loss: 0.8901 - val_precision: 0.9277
# Epoch 52/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5831 - auc: 0.9071 - f1_score: 0.5813 - loss: 1.2623 - precision: 0.7334
# Epoch 52: val_loss improved from 0.89011 to 0.88242, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5876 - auc: 0.9107 - f1_score: 0.5853 - loss: 1.2378 - precision: 0.7374 - val_accuracy: 0.6750 - val_auc: 0.9662 - val_f1_score: 0.6640 - val_loss: 0.8824 - val_precision: 0.9167
# Epoch 53/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6160 - auc: 0.9225 - f1_score: 0.5974 - loss: 1.1612 - precision: 0.7448
# Epoch 53: val_loss improved from 0.88242 to 0.87499, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6153 - auc: 0.9225 - f1_score: 0.5989 - loss: 1.1609 - precision: 0.7469 - val_accuracy: 0.6938 - val_auc: 0.9666 - val_f1_score: 0.6878 - val_loss: 0.8750 - val_precision: 0.9167
# Epoch 54/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5728 - auc: 0.9153 - f1_score: 0.5652 - loss: 1.2141 - precision: 0.7586
# Epoch 54: val_loss improved from 0.87499 to 0.86695, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5766 - auc: 0.9163 - f1_score: 0.5695 - loss: 1.2077 - precision: 0.7542 - val_accuracy: 0.6938 - val_auc: 0.9670 - val_f1_score: 0.6894 - val_loss: 0.8669 - val_precision: 0.9167
# Epoch 55/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5648 - auc: 0.9214 - f1_score: 0.5634 - loss: 1.1759 - precision: 0.7028
# Epoch 55: val_loss improved from 0.86695 to 0.86074, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5666 - auc: 0.9214 - f1_score: 0.5646 - loss: 1.1763 - precision: 0.7062 - val_accuracy: 0.6938 - val_auc: 0.9674 - val_f1_score: 0.6881 - val_loss: 0.8607 - val_precision: 0.9176
# Epoch 56/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6483 - auc: 0.9361 - f1_score: 0.6455 - loss: 1.0620 - precision: 0.7956
# Epoch 56: val_loss improved from 0.86074 to 0.85359, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6453 - auc: 0.9359 - f1_score: 0.6423 - loss: 1.0647 - precision: 0.7911 - val_accuracy: 0.6938 - val_auc: 0.9677 - val_f1_score: 0.6900 - val_loss: 0.8536 - val_precision: 0.9186
# Epoch 57/500
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5903 - auc: 0.9212 - f1_score: 0.5890 - loss: 1.1774 - precision: 0.7555
# Epoch 57: val_loss improved from 0.85359 to 0.84625, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5908 - auc: 0.9205 - f1_score: 0.5889 - loss: 1.1824 - precision: 0.7487 - val_accuracy: 0.6938 - val_auc: 0.9681 - val_f1_score: 0.6884 - val_loss: 0.8463 - val_precision: 0.9186
# Epoch 58/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6127 - auc: 0.9312 - f1_score: 0.6037 - loss: 1.1007 - precision: 0.7464
# Epoch 58: val_loss improved from 0.84625 to 0.84086, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6037 - auc: 0.9292 - f1_score: 0.5967 - loss: 1.1155 - precision: 0.7437 - val_accuracy: 0.7000 - val_auc: 0.9685 - val_f1_score: 0.6944 - val_loss: 0.8409 - val_precision: 0.9205
# Epoch 59/500
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5929 - auc: 0.9188 - f1_score: 0.5867 - loss: 1.1879 - precision: 0.7236
# Epoch 59: val_loss improved from 0.84086 to 0.83630, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5913 - auc: 0.9199 - f1_score: 0.5860 - loss: 1.1819 - precision: 0.7188 - val_accuracy: 0.6875 - val_auc: 0.9687 - val_f1_score: 0.6762 - val_loss: 0.8363 - val_precision: 0.9011
# Epoch 60/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6146 - auc: 0.9225 - f1_score: 0.6115 - loss: 1.1558 - precision: 0.7266
# Epoch 60: val_loss improved from 0.83630 to 0.83399, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6158 - auc: 0.9230 - f1_score: 0.6130 - loss: 1.1527 - precision: 0.7291 - val_accuracy: 0.6938 - val_auc: 0.9690 - val_f1_score: 0.6881 - val_loss: 0.8340 - val_precision: 0.9022
# Epoch 61/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6189 - auc: 0.9320 - f1_score: 0.6123 - loss: 1.0953 - precision: 0.7398
# Epoch 61: val_loss improved from 0.83399 to 0.82938, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6227 - auc: 0.9331 - f1_score: 0.6167 - loss: 1.0857 - precision: 0.7479 - val_accuracy: 0.7063 - val_auc: 0.9692 - val_f1_score: 0.7023 - val_loss: 0.8294 - val_precision: 0.9121
# Epoch 62/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6039 - auc: 0.9279 - f1_score: 0.5973 - loss: 1.1375 - precision: 0.7021
# Epoch 62: val_loss improved from 0.82938 to 0.82294, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5999 - auc: 0.9279 - f1_score: 0.5942 - loss: 1.1376 - precision: 0.7021 - val_accuracy: 0.7125 - val_auc: 0.9698 - val_f1_score: 0.7076 - val_loss: 0.8229 - val_precision: 0.9022
# Epoch 63/500
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5674 - auc: 0.9307 - f1_score: 0.5608 - loss: 1.1146 - precision: 0.7762
# Epoch 63: val_loss improved from 0.82294 to 0.81963, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5760 - auc: 0.9319 - f1_score: 0.5696 - loss: 1.1018 - precision: 0.7813 - val_accuracy: 0.7125 - val_auc: 0.9695 - val_f1_score: 0.7076 - val_loss: 0.8196 - val_precision: 0.9022
# Epoch 64/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5915 - auc: 0.9224 - f1_score: 0.5785 - loss: 1.1643 - precision: 0.7333
# Epoch 64: val_loss improved from 0.81963 to 0.81637, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5998 - auc: 0.9241 - f1_score: 0.5895 - loss: 1.1491 - precision: 0.7383 - val_accuracy: 0.7063 - val_auc: 0.9695 - val_f1_score: 0.7014 - val_loss: 0.8164 - val_precision: 0.9032
# Epoch 65/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6384 - auc: 0.9440 - f1_score: 0.6330 - loss: 1.0065 - precision: 0.7812
# Epoch 65: val_loss improved from 0.81637 to 0.81356, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6400 - auc: 0.9438 - f1_score: 0.6349 - loss: 1.0077 - precision: 0.7778 - val_accuracy: 0.7063 - val_auc: 0.9696 - val_f1_score: 0.7014 - val_loss: 0.8136 - val_precision: 0.9032
# Epoch 66/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6670 - auc: 0.9437 - f1_score: 0.6624 - loss: 0.9919 - precision: 0.7844
# Epoch 66: val_loss improved from 0.81356 to 0.80783, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6618 - auc: 0.9430 - f1_score: 0.6574 - loss: 0.9993 - precision: 0.7820 - val_accuracy: 0.7000 - val_auc: 0.9698 - val_f1_score: 0.6933 - val_loss: 0.8078 - val_precision: 0.9053
# Epoch 67/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6461 - auc: 0.9465 - f1_score: 0.6375 - loss: 0.9860 - precision: 0.7697
# Epoch 67: val_loss improved from 0.80783 to 0.80328, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.6451 - auc: 0.9461 - f1_score: 0.6369 - loss: 0.9890 - precision: 0.7691 - val_accuracy: 0.6812 - val_auc: 0.9702 - val_f1_score: 0.6695 - val_loss: 0.8033 - val_precision: 0.9053
# Epoch 68/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6254 - auc: 0.9423 - f1_score: 0.6175 - loss: 1.0145 - precision: 0.7691
# Epoch 68: val_loss improved from 0.80328 to 0.79757, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.6265 - auc: 0.9411 - f1_score: 0.6198 - loss: 1.0218 - precision: 0.7671 - val_accuracy: 0.6750 - val_auc: 0.9705 - val_f1_score: 0.6636 - val_loss: 0.7976 - val_precision: 0.9053
# Epoch 69/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6814 - auc: 0.9505 - f1_score: 0.6803 - loss: 0.9518 - precision: 0.8016
# Epoch 69: val_loss improved from 0.79757 to 0.79040, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6796 - auc: 0.9503 - f1_score: 0.6788 - loss: 0.9533 - precision: 0.8004 - val_accuracy: 0.7000 - val_auc: 0.9714 - val_f1_score: 0.6927 - val_loss: 0.7904 - val_precision: 0.9053
# Epoch 70/500
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6671 - auc: 0.9367 - f1_score: 0.6586 - loss: 1.0473 - precision: 0.7695
# Epoch 70: val_loss improved from 0.79040 to 0.78633, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6654 - auc: 0.9375 - f1_score: 0.6584 - loss: 1.0412 - precision: 0.7747 - val_accuracy: 0.7188 - val_auc: 0.9716 - val_f1_score: 0.7107 - val_loss: 0.7863 - val_precision: 0.8969
# Epoch 71/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6660 - auc: 0.9469 - f1_score: 0.6525 - loss: 0.9756 - precision: 0.7851
# Epoch 71: val_loss improved from 0.78633 to 0.78256, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6674 - auc: 0.9470 - f1_score: 0.6574 - loss: 0.9746 - precision: 0.7901 - val_accuracy: 0.7125 - val_auc: 0.9717 - val_f1_score: 0.7068 - val_loss: 0.7826 - val_precision: 0.8878
# Epoch 72/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6417 - auc: 0.9377 - f1_score: 0.6397 - loss: 1.0420 - precision: 0.7715
# Epoch 72: val_loss improved from 0.78256 to 0.77975, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.6414 - auc: 0.9378 - f1_score: 0.6395 - loss: 1.0417 - precision: 0.7722 - val_accuracy: 0.7125 - val_auc: 0.9717 - val_f1_score: 0.7067 - val_loss: 0.7798 - val_precision: 0.8900
# Epoch 73/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6334 - auc: 0.9471 - f1_score: 0.6202 - loss: 0.9700 - precision: 0.8059
# Epoch 73: val_loss improved from 0.77975 to 0.77553, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6360 - auc: 0.9471 - f1_score: 0.6254 - loss: 0.9696 - precision: 0.8050 - val_accuracy: 0.7250 - val_auc: 0.9721 - val_f1_score: 0.7183 - val_loss: 0.7755 - val_precision: 0.8812
# Epoch 74/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6406 - auc: 0.9398 - f1_score: 0.6198 - loss: 1.0290 - precision: 0.7978
# Epoch 74: val_loss improved from 0.77553 to 0.77116, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.6474 - auc: 0.9412 - f1_score: 0.6309 - loss: 1.0182 - precision: 0.8041 - val_accuracy: 0.7312 - val_auc: 0.9722 - val_f1_score: 0.7272 - val_loss: 0.7712 - val_precision: 0.8911
# Epoch 75/500
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6758 - auc: 0.9505 - f1_score: 0.6711 - loss: 0.9543 - precision: 0.7863
# Epoch 75: val_loss improved from 0.77116 to 0.76408, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6640 - auc: 0.9479 - f1_score: 0.6603 - loss: 0.9739 - precision: 0.7774 - val_accuracy: 0.7250 - val_auc: 0.9727 - val_f1_score: 0.7200 - val_loss: 0.7641 - val_precision: 0.8922
# Epoch 76/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6299 - auc: 0.9491 - f1_score: 0.6210 - loss: 0.9739 - precision: 0.7599
# Epoch 76: val_loss improved from 0.76408 to 0.75821, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6304 - auc: 0.9488 - f1_score: 0.6220 - loss: 0.9752 - precision: 0.7613 - val_accuracy: 0.7312 - val_auc: 0.9731 - val_f1_score: 0.7262 - val_loss: 0.7582 - val_precision: 0.8932
# Epoch 77/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6586 - auc: 0.9448 - f1_score: 0.6611 - loss: 0.9929 - precision: 0.7604
# Epoch 77: val_loss improved from 0.75821 to 0.75556, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6632 - auc: 0.9461 - f1_score: 0.6644 - loss: 0.9820 - precision: 0.7660 - val_accuracy: 0.7250 - val_auc: 0.9732 - val_f1_score: 0.7177 - val_loss: 0.7556 - val_precision: 0.8942
# Epoch 78/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6273 - auc: 0.9389 - f1_score: 0.6258 - loss: 1.0316 - precision: 0.7890
# Epoch 78: val_loss improved from 0.75556 to 0.75480, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.6293 - auc: 0.9393 - f1_score: 0.6279 - loss: 1.0288 - precision: 0.7907 - val_accuracy: 0.7188 - val_auc: 0.9730 - val_f1_score: 0.7117 - val_loss: 0.7548 - val_precision: 0.8942
# Epoch 79/500
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6803 - auc: 0.9494 - f1_score: 0.6669 - loss: 0.9464 - precision: 0.7661
# Epoch 79: val_loss improved from 0.75480 to 0.75137, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6778 - auc: 0.9497 - f1_score: 0.6676 - loss: 0.9440 - precision: 0.7779 - val_accuracy: 0.7188 - val_auc: 0.9731 - val_f1_score: 0.7117 - val_loss: 0.7514 - val_precision: 0.9029
# Epoch 80/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6431 - auc: 0.9460 - f1_score: 0.6321 - loss: 0.9807 - precision: 0.7768
# Epoch 80: val_loss improved from 0.75137 to 0.75097, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6489 - auc: 0.9471 - f1_score: 0.6395 - loss: 0.9714 - precision: 0.7792 - val_accuracy: 0.7125 - val_auc: 0.9729 - val_f1_score: 0.7048 - val_loss: 0.7510 - val_precision: 0.8942
# Epoch 81/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6959 - auc: 0.9571 - f1_score: 0.6934 - loss: 0.8970 - precision: 0.7990
# Epoch 81: val_loss improved from 0.75097 to 0.74678, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6947 - auc: 0.9570 - f1_score: 0.6923 - loss: 0.8982 - precision: 0.7994 - val_accuracy: 0.7063 - val_auc: 0.9732 - val_f1_score: 0.6994 - val_loss: 0.7468 - val_precision: 0.8942
# Epoch 82/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6649 - auc: 0.9568 - f1_score: 0.6554 - loss: 0.8899 - precision: 0.7968
# Epoch 82: val_loss improved from 0.74678 to 0.74212, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6636 - auc: 0.9541 - f1_score: 0.6562 - loss: 0.9111 - precision: 0.7919 - val_accuracy: 0.7188 - val_auc: 0.9740 - val_f1_score: 0.7125 - val_loss: 0.7421 - val_precision: 0.8952
# Epoch 83/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6957 - auc: 0.9519 - f1_score: 0.6878 - loss: 0.9251 - precision: 0.7805
# Epoch 83: val_loss improved from 0.74212 to 0.74063, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.6900 - auc: 0.9524 - f1_score: 0.6840 - loss: 0.9229 - precision: 0.7849 - val_accuracy: 0.7312 - val_auc: 0.9739 - val_f1_score: 0.7223 - val_loss: 0.7406 - val_precision: 0.8942
# Epoch 84/500
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6729 - auc: 0.9495 - f1_score: 0.6662 - loss: 0.9486 - precision: 0.7940
# Epoch 84: val_loss improved from 0.74063 to 0.73752, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.6768 - auc: 0.9502 - f1_score: 0.6724 - loss: 0.9415 - precision: 0.7933 - val_accuracy: 0.7375 - val_auc: 0.9742 - val_f1_score: 0.7291 - val_loss: 0.7375 - val_precision: 0.8942
# Epoch 85/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6974 - auc: 0.9602 - f1_score: 0.6785 - loss: 0.8579 - precision: 0.8311
# Epoch 85: val_loss improved from 0.73752 to 0.73435, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.6983 - auc: 0.9595 - f1_score: 0.6841 - loss: 0.8611 - precision: 0.8322 - val_accuracy: 0.7375 - val_auc: 0.9743 - val_f1_score: 0.7291 - val_loss: 0.7344 - val_precision: 0.8952
# Epoch 86/500
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7243 - auc: 0.9633 - f1_score: 0.7165 - loss: 0.8253 - precision: 0.8363
# Epoch 86: val_loss improved from 0.73435 to 0.72936, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7191 - auc: 0.9607 - f1_score: 0.7123 - loss: 0.8465 - precision: 0.8341 - val_accuracy: 0.7312 - val_auc: 0.9748 - val_f1_score: 0.7240 - val_loss: 0.7294 - val_precision: 0.8972
# Epoch 87/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7292 - auc: 0.9686 - f1_score: 0.7244 - loss: 0.7737 - precision: 0.8470
# Epoch 87: val_loss improved from 0.72936 to 0.72637, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7240 - auc: 0.9669 - f1_score: 0.7201 - loss: 0.7913 - precision: 0.8393 - val_accuracy: 0.7250 - val_auc: 0.9749 - val_f1_score: 0.7158 - val_loss: 0.7264 - val_precision: 0.8899
# Epoch 88/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6794 - auc: 0.9534 - f1_score: 0.6730 - loss: 0.9202 - precision: 0.7771
# Epoch 88: val_loss improved from 0.72637 to 0.72334, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6808 - auc: 0.9537 - f1_score: 0.6744 - loss: 0.9168 - precision: 0.7791 - val_accuracy: 0.7312 - val_auc: 0.9745 - val_f1_score: 0.7219 - val_loss: 0.7233 - val_precision: 0.8909
# Epoch 89/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6922 - auc: 0.9612 - f1_score: 0.6888 - loss: 0.8532 - precision: 0.8197
# Epoch 89: val_loss improved from 0.72334 to 0.72161, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.6929 - auc: 0.9616 - f1_score: 0.6897 - loss: 0.8501 - precision: 0.8209 - val_accuracy: 0.7250 - val_auc: 0.9746 - val_f1_score: 0.7154 - val_loss: 0.7216 - val_precision: 0.8991
# Epoch 90/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7376 - auc: 0.9666 - f1_score: 0.7332 - loss: 0.7906 - precision: 0.8495
# Epoch 90: val_loss improved from 0.72161 to 0.71875, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.7338 - auc: 0.9659 - f1_score: 0.7300 - loss: 0.7971 - precision: 0.8442 - val_accuracy: 0.7125 - val_auc: 0.9750 - val_f1_score: 0.7036 - val_loss: 0.7187 - val_precision: 0.8909
# Epoch 91/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6612 - auc: 0.9567 - f1_score: 0.6571 - loss: 0.8922 - precision: 0.7805
# Epoch 91: val_loss improved from 0.71875 to 0.71296, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.6717 - auc: 0.9579 - f1_score: 0.6688 - loss: 0.8806 - precision: 0.7881 - val_accuracy: 0.7125 - val_auc: 0.9754 - val_f1_score: 0.7036 - val_loss: 0.7130 - val_precision: 0.9000
# Epoch 92/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7163 - auc: 0.9628 - f1_score: 0.7095 - loss: 0.8190 - precision: 0.8499
# Epoch 92: val_loss improved from 0.71296 to 0.70771, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7155 - auc: 0.9623 - f1_score: 0.7098 - loss: 0.8242 - precision: 0.8512 - val_accuracy: 0.7125 - val_auc: 0.9758 - val_f1_score: 0.7036 - val_loss: 0.7077 - val_precision: 0.9009
# Epoch 93/500
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6979 - auc: 0.9562 - f1_score: 0.6961 - loss: 0.8918 - precision: 0.8565
# Epoch 93: val_loss improved from 0.70771 to 0.70456, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7032 - auc: 0.9579 - f1_score: 0.7016 - loss: 0.8758 - precision: 0.8455 - val_accuracy: 0.7125 - val_auc: 0.9759 - val_f1_score: 0.7036 - val_loss: 0.7046 - val_precision: 0.9027
# Epoch 94/500
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6853 - auc: 0.9598 - f1_score: 0.6746 - loss: 0.8625 - precision: 0.8247
# Epoch 94: val_loss improved from 0.70456 to 0.70159, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6956 - auc: 0.9616 - f1_score: 0.6876 - loss: 0.8467 - precision: 0.8302 - val_accuracy: 0.7125 - val_auc: 0.9761 - val_f1_score: 0.7033 - val_loss: 0.7016 - val_precision: 0.9027
# Epoch 95/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7033 - auc: 0.9570 - f1_score: 0.7011 - loss: 0.8759 - precision: 0.7985
# Epoch 95: val_loss improved from 0.70159 to 0.70095, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7031 - auc: 0.9569 - f1_score: 0.7010 - loss: 0.8768 - precision: 0.7985 - val_accuracy: 0.7250 - val_auc: 0.9761 - val_f1_score: 0.7184 - val_loss: 0.7009 - val_precision: 0.8870
# Epoch 96/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6739 - auc: 0.9542 - f1_score: 0.6701 - loss: 0.9074 - precision: 0.7953
# Epoch 96: val_loss did not improve from 0.70095
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.6771 - auc: 0.9552 - f1_score: 0.6739 - loss: 0.8992 - precision: 0.7968 - val_accuracy: 0.7250 - val_auc: 0.9760 - val_f1_score: 0.7159 - val_loss: 0.7012 - val_precision: 0.8860
# Epoch 97/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7555 - auc: 0.9677 - f1_score: 0.7550 - loss: 0.7862 - precision: 0.8545
# Epoch 97: val_loss improved from 0.70095 to 0.69892, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7512 - auc: 0.9673 - f1_score: 0.7510 - loss: 0.7877 - precision: 0.8509 - val_accuracy: 0.7250 - val_auc: 0.9762 - val_f1_score: 0.7159 - val_loss: 0.6989 - val_precision: 0.8879
# Epoch 98/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6963 - auc: 0.9636 - f1_score: 0.6875 - loss: 0.8369 - precision: 0.7840
# Epoch 98: val_loss improved from 0.69892 to 0.69868, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.6988 - auc: 0.9633 - f1_score: 0.6921 - loss: 0.8363 - precision: 0.7895 - val_accuracy: 0.7188 - val_auc: 0.9757 - val_f1_score: 0.7105 - val_loss: 0.6987 - val_precision: 0.8898
# Epoch 99/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7044 - auc: 0.9565 - f1_score: 0.6958 - loss: 0.8843 - precision: 0.8070
# Epoch 99: val_loss improved from 0.69868 to 0.69656, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.7053 - auc: 0.9569 - f1_score: 0.6973 - loss: 0.8801 - precision: 0.8085 - val_accuracy: 0.7188 - val_auc: 0.9759 - val_f1_score: 0.7113 - val_loss: 0.6966 - val_precision: 0.8898
# Epoch 100/500
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7008 - auc: 0.9625 - f1_score: 0.6828 - loss: 0.8305 - precision: 0.8107
# Epoch 100: val_loss improved from 0.69656 to 0.69266, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7001 - auc: 0.9624 - f1_score: 0.6888 - loss: 0.8313 - precision: 0.8170 - val_accuracy: 0.7250 - val_auc: 0.9762 - val_f1_score: 0.7161 - val_loss: 0.6927 - val_precision: 0.8833
# Epoch 101/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7077 - auc: 0.9677 - f1_score: 0.7088 - loss: 0.7837 - precision: 0.8266
# Epoch 101: val_loss improved from 0.69266 to 0.68816, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.7080 - auc: 0.9674 - f1_score: 0.7087 - loss: 0.7861 - precision: 0.8265 - val_accuracy: 0.7500 - val_auc: 0.9767 - val_f1_score: 0.7428 - val_loss: 0.6882 - val_precision: 0.8833
# Epoch 102/500
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7521 - auc: 0.9738 - f1_score: 0.7433 - loss: 0.7125 - precision: 0.8846
# Epoch 102: val_loss improved from 0.68816 to 0.68437, saving model to best_model_gtzan_v2.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7528 - auc: 0.9731 - f1_score: 0.7470 - loss: 0.7192 - precision: 0.8786 - val_accuracy: 0.7563 - val_auc: 0.9771 - val_f1_score: 0.7497 - val_loss: 0.6844 - val_precision: 0.8760
# Epoch 103/500
# ...
# Epoch 268/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9344 - auc: 0.9974 - f1_score: 0.9341 - loss: 0.2418 - precision: 0.9644
# Epoch 268: val_loss did not improve from 0.55191
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9333 - auc: 0.9973 - f1_score: 0.9331 - loss: 0.2463 - precision: 0.9623 - val_accuracy: 0.8062 - val_auc: 0.9804 - val_f1_score: 0.8036 - val_loss: 0.5545 - val_precision: 0.8690
# Epoch 269/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9323 - auc: 0.9976 - f1_score: 0.9289 - loss: 0.2458 - precision: 0.9668
# Epoch 269: val_loss did not improve from 0.55191
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9332 - auc: 0.9977 - f1_score: 0.9301 - loss: 0.2449 - precision: 0.9669 - val_accuracy: 0.8000 - val_auc: 0.9796 - val_f1_score: 0.7979 - val_loss: 0.5653 - val_precision: 0.8611
# Epoch 270/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9384 - auc: 0.9984 - f1_score: 0.9385 - loss: 0.2173 - precision: 0.9602
# Epoch 270: val_loss did not improve from 0.55191
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9374 - auc: 0.9984 - f1_score: 0.9375 - loss: 0.2194 - precision: 0.9594 - val_accuracy: 0.8000 - val_auc: 0.9794 - val_f1_score: 0.7976 - val_loss: 0.5710 - val_precision: 0.8611
# Epoch 271/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9525 - auc: 0.9971 - f1_score: 0.9437 - loss: 0.2524 - precision: 0.9748
# Epoch 271: val_loss did not improve from 0.55191
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9524 - auc: 0.9972 - f1_score: 0.9444 - loss: 0.2504 - precision: 0.9745 - val_accuracy: 0.8062 - val_auc: 0.9796 - val_f1_score: 0.8037 - val_loss: 0.5681 - val_precision: 0.8611
# Epoch 272/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9477 - auc: 0.9988 - f1_score: 0.9454 - loss: 0.2093 - precision: 0.9633
# Epoch 272: val_loss did not improve from 0.55191
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9467 - auc: 0.9987 - f1_score: 0.9450 - loss: 0.2119 - precision: 0.9638 - val_accuracy: 0.8062 - val_auc: 0.9797 - val_f1_score: 0.8016 - val_loss: 0.5640 - val_precision: 0.8671
# Epoch 273/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9254 - auc: 0.9956 - f1_score: 0.9248 - loss: 0.2826 - precision: 0.9443
# Epoch 273: val_loss did not improve from 0.55191
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9255 - auc: 0.9956 - f1_score: 0.9250 - loss: 0.2822 - precision: 0.9448 - val_accuracy: 0.8062 - val_auc: 0.9799 - val_f1_score: 0.8014 - val_loss: 0.5648 - val_precision: 0.8681
# Epoch 274/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9418 - auc: 0.9977 - f1_score: 0.9419 - loss: 0.2285 - precision: 0.9631
# Epoch 274: val_loss did not improve from 0.55191
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9410 - auc: 0.9977 - f1_score: 0.9410 - loss: 0.2300 - precision: 0.9627 - val_accuracy: 0.8000 - val_auc: 0.9798 - val_f1_score: 0.7960 - val_loss: 0.5661 - val_precision: 0.8803
# Epoch 275/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9477 - auc: 0.9987 - f1_score: 0.9456 - loss: 0.1984 - precision: 0.9568
# Epoch 275: val_loss did not improve from 0.55191
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9467 - auc: 0.9985 - f1_score: 0.9451 - loss: 0.2055 - precision: 0.9574 - val_accuracy: 0.8062 - val_auc: 0.9793 - val_f1_score: 0.8035 - val_loss: 0.5702 - val_precision: 0.8681
# Epoch 276/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9509 - auc: 0.9978 - f1_score: 0.9517 - loss: 0.2112 - precision: 0.9652
# Epoch 276: val_loss did not improve from 0.55191
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9501 - auc: 0.9978 - f1_score: 0.9508 - loss: 0.2117 - precision: 0.9645 - val_accuracy: 0.8062 - val_auc: 0.9792 - val_f1_score: 0.8044 - val_loss: 0.5705 - val_precision: 0.8621
# Epoch 277/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9549 - auc: 0.9986 - f1_score: 0.9524 - loss: 0.2013 - precision: 0.9658
# Epoch 277: val_loss did not improve from 0.55191
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9499 - auc: 0.9984 - f1_score: 0.9480 - loss: 0.2093 - precision: 0.9639 - val_accuracy: 0.7937 - val_auc: 0.9793 - val_f1_score: 0.7928 - val_loss: 0.5721 - val_precision: 0.8493
# Epoch 278/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9451 - auc: 0.9984 - f1_score: 0.9438 - loss: 0.2204 - precision: 0.9670
# Epoch 278: val_loss did not improve from 0.55191
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9443 - auc: 0.9983 - f1_score: 0.9432 - loss: 0.2221 - precision: 0.9667 - val_accuracy: 0.8000 - val_auc: 0.9795 - val_f1_score: 0.7996 - val_loss: 0.5678 - val_precision: 0.8552
# Epoch 279/500
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9235 - auc: 0.9974 - f1_score: 0.9184 - loss: 0.2529 - precision: 0.9515
# Epoch 279: val_loss did not improve from 0.55191
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9285 - auc: 0.9974 - f1_score: 0.9253 - loss: 0.2502 - precision: 0.9547 - val_accuracy: 0.7937 - val_auc: 0.9793 - val_f1_score: 0.7925 - val_loss: 0.5699 - val_precision: 0.8611
# Epoch 280/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9393 - auc: 0.9977 - f1_score: 0.9375 - loss: 0.2368 - precision: 0.9671
# Epoch 280: val_loss did not improve from 0.55191
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9403 - auc: 0.9977 - f1_score: 0.9386 - loss: 0.2351 - precision: 0.9677 - val_accuracy: 0.8000 - val_auc: 0.9787 - val_f1_score: 0.7996 - val_loss: 0.5742 - val_precision: 0.8662
# Epoch 281/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9444 - auc: 0.9986 - f1_score: 0.9443 - loss: 0.2173 - precision: 0.9755
# Epoch 281: val_loss did not improve from 0.55191
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9445 - auc: 0.9985 - f1_score: 0.9446 - loss: 0.2194 - precision: 0.9733 - val_accuracy: 0.8000 - val_auc: 0.9789 - val_f1_score: 0.7997 - val_loss: 0.5716 - val_precision: 0.8611
# Epoch 282/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9500 - auc: 0.9987 - f1_score: 0.9500 - loss: 0.2001 - precision: 0.9733
# Epoch 282: val_loss did not improve from 0.55191
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9501 - auc: 0.9987 - f1_score: 0.9501 - loss: 0.2002 - precision: 0.9730 - val_accuracy: 0.8125 - val_auc: 0.9792 - val_f1_score: 0.8112 - val_loss: 0.5661 - val_precision: 0.8741
# Epoch 283/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9451 - auc: 0.9982 - f1_score: 0.9458 - loss: 0.2296 - precision: 0.9746
# Epoch 283: val_loss did not improve from 0.55191
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9457 - auc: 0.9982 - f1_score: 0.9463 - loss: 0.2286 - precision: 0.9745 - val_accuracy: 0.8000 - val_auc: 0.9795 - val_f1_score: 0.7960 - val_loss: 0.5647 - val_precision: 0.8803
# Epoch 284/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9490 - auc: 0.9979 - f1_score: 0.9482 - loss: 0.2186 - precision: 0.9707
# Epoch 284: val_loss did not improve from 0.55191
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9488 - auc: 0.9979 - f1_score: 0.9481 - loss: 0.2186 - precision: 0.9706 - val_accuracy: 0.8062 - val_auc: 0.9800 - val_f1_score: 0.8018 - val_loss: 0.5620 - val_precision: 0.8750
# Epoch 285/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9358 - auc: 0.9968 - f1_score: 0.9338 - loss: 0.2528 - precision: 0.9543
# Epoch 285: val_loss did not improve from 0.55191
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9367 - auc: 0.9968 - f1_score: 0.9348 - loss: 0.2515 - precision: 0.9553 - val_accuracy: 0.8000 - val_auc: 0.9798 - val_f1_score: 0.7960 - val_loss: 0.5640 - val_precision: 0.8681
# Epoch 286/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9304 - auc: 0.9972 - f1_score: 0.9260 - loss: 0.2578 - precision: 0.9501
# Epoch 286: val_loss did not improve from 0.55191
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9311 - auc: 0.9972 - f1_score: 0.9271 - loss: 0.2550 - precision: 0.9510 - val_accuracy: 0.8062 - val_auc: 0.9798 - val_f1_score: 0.8035 - val_loss: 0.5638 - val_precision: 0.8750
# Epoch 287/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9477 - auc: 0.9981 - f1_score: 0.9478 - loss: 0.2231 - precision: 0.9689
# Epoch 287: val_loss did not improve from 0.55191
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9484 - auc: 0.9982 - f1_score: 0.9486 - loss: 0.2213 - precision: 0.9693 - val_accuracy: 0.8125 - val_auc: 0.9799 - val_f1_score: 0.8107 - val_loss: 0.5607 - val_precision: 0.8681
# Epoch 288/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9530 - auc: 0.9987 - f1_score: 0.9529 - loss: 0.2061 - precision: 0.9731
# Epoch 288: val_loss did not improve from 0.55191
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9521 - auc: 0.9986 - f1_score: 0.9520 - loss: 0.2078 - precision: 0.9724 - val_accuracy: 0.8188 - val_auc: 0.9799 - val_f1_score: 0.8170 - val_loss: 0.5621 - val_precision: 0.8681
# Epoch 289/500
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9543 - auc: 0.9987 - f1_score: 0.9531 - loss: 0.2135 - precision: 0.9711
# Epoch 289: val_loss did not improve from 0.55191
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9518 - auc: 0.9987 - f1_score: 0.9508 - loss: 0.2140 - precision: 0.9694 - val_accuracy: 0.8125 - val_auc: 0.9796 - val_f1_score: 0.8114 - val_loss: 0.5678 - val_precision: 0.8611
# Epoch 290/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9467 - auc: 0.9990 - f1_score: 0.9458 - loss: 0.1888 - precision: 0.9671
# Epoch 290: val_loss did not improve from 0.55191
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9465 - auc: 0.9990 - f1_score: 0.9458 - loss: 0.1897 - precision: 0.9675 - val_accuracy: 0.8125 - val_auc: 0.9795 - val_f1_score: 0.8120 - val_loss: 0.5713 - val_precision: 0.8542
# Epoch 291/500
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9422 - auc: 0.9985 - f1_score: 0.9425 - loss: 0.1980 - precision: 0.9678
# Epoch 291: val_loss did not improve from 0.55191
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9461 - auc: 0.9985 - f1_score: 0.9463 - loss: 0.1972 - precision: 0.9692 - val_accuracy: 0.8250 - val_auc: 0.9795 - val_f1_score: 0.8250 - val_loss: 0.5702 - val_precision: 0.8542
# Epoch 292/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9499 - auc: 0.9987 - f1_score: 0.9495 - loss: 0.1972 - precision: 0.9754
# Epoch 292: val_loss did not improve from 0.55191
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9488 - auc: 0.9987 - f1_score: 0.9484 - loss: 0.1988 - precision: 0.9746 - val_accuracy: 0.8250 - val_auc: 0.9798 - val_f1_score: 0.8250 - val_loss: 0.5607 - val_precision: 0.8552
# Epoch 293/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9600 - auc: 0.9988 - f1_score: 0.9597 - loss: 0.1892 - precision: 0.9801
# Epoch 293: val_loss did not improve from 0.55191
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9581 - auc: 0.9987 - f1_score: 0.9579 - loss: 0.1915 - precision: 0.9796 - val_accuracy: 0.8250 - val_auc: 0.9802 - val_f1_score: 0.8245 - val_loss: 0.5575 - val_precision: 0.8621
# Epoch 294/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9324 - auc: 0.9980 - f1_score: 0.9266 - loss: 0.2179 - precision: 0.9636
# Epoch 294: val_loss did not improve from 0.55191
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9339 - auc: 0.9980 - f1_score: 0.9286 - loss: 0.2163 - precision: 0.9642 - val_accuracy: 0.8313 - val_auc: 0.9795 - val_f1_score: 0.8314 - val_loss: 0.5609 - val_precision: 0.8681
# Epoch 295/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9471 - auc: 0.9990 - f1_score: 0.9446 - loss: 0.1854 - precision: 0.9581
# Epoch 295: val_loss did not improve from 0.55191
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9473 - auc: 0.9990 - f1_score: 0.9450 - loss: 0.1855 - precision: 0.9586 - val_accuracy: 0.8188 - val_auc: 0.9793 - val_f1_score: 0.8183 - val_loss: 0.5658 - val_precision: 0.8803
# Epoch 296/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9667 - auc: 0.9991 - f1_score: 0.9647 - loss: 0.1734 - precision: 0.9762
# Epoch 296: val_loss did not improve from 0.55191
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9666 - auc: 0.9991 - f1_score: 0.9648 - loss: 0.1738 - precision: 0.9766 - val_accuracy: 0.8125 - val_auc: 0.9792 - val_f1_score: 0.8138 - val_loss: 0.5686 - val_precision: 0.8803
# Epoch 297/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9407 - auc: 0.9971 - f1_score: 0.9397 - loss: 0.2406 - precision: 0.9698
# Epoch 297: val_loss did not improve from 0.55191
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9411 - auc: 0.9972 - f1_score: 0.9402 - loss: 0.2382 - precision: 0.9698 - val_accuracy: 0.8062 - val_auc: 0.9792 - val_f1_score: 0.8071 - val_loss: 0.5715 - val_precision: 0.8671
# Epoch 298/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9509 - auc: 0.9987 - f1_score: 0.9496 - loss: 0.1923 - precision: 0.9625
# Epoch 298: val_loss did not improve from 0.55191
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9507 - auc: 0.9987 - f1_score: 0.9495 - loss: 0.1928 - precision: 0.9627 - val_accuracy: 0.8000 - val_auc: 0.9797 - val_f1_score: 0.7988 - val_loss: 0.5660 - val_precision: 0.8671
# Epoch 299/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9256 - auc: 0.9977 - f1_score: 0.9230 - loss: 0.2341 - precision: 0.9395
# Epoch 299: val_loss did not improve from 0.55191
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9267 - auc: 0.9978 - f1_score: 0.9243 - loss: 0.2327 - precision: 0.9406 - val_accuracy: 0.8000 - val_auc: 0.9793 - val_f1_score: 0.7988 - val_loss: 0.5672 - val_precision: 0.8552
# Epoch 300/500
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9396 - auc: 0.9987 - f1_score: 0.9417 - loss: 0.1997 - precision: 0.9692
# Epoch 300: val_loss did not improve from 0.55191
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9400 - auc: 0.9987 - f1_score: 0.9416 - loss: 0.2007 - precision: 0.9673 - val_accuracy: 0.8062 - val_auc: 0.9791 - val_f1_score: 0.8058 - val_loss: 0.5723 - val_precision: 0.8621
# Epoch 301/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9595 - auc: 0.9989 - f1_score: 0.9565 - loss: 0.1911 - precision: 0.9849
# Epoch 301: val_loss did not improve from 0.55191
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9596 - auc: 0.9989 - f1_score: 0.9569 - loss: 0.1912 - precision: 0.9851 - val_accuracy: 0.8125 - val_auc: 0.9793 - val_f1_score: 0.8114 - val_loss: 0.5689 - val_precision: 0.8621
# Epoch 302/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9497 - auc: 0.9991 - f1_score: 0.9507 - loss: 0.1913 - precision: 0.9806
# Epoch 302: val_loss did not improve from 0.55191
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9503 - auc: 0.9991 - f1_score: 0.9512 - loss: 0.1904 - precision: 0.9810 - val_accuracy: 0.8000 - val_auc: 0.9792 - val_f1_score: 0.7998 - val_loss: 0.5736 - val_precision: 0.8483
# Epoch 303/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9554 - auc: 0.9988 - f1_score: 0.9565 - loss: 0.1850 - precision: 0.9788
# Epoch 303: val_loss did not improve from 0.55191
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9556 - auc: 0.9988 - f1_score: 0.9566 - loss: 0.1844 - precision: 0.9784 - val_accuracy: 0.8062 - val_auc: 0.9794 - val_f1_score: 0.8049 - val_loss: 0.5706 - val_precision: 0.8671
# Epoch 304/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9546 - auc: 0.9988 - f1_score: 0.9546 - loss: 0.1802 - precision: 0.9724
# Epoch 304: val_loss did not improve from 0.55191
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9541 - auc: 0.9988 - f1_score: 0.9540 - loss: 0.1815 - precision: 0.9716 - val_accuracy: 0.8062 - val_auc: 0.9768 - val_f1_score: 0.8044 - val_loss: 0.5706 - val_precision: 0.8621
# Epoch 304: early stopping
# Restoring model weights from the end of the best epoch: 254.

# %%
plt.figure(figsize=(20, 6))

# Plot training and validation accuracy
plt.subplot(1, 3, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot training and validation loss
plt.subplot(1, 3, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 3, 3)
plt.plot(history.history['precision'], label='Training Precision')
plt.plot(history.history['val_precision'], label='Validation Precision')
plt.title('Precision over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
y_pred_probs = model.predict(X_test)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = np.argmax(y_test, axis=1) if y_test.ndim > 1 else y_test

accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred, average='macro', zero_division=0)
f1 = f1_score(y_true, y_pred, average='macro')
conf_matrix = confusion_matrix(y_true, y_pred)

print("Dokładność:", accuracy)
print("Precyzja (macro):", precision)
print("F1 score (macro):", f1)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Dokładność: 0.725
# Precyzja (macro): 0.7347417440660475
# F1 score (macro): 0.7252317202317202

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix Heatmap')
plt.show()

# %%
y_true_bin = label_binarize(y_true, classes=range(10))
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(10):
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_pred_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])


plt.figure(figsize=(10, 8))
for i in range(10):
    plt.plot(fpr[i], tpr[i], label=f'Klasa {i} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Krzywe ROC dla klas')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()
