# %% [markdown]
# MobileNet
#
# *Dense Layers* + Batch normalization

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Params
img_size = 224
batch_size = 32
num_classes = 10

name_model="models/batch.keras"

# Paths
train_dir = r"C:\Users\jakub\Desktop\muzyka_guiio\Music-Classification\project_data\train_spectrograms"
test_dir = r"C:\Users\jakub\Desktop\muzyka_guiio\Music-Classification\project_data\test_spectrograms"

# Train/val generators (80/20 split)
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)


print("Train:")
train_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='categorical',
    subset='training',
    shuffle=True
)

print("Val:")
val_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation',
    shuffle=False
)

# Test generator (no split)
test_datagen = ImageDataGenerator(rescale=1./255)

print("Test:")
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Train:
# Found 640 images belonging to 10 classes.
# Val:
# Found 159 images belonging to 10 classes.
# Test:
# Found 200 images belonging to 10 classes.

# %% [markdown]
# MobileNetV2, GlobalAvaragePooling2D + Dense Layer at the end + BatchNormalization

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.models import Model
import os


# Model setup
base_model = MobileNetV2(input_shape=(img_size, img_size, 3), include_top=False, weights='imagenet')
base_model.trainable = False  # Freeze base layers

x = base_model.output
x = GlobalAveragePooling2D()(x)        # Flatten conv output
x = BatchNormalization()(x)
x = Dense(128, activation='relu')(x)   # Optional dense layer
predictions = Dense(num_classes, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# Compile
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy',tf.keras.metrics.Precision()])

# Train
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=25
)

# Save model

model.save(name_model)

# Test evaluation
print("\nTesting -------------------------------")
results = model.evaluate(test_generator)

# Indeksy: [0] = loss, [1] = accuracy, [2] = precision
test_loss = results[0]
test_acc = results[1]
test_precision = results[2]

print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_acc:.2%}")
print(f"Test Precision: {test_precision:.2%}")
# Out:
# c:\Users\jakub\Desktop\muzyka_guiio\Music-Classification\.venv\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.3030 - loss: 2.0116 - precision: 0.5740 - val_accuracy: 0.3082 - val_loss: 1.7856 - val_precision: 0.6923
# Epoch 2/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.7636 - loss: 0.6959 - precision: 0.8444 - val_accuracy: 0.3208 - val_loss: 1.7692 - val_precision: 0.4857
# Epoch 3/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 30s 1s/step - accuracy: 0.8807 - loss: 0.3665 - precision: 0.9407 - val_accuracy: 0.4340 - val_loss: 1.6333 - val_precision: 0.6081
# Epoch 4/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 29s 1s/step - accuracy: 0.9556 - loss: 0.2277 - precision: 0.9775 - val_accuracy: 0.4591 - val_loss: 1.5030 - val_precision: 0.6145
# Epoch 5/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 29s 1s/step - accuracy: 0.9704 - loss: 0.1762 - precision: 0.9906 - val_accuracy: 0.4465 - val_loss: 1.4819 - val_precision: 0.6444
# Epoch 6/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 30s 2s/step - accuracy: 0.9890 - loss: 0.1347 - precision: 0.9937 - val_accuracy: 0.4906 - val_loss: 1.3939 - val_precision: 0.7000
# Epoch 7/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.9876 - loss: 0.0948 - precision: 0.9955 - val_accuracy: 0.4969 - val_loss: 1.3953 - val_precision: 0.6566
# Epoch 8/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.9985 - loss: 0.0693 - precision: 0.9985 - val_accuracy: 0.5031 - val_loss: 1.4066 - val_precision: 0.6346
# Epoch 9/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 1.0000 - loss: 0.0535 - precision: 1.0000 - val_accuracy: 0.5220 - val_loss: 1.4015 - val_precision: 0.6216
# Epoch 10/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.9979 - loss: 0.0467 - precision: 0.9979 - val_accuracy: 0.5157 - val_loss: 1.4101 - val_precision: 0.6325
# Epoch 11/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 1.0000 - loss: 0.0339 - precision: 1.0000 - val_accuracy: 0.4969 - val_loss: 1.4789 - val_precision: 0.6116
# Epoch 12/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 1.0000 - loss: 0.0319 - precision: 1.0000 - val_accuracy: 0.5031 - val_loss: 1.4659 - val_precision: 0.6098
# Epoch 13/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 1.0000 - loss: 0.0229 - precision: 1.0000 - val_accuracy: 0.5031 - val_loss: 1.5374 - val_precision: 0.5814
# Epoch 14/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 1.0000 - loss: 0.0221 - precision: 1.0000 - val_accuracy: 0.5157 - val_loss: 1.6141 - val_precision: 0.5588
# Epoch 15/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 1.0000 - loss: 0.0185 - precision: 1.0000 - val_accuracy: 0.4969 - val_loss: 1.6456 - val_precision: 0.5564
# Epoch 16/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 1.0000 - loss: 0.0182 - precision: 1.0000 - val_accuracy: 0.5031 - val_loss: 1.6811 - val_precision: 0.5672
# Epoch 17/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 45s 2s/step - accuracy: 1.0000 - loss: 0.0154 - precision: 1.0000 - val_accuracy: 0.5031 - val_loss: 1.7033 - val_precision: 0.5652
# Epoch 18/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 1.0000 - loss: 0.0144 - precision: 1.0000 - val_accuracy: 0.5283 - val_loss: 1.6608 - val_precision: 0.5662
# Epoch 19/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 1.0000 - loss: 0.0125 - precision: 1.0000 - val_accuracy: 0.5283 - val_loss: 1.7180 - val_precision: 0.5500
# Epoch 20/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 1.0000 - loss: 0.0105 - precision: 1.0000 - val_accuracy: 0.5220 - val_loss: 1.7639 - val_precision: 0.5385
# Epoch 21/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 1.0000 - loss: 0.0097 - precision: 1.0000 - val_accuracy: 0.5220 - val_loss: 1.7880 - val_precision: 0.5417
# Epoch 22/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 1.0000 - loss: 0.0106 - precision: 1.0000 - val_accuracy: 0.5157 - val_loss: 1.8366 - val_precision: 0.5385
# Epoch 23/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 1.0000 - loss: 0.0079 - precision: 1.0000 - val_accuracy: 0.5031 - val_loss: 1.8751 - val_precision: 0.5315
# Epoch 24/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 1.0000 - loss: 0.0081 - precision: 1.0000 - val_accuracy: 0.5031 - val_loss: 1.9278 - val_precision: 0.5385
# Epoch 25/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 1.0000 - loss: 0.0099 - precision: 1.0000 - val_accuracy: 0.4969 - val_loss: 1.9740 - val_precision: 0.5315
#
# Testing -------------------------------
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.6674 - loss: 1.2596 - precision: 0.6960
# Test Loss: 1.1791
# Test Accuracy: 69.50%
# Test Precision: 72.28%

# %%
from mobilenet_utils import plot_training_history

plot_training_history(history)

# %% [markdown]
# Classification report  + Confusion matrix

# %%
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix
import numpy as np

# Generujemy predykcje
y_pred = model.predict(val_generator)
y_pred_classes = np.argmax(y_pred, axis=1)

# Prawdziwe etykiety
y_true = val_generator.classes

# Nazwy klas
class_labels = list(val_generator.class_indices.keys())

cm = confusion_matrix(y_true, y_pred_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel("Prediction")
plt.ylabel("Class")
plt.title("Confusion matrix")
plt.show()
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step
