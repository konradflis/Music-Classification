# %% [markdown]
# MobileNet
#
# *Dense Layers*

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Params
img_size = 224
batch_size = 32
num_classes = 10

# Paths
train_dir = r"C:\Users\jakub\Desktop\muzyka_guiio\Music-Classification\project_data\train_spectrograms"
test_dir = r"C:\Users\jakub\Desktop\muzyka_guiio\Music-Classification\project_data\test_spectrograms"

# Train/val generators (80/20 split)
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)


print("Train:")
train_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='categorical',
    subset='training',
    shuffle=True
)

print("Val:")
val_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation',
    shuffle=False
)

# Test generator (no split)
test_datagen = ImageDataGenerator(rescale=1./255)

print("Test:")
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Train:
# Found 640 images belonging to 10 classes.
# Val:
# Found 159 images belonging to 10 classes.
# Test:
# Found 200 images belonging to 10 classes.

# %% [markdown]
# MobileNetV2, GlobalAvaragePooling2D + Dense Layer at the end

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model
import os


# Model setup
base_model = MobileNetV2(input_shape=(img_size, img_size, 3), include_top=False, weights='imagenet')
base_model.trainable = False  # Freeze base layers

x = base_model.output
x = GlobalAveragePooling2D()(x)        # Flatten conv output
x = Dense(128, activation='relu')(x)   # Optional dense layer
predictions = Dense(num_classes, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# Compile
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy',tf.keras.metrics.Precision()])

# Train
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=25
)

# Save model
name_model="models/mobilenet_added_dense.keras"
model.save(name_model)

# Test evaluation
print("\nTesting -------------------------------")
results = model.evaluate(test_generator)

# Indeksy: [0] = loss, [1] = accuracy, [2] = precision
test_loss = results[0]
test_acc = results[1]
test_precision = results[2]

print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_acc:.2%}")
print(f"Test Precision: {test_precision:.2%}")
# Out:
# c:\Users\jakub\Desktop\muzyka_guiio\Music-Classification\.venv\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 130s 5s/step - accuracy: 0.2076 - loss: 2.2400 - precision_1: 0.5164 - val_accuracy: 0.4277 - val_loss: 1.5850 - val_precision_1: 0.7619
# Epoch 2/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.5599 - loss: 1.2293 - precision_1: 0.8475 - val_accuracy: 0.4528 - val_loss: 1.5151 - val_precision_1: 0.6842
# Epoch 3/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.6693 - loss: 0.9945 - precision_1: 0.8554 - val_accuracy: 0.5283 - val_loss: 1.3331 - val_precision_1: 0.6744
# Epoch 4/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.7582 - loss: 0.8265 - precision_1: 0.8941 - val_accuracy: 0.4969 - val_loss: 1.4656 - val_precision_1: 0.6289
# Epoch 5/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.7490 - loss: 0.7553 - precision_1: 0.8744 - val_accuracy: 0.5346 - val_loss: 1.4138 - val_precision_1: 0.6239
# Epoch 6/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 0.7997 - loss: 0.6285 - precision_1: 0.8949 - val_accuracy: 0.5031 - val_loss: 1.4063 - val_precision_1: 0.6476
# Epoch 7/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.7983 - loss: 0.5815 - precision_1: 0.9100 - val_accuracy: 0.5031 - val_loss: 1.3985 - val_precision_1: 0.6195
# Epoch 8/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.8357 - loss: 0.5138 - precision_1: 0.9336 - val_accuracy: 0.5409 - val_loss: 1.3892 - val_precision_1: 0.6496
# Epoch 9/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.9005 - loss: 0.4531 - precision_1: 0.9344 - val_accuracy: 0.5283 - val_loss: 1.4150 - val_precision_1: 0.6239
# Epoch 10/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 0.8901 - loss: 0.4386 - precision_1: 0.9461 - val_accuracy: 0.5409 - val_loss: 1.3925 - val_precision_1: 0.6583
# Epoch 11/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.9278 - loss: 0.3506 - precision_1: 0.9711 - val_accuracy: 0.5283 - val_loss: 1.4560 - val_precision_1: 0.6129
# Epoch 12/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.9345 - loss: 0.3175 - precision_1: 0.9673 - val_accuracy: 0.5157 - val_loss: 1.4812 - val_precision_1: 0.6167
# Epoch 13/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.9331 - loss: 0.3202 - precision_1: 0.9758 - val_accuracy: 0.5975 - val_loss: 1.3939 - val_precision_1: 0.6864
# Epoch 14/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.9425 - loss: 0.2751 - precision_1: 0.9754 - val_accuracy: 0.5220 - val_loss: 1.4721 - val_precision_1: 0.6260
# Epoch 15/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.9505 - loss: 0.2596 - precision_1: 0.9843 - val_accuracy: 0.5346 - val_loss: 1.5412 - val_precision_1: 0.6393
# Epoch 16/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9433 - loss: 0.2356 - precision_1: 0.9812 - val_accuracy: 0.5472 - val_loss: 1.5396 - val_precision_1: 0.5704
# Epoch 17/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9708 - loss: 0.2039 - precision_1: 0.9831 - val_accuracy: 0.5346 - val_loss: 1.5227 - val_precision_1: 0.6107
# Epoch 18/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.9656 - loss: 0.1992 - precision_1: 0.9858 - val_accuracy: 0.5409 - val_loss: 1.4965 - val_precision_1: 0.6107
# Epoch 19/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 0.9699 - loss: 0.1508 - precision_1: 0.9908 - val_accuracy: 0.5409 - val_loss: 1.5516 - val_precision_1: 0.6183
# Epoch 20/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.9849 - loss: 0.1505 - precision_1: 0.9887 - val_accuracy: 0.5409 - val_loss: 1.5877 - val_precision_1: 0.5852
# Epoch 21/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.9748 - loss: 0.1478 - precision_1: 0.9897 - val_accuracy: 0.5472 - val_loss: 1.5593 - val_precision_1: 0.6202
# Epoch 22/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9794 - loss: 0.1475 - precision_1: 0.9949 - val_accuracy: 0.5346 - val_loss: 1.6428 - val_precision_1: 0.6107
# Epoch 23/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9782 - loss: 0.1273 - precision_1: 0.9879 - val_accuracy: 0.5220 - val_loss: 1.6991 - val_precision_1: 0.5725
# Epoch 24/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9850 - loss: 0.1300 - precision_1: 0.9982 - val_accuracy: 0.5283 - val_loss: 1.6840 - val_precision_1: 0.5839
# Epoch 25/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.9986 - loss: 0.0923 - precision_1: 0.9995 - val_accuracy: 0.5472 - val_loss: 1.7079 - val_precision_1: 0.5797
#
# Testing -------------------------------
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.6928 - loss: 1.0982 - precision_1: 0.7382
# Test Loss: 1.0499
# Test Accuracy: 70.50%
# Test Precision: 74.27%

# %%
from mobilenet_utils import plot_training_history

plot_training_history(history)

# %% [markdown]
# Classification report  + Confusion matrix

# %%
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix
import numpy as np

# Generujemy predykcje
y_pred = model.predict(val_generator)
y_pred_classes = np.argmax(y_pred, axis=1)

# Prawdziwe etykiety
y_true = val_generator.classes

# Nazwy klas
class_labels = list(val_generator.class_indices.keys())

cm = confusion_matrix(y_true, y_pred_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel("Prediction")
plt.ylabel("Class")
plt.title("Confusion matrix")
plt.show()
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step
