# %% [markdown]
# MobileNet
#
# *Dense Layers* + single dropout

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

name_model="models/dropout1.keras"

# Params
img_size = 224
batch_size = 32
num_classes = 10

# Paths
train_dir = r"C:\Users\jakub\Desktop\muzyka_guiio\Music-Classification\project_data\train_spectrograms"
test_dir = r"C:\Users\jakub\Desktop\muzyka_guiio\Music-Classification\project_data\test_spectrograms"

# Train/val generators (80/20 split)
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)


print("Train:")
train_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='categorical',
    subset='training',
    shuffle=True
)

print("Val:")
val_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation',
    shuffle=False
)

# Test generator (no split)
test_datagen = ImageDataGenerator(rescale=1./255)

print("Test:")
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Train:
# Found 640 images belonging to 10 classes.
# Val:
# Found 159 images belonging to 10 classes.
# Test:
# Found 200 images belonging to 10 classes.

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
import os


# Model setup
base_model = MobileNetV2(input_shape=(img_size, img_size, 3), include_top=False, weights='imagenet')
base_model.trainable = False  # Freeze base layers

x = base_model.output
x = GlobalAveragePooling2D()(x)        # Flatten conv output
x = Dropout(0.3)(x)
x = Dense(128, activation='relu')(x)   # Optional dense layer
predictions = Dense(num_classes, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# Compile
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy',tf.keras.metrics.Precision()])

# Train
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=25
)

# Save model
model.save(name_model)

# Test evaluation
print("\nTesting -------------------------------")
results = model.evaluate(test_generator)

# Indeksy: [0] = loss, [1] = accuracy, [2] = precision
test_loss = results[0]
test_acc = results[1]
test_precision = results[2]

print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_acc:.2%}")
print(f"Test Precision: {test_precision:.2%}")
# Out:
# c:\Users\jakub\Desktop\muzyka_guiio\Music-Classification\.venv\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 26s 988ms/step - accuracy: 0.2191 - loss: 2.3357 - precision: 0.5455 - val_accuracy: 0.4025 - val_loss: 1.7577 - val_precision: 0.8333
# Epoch 2/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 18s 900ms/step - accuracy: 0.4743 - loss: 1.4983 - precision: 0.7465 - val_accuracy: 0.3899 - val_loss: 1.6824 - val_precision: 0.6909
# Epoch 3/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.5339 - loss: 1.2728 - precision: 0.7511 - val_accuracy: 0.4277 - val_loss: 1.5567 - val_precision: 0.6364
# Epoch 4/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.6112 - loss: 1.1266 - precision: 0.7556 - val_accuracy: 0.5031 - val_loss: 1.5091 - val_precision: 0.6585
# Epoch 5/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 19s 978ms/step - accuracy: 0.6475 - loss: 0.9600 - precision: 0.8126 - val_accuracy: 0.4654 - val_loss: 1.4588 - val_precision: 0.5980
# Epoch 6/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.6586 - loss: 0.9568 - precision: 0.7749 - val_accuracy: 0.5031 - val_loss: 1.4461 - val_precision: 0.6239
# Epoch 7/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.6547 - loss: 0.9389 - precision: 0.7809 - val_accuracy: 0.5220 - val_loss: 1.4031 - val_precision: 0.6429
# Epoch 8/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.8041 - loss: 0.6871 - precision: 0.8806 - val_accuracy: 0.5031 - val_loss: 1.4039 - val_precision: 0.6250
# Epoch 9/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 0.7465 - loss: 0.7368 - precision: 0.8408 - val_accuracy: 0.5220 - val_loss: 1.4617 - val_precision: 0.5932
# Epoch 10/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.7549 - loss: 0.7197 - precision: 0.8499 - val_accuracy: 0.5157 - val_loss: 1.4648 - val_precision: 0.6303
# Epoch 11/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step - accuracy: 0.7970 - loss: 0.5978 - precision: 0.8945 - val_accuracy: 0.5472 - val_loss: 1.4253 - val_precision: 0.6066
# Epoch 12/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.8058 - loss: 0.5594 - precision: 0.8789 - val_accuracy: 0.5157 - val_loss: 1.4974 - val_precision: 0.6239
# Epoch 13/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.8210 - loss: 0.5579 - precision: 0.8819 - val_accuracy: 0.5409 - val_loss: 1.4387 - val_precision: 0.6281
# Epoch 14/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.8255 - loss: 0.5524 - precision: 0.8835 - val_accuracy: 0.5157 - val_loss: 1.4476 - val_precision: 0.6333
# Epoch 15/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 0.8540 - loss: 0.4522 - precision: 0.9081 - val_accuracy: 0.5597 - val_loss: 1.4907 - val_precision: 0.6047
# Epoch 16/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 893ms/step - accuracy: 0.8311 - loss: 0.4903 - precision: 0.8880 - val_accuracy: 0.5220 - val_loss: 1.5604 - val_precision: 0.5760
# Epoch 17/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.8504 - loss: 0.4532 - precision: 0.9006 - val_accuracy: 0.5157 - val_loss: 1.6601 - val_precision: 0.6083
# Epoch 18/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step - accuracy: 0.8102 - loss: 0.4828 - precision: 0.8800 - val_accuracy: 0.5031 - val_loss: 1.6652 - val_precision: 0.5758
# Epoch 19/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.8503 - loss: 0.4278 - precision: 0.8986 - val_accuracy: 0.5346 - val_loss: 1.5438 - val_precision: 0.5985
# Epoch 20/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 0.8505 - loss: 0.4132 - precision: 0.8939 - val_accuracy: 0.5220 - val_loss: 1.6144 - val_precision: 0.6000
# Epoch 21/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step - accuracy: 0.8783 - loss: 0.3722 - precision: 0.9242 - val_accuracy: 0.5283 - val_loss: 1.6189 - val_precision: 0.6061
# Epoch 22/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.9010 - loss: 0.3213 - precision: 0.9466 - val_accuracy: 0.5283 - val_loss: 1.6901 - val_precision: 0.6063
# Epoch 23/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.8687 - loss: 0.3695 - precision: 0.9199 - val_accuracy: 0.5283 - val_loss: 1.5945 - val_precision: 0.5985
# Epoch 24/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 28s 1s/step - accuracy: 0.8590 - loss: 0.3635 - precision: 0.9059 - val_accuracy: 0.5220 - val_loss: 1.8175 - val_precision: 0.5735
# Epoch 25/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.8896 - loss: 0.3305 - precision: 0.9196 - val_accuracy: 0.5472 - val_loss: 1.7755 - val_precision: 0.5745
#
# Testing -------------------------------
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 897ms/step - accuracy: 0.5875 - loss: 1.2755 - precision: 0.6287
# Test Loss: 1.1125
# Test Accuracy: 63.50%
# Test Precision: 68.21%

# %%
from mobilenet_utils import plot_training_history

plot_training_history(history)

# %% [markdown]
# Classification report  + Confusion matrix

# %%
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix
import numpy as np

# Generujemy predykcje
y_pred = model.predict(val_generator)
y_pred_classes = np.argmax(y_pred, axis=1)

# Prawdziwe etykiety
y_true = val_generator.classes

# Nazwy klas
class_labels = list(val_generator.class_indices.keys())

cm = confusion_matrix(y_true, y_pred_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel("Prediction")
plt.ylabel("Class")
plt.title("Confusion matrix")
plt.show()
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step

# %% [markdown]
# MobileNet
#
# *Dense Layers* + double dropout

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

name_model="models/dropout2.keras"

# Params
img_size = 224
batch_size = 32
num_classes = 10

# Paths
train_dir = r"C:\Users\jakub\Desktop\muzyka_guiio\Music-Classification\project_data\train_spectrograms"
test_dir = r"C:\Users\jakub\Desktop\muzyka_guiio\Music-Classification\project_data\test_spectrograms"

# Train/val generators (80/20 split)
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)


print("Train:")
train_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='categorical',
    subset='training',
    shuffle=True
)

print("Val:")
val_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation',
    shuffle=False
)

# Test generator (no split)
test_datagen = ImageDataGenerator(rescale=1./255)

print("Test:")
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Train:
# Found 640 images belonging to 10 classes.
# Val:
# Found 159 images belonging to 10 classes.
# Test:
# Found 200 images belonging to 10 classes.

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
import os


# Model setup
base_model = MobileNetV2(input_shape=(img_size, img_size, 3), include_top=False, weights='imagenet')
base_model.trainable = False  # Freeze base layers

x = base_model.output
x = GlobalAveragePooling2D()(x)        # Flatten conv output
x = Dropout(0.3)(x)
x = Dense(128, activation='relu')(x)   # Optional dense layer
x = Dropout(0.3)(x)
predictions = Dense(num_classes, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# Compile
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy',tf.keras.metrics.Precision()])

# Train
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=25
)

# Save model
model.save(name_model)

# Test evaluation
print("\nTesting -------------------------------")
results = model.evaluate(test_generator)

# Indeksy: [0] = loss, [1] = accuracy, [2] = precision
test_loss = results[0]
test_acc = results[1]
test_precision = results[2]

print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_acc:.2%}")
print(f"Test Precision: {test_precision:.2%}")
# Out:
# c:\Users\jakub\Desktop\muzyka_guiio\Music-Classification\.venv\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.1410 - loss: 2.5797 - precision_1: 0.1931 - val_accuracy: 0.4277 - val_loss: 1.7746 - val_precision_1: 0.9333
# Epoch 2/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 0.3784 - loss: 1.7258 - precision_1: 0.7976 - val_accuracy: 0.4025 - val_loss: 1.6754 - val_precision_1: 0.7500
# Epoch 3/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.4713 - loss: 1.5062 - precision_1: 0.6293 - val_accuracy: 0.4906 - val_loss: 1.4834 - val_precision_1: 0.7333
# Epoch 4/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step - accuracy: 0.5531 - loss: 1.2713 - precision_1: 0.7263 - val_accuracy: 0.5157 - val_loss: 1.3744 - val_precision_1: 0.7681
# Epoch 5/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.5644 - loss: 1.2569 - precision_1: 0.7224 - val_accuracy: 0.4906 - val_loss: 1.4249 - val_precision_1: 0.6905
# Epoch 6/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0