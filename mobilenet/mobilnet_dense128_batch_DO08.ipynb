# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Params
img_size = 224
batch_size = 32
num_classes = 10

# Paths
train_dir = r"C:\Users\Dell\Desktop\Music-Classification-MobileNet1\project_data\train_spectrograms"
test_dir = r"C:\Users\Dell\Desktop\Music-Classification-MobileNet1\project_data\test_spectrograms"

# Train/val generators (80/20 split)
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)


print("Train:")
train_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='categorical',
    subset='training',
    shuffle=True
)

print("Val:")
val_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation',
    shuffle=False
)

# Test generator (no split)
test_datagen = ImageDataGenerator(rescale=1./255)

print("Test:")
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Train:
# Found 766 images belonging to 10 classes.
# Val:
# Found 188 images belonging to 10 classes.
# Test:
# Found 355 images belonging to 10 classes.

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model
import os


# Model setup
base_model = MobileNetV2(input_shape=(img_size, img_size, 3), include_top=False, weights='imagenet')
base_model.trainable = False  # Freeze base layers

x = base_model.output
x = GlobalAveragePooling2D()(x)        # Flatten conv output
x = Dense(128)(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Activation('relu')(x)
x = tf.keras.layers.Dropout(0.3)(x)
predictions = Dense(num_classes, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# Compile
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy',tf.keras.metrics.Precision()])

# Train
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=25
)

# Save model
name_model="models/mobilenet_dense128_batch_DO03.keras"
model.save(name_model)

# Test evaluation
print("\nTesting -------------------------------")
results = model.evaluate(test_generator)

# Indeksy: [0] = loss, [1] = accuracy, [2] = precision
test_loss = results[0]
test_acc = results[1]
test_precision = results[2]

print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_acc:.2%}")
print(f"Test Precision: {test_precision:.2%}")
# Out:
# c:\Users\Dell\AppData\Local\pypoetry\Cache\virtualenvs\music-classification-1IWzNP0M-py3.12\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 25s 762ms/step - accuracy: 0.2625 - loss: 2.2078 - precision: 0.4604 - val_accuracy: 0.3085 - val_loss: 2.0662 - val_precision: 0.5455
# Epoch 2/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 16s 647ms/step - accuracy: 0.6487 - loss: 1.0739 - precision: 0.7823 - val_accuracy: 0.4149 - val_loss: 1.7233 - val_precision: 0.6290
# Epoch 3/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 15s 636ms/step - accuracy: 0.7357 - loss: 0.8156 - precision: 0.8809 - val_accuracy: 0.4521 - val_loss: 1.4660 - val_precision: 0.7215
# Epoch 4/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 15s 641ms/step - accuracy: 0.8003 - loss: 0.6457 - precision: 0.9011 - val_accuracy: 0.5160 - val_loss: 1.3540 - val_precision: 0.7340
# Epoch 5/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 16s 649ms/step - accuracy: 0.8406 - loss: 0.5211 - precision: 0.9258 - val_accuracy: 0.5957 - val_loss: 1.2333 - val_precision: 0.7523
# Epoch 6/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 16s 650ms/step - accuracy: 0.8879 - loss: 0.4624 - precision: 0.9408 - val_accuracy: 0.5585 - val_loss: 1.2535 - val_precision: 0.7321
# Epoch 7/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 15s 634ms/step - accuracy: 0.9038 - loss: 0.4043 - precision: 0.9578 - val_accuracy: 0.5532 - val_loss: 1.2165 - val_precision: 0.7333
# Epoch 8/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 15s 636ms/step - accuracy: 0.9228 - loss: 0.3358 - precision: 0.9725 - val_accuracy: 0.5319 - val_loss: 1.3099 - val_precision: 0.6860
# Epoch 9/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 15s 641ms/step - accuracy: 0.9619 - loss: 0.2525 - precision: 0.9856 - val_accuracy: 0.5319 - val_loss: 1.2914 - val_precision: 0.6667
# Epoch 10/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 16s 649ms/step - accuracy: 0.9445 - loss: 0.2402 - precision: 0.9680 - val_accuracy: 0.5745 - val_loss: 1.2510 - val_precision: 0.6977
# Epoch 11/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 15s 631ms/step - accuracy: 0.9678 - loss: 0.2156 - precision: 0.9855 - val_accuracy: 0.5585 - val_loss: 1.3391 - val_precision: 0.6507
# Epoch 12/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 15s 625ms/step - accuracy: 0.9698 - loss: 0.1611 - precision: 0.9791 - val_accuracy: 0.5426 - val_loss: 1.3631 - val_precision: 0.6496
# Epoch 13/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 15s 637ms/step - accuracy: 0.9808 - loss: 0.1551 - precision: 0.9906 - val_accuracy: 0.5745 - val_loss: 1.3199 - val_precision: 0.6781
# Epoch 14/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 17s 706ms/step - accuracy: 0.9766 - loss: 0.1435 - precision: 0.9865 - val_accuracy: 0.5266 - val_loss: 1.4874 - val_precision: 0.5960
# Epoch 15/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 16s 681ms/step - accuracy: 0.9850 - loss: 0.1139 - precision: 0.9991 - val_accuracy: 0.5479 - val_loss: 1.4350 - val_precision: 0.6376
# Epoch 16/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 18s 736ms/step - accuracy: 0.9915 - loss: 0.1002 - precision: 0.9959 - val_accuracy: 0.5851 - val_loss: 1.4416 - val_precision: 0.6474
# Epoch 17/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 17s 712ms/step - accuracy: 0.9971 - loss: 0.0836 - precision: 0.9993 - val_accuracy: 0.5904 - val_loss: 1.4265 - val_precision: 0.6667
# Epoch 18/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 16s 668ms/step - accuracy: 0.9942 - loss: 0.0859 - precision: 0.9983 - val_accuracy: 0.5638 - val_loss: 1.5095 - val_precision: 0.6194
# Epoch 19/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 15s 636ms/step - accuracy: 0.9963 - loss: 0.0624 - precision: 0.9980 - val_accuracy: 0.5638 - val_loss: 1.5055 - val_precision: 0.6184
# Epoch 20/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 15s 626ms/step - accuracy: 0.9946 - loss: 0.0758 - precision: 0.9945 - val_accuracy: 0.5426 - val_loss: 1.6049 - val_precision: 0.6149
# Epoch 21/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 16s 653ms/step - accuracy: 0.9996 - loss: 0.0554 - precision: 1.0000 - val_accuracy: 0.5585 - val_loss: 1.5143 - val_precision: 0.6266
# Epoch 22/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 15s 641ms/step - accuracy: 0.9979 - loss: 0.0532 - precision: 0.9979 - val_accuracy: 0.5585 - val_loss: 1.7053 - val_precision: 0.6164
# Epoch 23/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 16s 651ms/step - accuracy: 0.9977 - loss: 0.0475 - precision: 0.9977 - val_accuracy: 0.5426 - val_loss: 1.6101 - val_precision: 0.5988
# Epoch 24/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 16s 660ms/step - accuracy: 0.9973 - loss: 0.0546 - precision: 0.9988 - val_accuracy: 0.5372 - val_loss: 1.7620 - val_precision: 0.6000
# Epoch 25/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 16s 654ms/step - accuracy: 1.0000 - loss: 0.0416 - precision: 1.0000 - val_accuracy: 0.5372 - val_loss: 1.7246 - val_precision: 0.5818
#
# Testing -------------------------------
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 510ms/step - accuracy: 0.8782 - loss: 0.4569 - precision: 0.8965
# Test Loss: 0.4500
# Test Accuracy: 88.17%
# Test Precision: 90.38%

# %%
from mobilenet_utils import plot_training_history

plot_training_history(history)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix
import numpy as np

# Generujemy predykcje
y_pred = model.predict(val_generator)
y_pred_classes = np.argmax(y_pred, axis=1)

# Prawdziwe etykiety
y_true = val_generator.classes

# Nazwy klas
class_labels = list(val_generator.class_indices.keys())

cm = confusion_matrix(y_true, y_pred_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel("Prediction")
plt.ylabel("Class")
plt.title("Confusion matrix")
plt.show()
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 744ms/step
