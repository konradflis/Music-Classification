# %% [markdown]
# MobileNet
#
# *Dense Layers* + Batch normalization

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Params
img_size = 224
batch_size = 32
num_classes = 10

name_model="models/batch_and_dropout.keras"

# Paths
train_dir = r"C:\Users\jakub\Desktop\muzyka_guiio\Music-Classification\project_data\train_spectrograms"
test_dir = r"C:\Users\jakub\Desktop\muzyka_guiio\Music-Classification\project_data\test_spectrograms"

# Train/val generators (80/20 split)
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)


print("Train:")
train_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='categorical',
    subset='training',
    shuffle=True
)

print("Val:")
val_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation',
    shuffle=False
)

# Test generator (no split)
test_datagen = ImageDataGenerator(rescale=1./255)

print("Test:")
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Train:
# Found 640 images belonging to 10 classes.
# Val:
# Found 159 images belonging to 10 classes.
# Test:
# Found 200 images belonging to 10 classes.

# %% [markdown]
# MobileNetV2, GlobalAvaragePooling2D + Dense Layer at the end + BatchNormalization

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, BatchNormalization, Dropout
from tensorflow.keras.models import Model
import os


# Model setup
base_model = MobileNetV2(input_shape=(img_size, img_size, 3), include_top=False, weights='imagenet')
base_model.trainable = False  # Freeze base layers

x = base_model.output
x = GlobalAveragePooling2D()(x)        # Flatten conv output
x = Dropout(0.3)(x)  # Dropout z p=0.3
x = BatchNormalization()(x)
x = Dropout(0.3)(x)  # Dropout z p=0.3
x = Dense(128, activation='relu')(x)   # Optional dense layer
predictions = Dense(num_classes, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# Compile
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy',tf.keras.metrics.Precision()])

# Train
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=25
)

# Save model

model.save(name_model)

# Test evaluation
print("\nTesting -------------------------------")
results = model.evaluate(test_generator)

# Indeksy: [0] = loss, [1] = accuracy, [2] = precision
test_loss = results[0]
test_acc = results[1]
test_precision = results[2]

print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_acc:.2%}")
print(f"Test Precision: {test_precision:.2%}")
# Out:
# Epoch 1/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 128s 4s/step - accuracy: 0.2116 - loss: 2.4602 - precision_1: 0.3614 - val_accuracy: 0.3145 - val_loss: 1.9391 - val_precision_1: 0.6818
# Epoch 2/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 54s 3s/step - accuracy: 0.5449 - loss: 1.3784 - precision_1: 0.6542 - val_accuracy: 0.4277 - val_loss: 1.6794 - val_precision_1: 0.6579
# Epoch 3/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 52s 3s/step - accuracy: 0.6108 - loss: 1.0897 - precision_1: 0.7557 - val_accuracy: 0.5094 - val_loss: 1.5489 - val_precision_1: 0.6226
# Epoch 4/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 47s 2s/step - accuracy: 0.6593 - loss: 0.9065 - precision_1: 0.7823 - val_accuracy: 0.4906 - val_loss: 1.5546 - val_precision_1: 0.6667
# Epoch 5/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 54s 3s/step - accuracy: 0.7666 - loss: 0.6762 - precision_1: 0.8589 - val_accuracy: 0.5157 - val_loss: 1.5082 - val_precision_1: 0.6970
# Epoch 6/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 63s 3s/step - accuracy: 0.7827 - loss: 0.6467 - precision_1: 0.8780 - val_accuracy: 0.5157 - val_loss: 1.4031 - val_precision_1: 0.7468
# Epoch 7/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - accuracy: 0.7922 - loss: 0.6007 - precision_1: 0.8716 - val_accuracy: 0.5220 - val_loss: 1.3876 - val_precision_1: 0.7529
# Epoch 8/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 83s 3s/step - accuracy: 0.8390 - loss: 0.4713 - precision_1: 0.9029 - val_accuracy: 0.5157 - val_loss: 1.3857 - val_precision_1: 0.7363
# Epoch 9/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 73s 4s/step - accuracy: 0.8389 - loss: 0.4223 - precision_1: 0.8825 - val_accuracy: 0.5094 - val_loss: 1.4022 - val_precision_1: 0.6923
# Epoch 10/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 66s 3s/step - accuracy: 0.8759 - loss: 0.3763 - precision_1: 0.9049 - val_accuracy: 0.4969 - val_loss: 1.3707 - val_precision_1: 0.6887
# Epoch 11/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 60s 3s/step - accuracy: 0.8693 - loss: 0.4177 - precision_1: 0.9156 - val_accuracy: 0.5283 - val_loss: 1.3398 - val_precision_1: 0.6792
# Epoch 12/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.8815 - loss: 0.3783 - precision_1: 0.9263 - val_accuracy: 0.4969 - val_loss: 1.3800 - val_precision_1: 0.6789
# Epoch 13/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9072 - loss: 0.2808 - precision_1: 0.9510 - val_accuracy: 0.5283 - val_loss: 1.3713 - val_precision_1: 0.6491
# Epoch 14/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.9063 - loss: 0.2907 - precision_1: 0.9561 - val_accuracy: 0.5283 - val_loss: 1.3785 - val_precision_1: 0.6695
# Epoch 15/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 47s 2s/step - accuracy: 0.9261 - loss: 0.2821 - precision_1: 0.9456 - val_accuracy: 0.5220 - val_loss: 1.4102 - val_precision_1: 0.6446
# Epoch 16/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 56s 3s/step - accuracy: 0.9256 - loss: 0.2635 - precision_1: 0.9570 - val_accuracy: 0.5535 - val_loss: 1.4276 - val_precision_1: 0.6387
# Epoch 17/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 70s 4s/step - accuracy: 0.8956 - loss: 0.2602 - precision_1: 0.9255 - val_accuracy: 0.5535 - val_loss: 1.4754 - val_precision_1: 0.6423
# Epoch 18/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 73s 4s/step - accuracy: 0.8930 - loss: 0.3321 - precision_1: 0.9104 - val_accuracy: 0.5660 - val_loss: 1.5959 - val_precision_1: 0.6320
# Epoch 19/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 64s 3s/step - accuracy: 0.9139 - loss: 0.2420 - precision_1: 0.9342 - val_accuracy: 0.5409 - val_loss: 1.5877 - val_precision_1: 0.6061
# Epoch 20/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 54s 3s/step - accuracy: 0.9330 - loss: 0.2241 - precision_1: 0.9543 - val_accuracy: 0.5346 - val_loss: 1.6425 - val_precision_1: 0.6183
# Epoch 21/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 85s 3s/step - accuracy: 0.9343 - loss: 0.2064 - precision_1: 0.9451 - val_accuracy: 0.5220 - val_loss: 1.6524 - val_precision_1: 0.6061
# Epoch 22/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 56s 3s/step - accuracy: 0.9363 - loss: 0.2152 - precision_1: 0.9442 - val_accuracy: 0.5409 - val_loss: 1.6698 - val_precision_1: 0.6183
# Epoch 23/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.9526 - loss: 0.1646 - precision_1: 0.9579 - val_accuracy: 0.5409 - val_loss: 1.7852 - val_precision_1: 0.6000
# Epoch 24/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 52s 3s/step - accuracy: 0.9424 - loss: 0.1883 - precision_1: 0.9507 - val_accuracy: 0.5597 - val_loss: 1.7280 - val_precision_1: 0.6194
# Epoch 25/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 85s 3s/step - accuracy: 0.9416 - loss: 0.1780 - precision_1: 0.9584 - val_accuracy: 0.5597 - val_loss: 1.7646 - val_precision_1: 0.6299
#
# Testing -------------------------------
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.7056 - loss: 1.0958 - precision_1: 0.7497
# Test Loss: 1.0295
# Test Accuracy: 72.50%
# Test Precision: 75.00%

# %%
from mobilenet_utils import plot_training_history

plot_training_history(history)

# %% [markdown]
# Classification report  + Confusion matrix

# %%
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix
import numpy as np

# Generujemy predykcje
y_pred = model.predict(val_generator)
y_pred_classes = np.argmax(y_pred, axis=1)

# Prawdziwe etykiety
y_true = val_generator.classes

# Nazwy klas
class_labels = list(val_generator.class_indices.keys())

cm = confusion_matrix(y_true, y_pred_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel("Prediction")
plt.ylabel("Class")
plt.title("Confusion matrix")
plt.show()
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 28s 4s/step
