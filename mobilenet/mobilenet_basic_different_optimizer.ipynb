# %% [markdown]
# MobileNet

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from mobilenet_utils import plot_training_history

# Params
img_size = 224
batch_size = 32
num_classes = 10

# Paths
train_dir = r"C:\Users\jakub\Desktop\muzyka_guiio\Music-Classification\project_data\train_spectrograms"
test_dir = r"C:\Users\jakub\Desktop\muzyka_guiio\Music-Classification\project_data\test_spectrograms"

# Train/val generators (80/20 split)
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)


print("Train:")
train_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='categorical',
    subset='training',
    shuffle=True
)

print("Val:")
val_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation',
    shuffle=False
)

# Test generator (no split)
test_datagen = ImageDataGenerator(rescale=1./255)

print("Test:")
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Train:
# Found 640 images belonging to 10 classes.
# Val:
# Found 159 images belonging to 10 classes.
# Test:
# Found 200 images belonging to 10 classes.

# %% [markdown]
# Most basic version - MobileNetV2, GlobalAvaragePooling2D

# %%
import tensorflow as tf
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from mobilenet_utils import plot_training_history
import os

optimizers = {
    "Adam": Adam(),
    "SGD": SGD(),
    "RMSprop": RMSprop()
}

results_summary = {}

for name, optimizer in optimizers.items():
    print(f"\n===== Trening z optymalizatorem: {name} =====")

    # Buduj model od nowa w każdej iteracji
    base_model = MobileNetV2(input_shape=(img_size, img_size, 3), include_top=False, weights='imagenet')
    base_model.trainable = False

    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    predictions = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs=base_model.input, outputs=predictions)

    model.compile(optimizer=optimizer,
                  loss='categorical_crossentropy',
                  metrics=['accuracy', tf.keras.metrics.Precision()])

    history = model.fit(
        train_generator,
        validation_data=val_generator,
        epochs=25
    )

    # Ewaluacja
    print("\nTesting ----------------------------")
    results = model.evaluate(test_generator, verbose=0)

    test_loss, test_acc, test_precision = results[0], results[1], results[2]
    print(f"{name} - Test Loss: {test_loss:.4f} | Accuracy: {test_acc:.2%} | Precision: {test_precision:.2%}")

    # Zapisz wyniki
    results_summary[name] = {
        "loss": test_loss,
        "accuracy": test_acc,
        "precision": test_precision,
        "history": history
    }

    # Wyświetl wykresy
    plot_training_history(history)
# Out:
# ===== Trening z optymalizatorem: Adam =====
# Epoch 1/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.1285 - loss: 2.7397 - precision_1: 0.0619 - val_accuracy: 0.3145 - val_loss: 1.8968 - val_precision_1: 0.7059
# Epoch 2/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.4382 - loss: 1.6851 - precision_1: 0.8214 - val_accuracy: 0.4403 - val_loss: 1.6294 - val_precision_1: 0.7941
# Epoch 3/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 18s 916ms/step - accuracy: 0.5338 - loss: 1.4009 - precision_1: 0.9094 - val_accuracy: 0.4654 - val_loss: 1.5394 - val_precision_1: 0.8000
# Epoch 4/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 18s 925ms/step - accuracy: 0.5908 - loss: 1.2370 - precision_1: 0.8722 - val_accuracy: 0.4528 - val_loss: 1.4947 - val_precision_1: 0.7895
# Epoch 5/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 19s 945ms/step - accuracy: 0.6421 - loss: 1.1133 - precision_1: 0.8812 - val_accuracy: 0.5094 - val_loss: 1.4269 - val_precision_1: 0.7544
# Epoch 6/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 983ms/step - accuracy: 0.6383 - loss: 1.0822 - precision_1: 0.8620 - val_accuracy: 0.5157 - val_loss: 1.3991 - val_precision_1: 0.7606
# Epoch 7/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 19s 946ms/step - accuracy: 0.7153 - loss: 0.9551 - precision_1: 0.8674 - val_accuracy: 0.5220 - val_loss: 1.3545 - val_precision_1: 0.7703
# Epoch 8/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 19s
25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.7291 - loss: 0.8718 - precision_2: 0.9046 - val_accuracy: 0.4780 - val_loss: 1.3588 - val_precision_2: 0.6951
# Epoch 19/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 19s 973ms/step - accuracy: 0.7088 - loss: 0.8955 - precision_2: 0.8714 - val_accuracy: 0.5220 - val_loss: 1.2956 - val_precision_2: 0.7011
# Epoch 20/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.7602 - loss: 0.8178 - precision_2: 0.8935 - val_accuracy: 0.5094 - val_loss: 1.3226 - val_precision_2: 0.6744
# Epoch 21/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 998ms/step - accuracy: 0.7523 - loss: 0.8123 - precision_2: 0.8988 - val_accuracy: 0.5597 - val_loss: 1.2990 - val_precision_2: 0.7059
# Epoch 22/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.7479 - loss: 0.7977 - precision_2: 0.8954 - val_accuracy: 0.5094 - val_loss: 1.2998 - val_precision_2: 0.6977
# Epoch 23/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 982ms/step - accuracy: 0.7541 - loss: 0.7976 - precision_2: 0.9089 - val_accuracy: 0.5283 - val_loss: 1.3263 - val_precision_2: 0.6705
# Epoch 24/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 999ms/step - accuracy: 0.7864 - loss: 0.7737 - precision_2: 0.8838 - val_accuracy: 0.5157 - val_loss: 1.3049 - val_precision_2: 0.6848
# Epoch 25/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.7669 - loss: 0.8098 - precision_2: 0.8897 - val_accuracy: 0.5157 - val_loss: 1.2948 - val_precision_2: 0.7159
#
# Testing ----------------------------
# SGD - Test Loss: 1.0301 | Accuracy: 66.50% | Precision: 78.69%
# ===== Trening z optymalizatorem: RMSprop =====
# Epoch 1/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.2187 - loss: 2.1774 - precision_3: 0.3334 - val_accuracy: 0.4403 - val_loss: 1.6679 - val_precision_3: 0.9474
# Epoch 2/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 18s 906ms/step - accuracy: 0.4759 - loss: 1.5423 - precision_3: 0.8209 - val_accuracy: 0.4528 - val_loss: 1.5586 - val_precision_3: 0.7895
# Epoch 3/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 18s 926ms/step - accuracy: 0.5842 - loss: 1.2809 - precision_3: 0.8626 - val_accuracy: 0.4969 - val_loss: 1.4007 - val_precision_3: 0.8913
# Epoch 4/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 18s 921ms/step - accuracy: 0.6339 - loss: 1.1693 - precision_3: 0.8565 - val_accuracy: 0.4654 - val_loss: 1.3998 - val_precision_3: 0.7571
# Epoch 5/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 18s 916ms/step - accuracy: 0.6800 - loss: 1.0116 - precision_3: 0.8923 - val_accuracy: 0.5094 - val_loss: 1.3612 - val_precision_3: 0.7101
# Epoch 6/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 19s 941ms/step - accuracy: 0.7114 - loss: 0.9848 - precision_3: 0.8918 - val_accuracy: 0.5346 - val_loss: 1.3070 - val_precision_3: 0.7945
# Epoch 7/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.7476 - loss: 0.8545 - precision_3: 0.8799 - val_accuracy: 0.5157 - val_loss: 1.3098 - val_precision_3: 0.7564
# Epoch 8/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.7596 - loss: 0.8492 - precision_3: 0.8925 - val_accuracy: 0.5283 - val_loss: 1.3433 - val_precision_3: 0.6813
# Epoch 9/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.7751 - loss: 0.7630 - precision_3: 0.9024 - val_accuracy: 0.5346 - val_loss: 1.3188 - val_precision_3: 0.6907
# Epoch 10/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 996ms/step - accuracy: 0.7684 - loss: 0.7938 - precision_3: 0.8958 - val_accuracy: 0.5220 - val_loss: 1.2965 - val_precision_3: 0.7143
# Epoch 11/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.7954 - loss: 0.7153 - precision_3: 0.9201 - val_accuracy: 0.5597 - val_loss: 1.2684 - val_precision_3: 0.7188
# Epoch 12/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.8077 - loss: 0.6980 - precision_3: 0.9179 - val_accuracy: 0.5535 - val_loss: 1.2802 - val_precision_3: 0.6800
# Epoch 13/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.8321 - loss: 0.6390 - precision_3: 0.9367 - val_accuracy: 0.5597 - val_loss: 1.2736 - val_precision_3: 0.6822
# Epoch 14/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.8066 - loss: 0.6377 - precision_3: 0.9106 - val_accuracy: 0.5283 - val_loss: 1.3610 - val_precision_3: 0.6697
# Epoch 15/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.8454 - loss: 0.5698 - precision_3: 0.9306 - val_accuracy: 0.5283 - val_loss: 1.3019 - val_precision_3: 0.6757
# Epoch 16/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 19s 972ms/step - accuracy: 0.8378 - loss: 0.6015 - precision_3: 0.9224 - val_accuracy: 0.5346 - val_loss: 1.3428 - val_precision_3: 0.6727
# Epoch 17/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 993ms/step - accuracy: 0.8364 - loss: 0.5892 - precision_3: 0.9262 - val_accuracy: 0.5283 - val_loss: 1.3349 - val_precision_3: 0.6481
# Epoch 18/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.8477 - loss: 0.5468 - precision_3: 0.9221 - val_accuracy: 0.5283 - val_loss: 1.3175 - val_precision_3: 0.6893
# Epoch 19/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.8563 - loss: 0.5441 - precision_3: 0.9471 - val_accuracy: 0.5157 - val_loss: 1.3357 - val_precision_3: 0.6429
# Epoch 20/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.8828 - loss: 0.4900 - precision_3: 0.9500 - val_accuracy: 0.5157 - val_loss: 1.3687 - val_precision_3: 0.6316
# Epoch 21/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.8671 - loss: 0.4848 - precision_3: 0.9293 - val_accuracy: 0.5535 - val_loss: 1.3122 - val_precision_3: 0.6726
# Epoch 22/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.8941 - loss: 0.4438 - precision_3: 0.9452 - val_accuracy: 0.5031 - val_loss: 1.3942 - val_precision_3: 0.6033
# Epoch 23/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.8750 - loss: 0.4891 - precision_3: 0.9408 - val_accuracy: 0.5535 - val_loss: 1.3633 - val_precision_3: 0.6522
# Epoch 24/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.8773 - loss: 0.4491 - precision_3: 0.9429 - val_accuracy: 0.5597 - val_loss: 1.3117 - val_precision_3: 0.6897
# Epoch 25/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.8879 - loss: 0.4265 - precision_3: 0.9559 - val_accuracy: 0.5472 - val_loss: 1.3344 - val_precision_3: 0.6637
#
# Testing ----------------------------
# RMSprop - Test Loss: 0.8809 | Accuracy: 74.00% | Precision: 81.94%

# %% [markdown]
# Classification report  + Confusion matrix

# %%
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix
import numpy as np

# Generujemy predykcje
y_pred = model.predict(val_generator)
y_pred_classes = np.argmax(y_pred, axis=1)

# Prawdziwe etykiety
y_true = val_generator.classes

# Nazwy klas
class_labels = list(val_generator.class_indices.keys())

cm = confusion_matrix(y_true, y_pred_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel("Prediction")
plt.ylabel("Class")
plt.title("Confusion matrix")
plt.show()
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step

# %% [markdown]
# wnioski z różnych optymalizatorów:
# - SGD wypada najgorzej
# - Adam i RMSProp analogicznie ()
