# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Params
img_size = 224
batch_size = 32
num_classes = 10

# Paths
train_dir = r"C:\Users\Dell\Desktop\Music-Classification-MobileNet1\project_data\train_spectrograms"
test_dir = r"C:\Users\Dell\Desktop\Music-Classification-MobileNet1\project_data\test_spectrograms"

# Train/val generators (80/20 split)
datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=10,
    horizontal_flip=True,
    validation_split=0.2
)


print("Train:")
train_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='categorical',
    subset='training',
    shuffle=True
)

print("Val:")
val_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation',
    shuffle=False
)

# Test generator (no split)
test_datagen = ImageDataGenerator(rescale=1./255)

print("Test:")
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Train:
# Found 766 images belonging to 10 classes.
# Val:
# Found 188 images belonging to 10 classes.
# Test:
# Found 355 images belonging to 10 classes.

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model
import os


# Model setup
base_model = MobileNetV2(input_shape=(img_size, img_size, 3), include_top=False, weights='imagenet')
base_model.trainable = False  # Freeze base layers

x = base_model.output
x = GlobalAveragePooling2D()(x)        # Flatten conv output
predictions = Dense(num_classes, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# Compile
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy',tf.keras.metrics.Precision()])

# Train
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=25
)

# Save model
name_model="models/dataAug_rotation10_Flip.keras"
model.save(name_model)

# Test evaluation
print("\nTesting -------------------------------")
results = model.evaluate(test_generator)

# Indeksy: [0] = loss, [1] = accuracy, [2] = precision
test_loss = results[0]
test_acc = results[1]
test_precision = results[2]

print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_acc:.2%}")
print(f"Test Precision: {test_precision:.2%}")
# Out:
# Epoch 1/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.1410 - loss: 2.5288 - precision_1: 0.0400 - val_accuracy: 0.3670 - val_loss: 1.8812 - val_precision_1: 0.8462
# Epoch 2/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.4306 - loss: 1.7173 - precision_1: 0.8990 - val_accuracy: 0.4574 - val_loss: 1.5670 - val_precision_1: 0.8000
# Epoch 3/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.5454 - loss: 1.4055 - precision_1: 0.9408 - val_accuracy: 0.4787 - val_loss: 1.5027 - val_precision_1: 0.7500
# Epoch 4/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.5900 - loss: 1.2596 - precision_1: 0.8893 - val_accuracy: 0.5638 - val_loss: 1.3750 - val_precision_1: 0.7887
# Epoch 5/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.6298 - loss: 1.1651 - precision_1: 0.8814 - val_accuracy: 0.5000 - val_loss: 1.3945 - val_precision_1: 0.7632
# Epoch 6/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.6608 - loss: 1.0221 - precision_1: 0.8773 - val_accuracy: 0.5319 - val_loss: 1.3615 - val_precision_1: 0.7529
# Epoch 7/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.6415 - loss: 1.0561 - precision_1: 0.8503 - val_accuracy: 0.5000 - val_loss: 1.3275 - val_precision_1: 0.7727
# Epoch 8/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.6834 - loss: 0.9625 - precision_1: 0.8695 - val_accuracy: 0.5106 - val_loss: 1.3797 - val_precision_1: 0.6735
# Epoch 9/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.6855 - loss: 0.9583 - precision_1: 0.8342 - val_accuracy: 0.5213 - val_loss: 1.3245 - val_precision_1: 0.7525
# Epoch 10/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.7076 - loss: 0.8635 - precision_1: 0.8684 - val_accuracy: 0.5160 - val_loss: 1.3326 - val_precision_1: 0.7333
# Epoch 11/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.7116 - loss: 0.8789 - precision_1: 0.8705 - val_accuracy: 0.5266 - val_loss: 1.3639 - val_precision_1: 0.7100
# Epoch 12/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.7179 - loss: 0.8767 - precision_1: 0.8400 - val_accuracy: 0.5585 - val_loss: 1.3012 - val_precision_1: 0.7523
# Epoch 13/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.7138 - loss: 0.8480 - precision_1: 0.8540 - val_accuracy: 0.5213 - val_loss: 1.3084 - val_precision_1: 0.7282
# Epoch 14/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.7355 - loss: 0.8020 - precision_1: 0.8820 - val_accuracy: 0.5372 - val_loss: 1.3014 - val_precision_1: 0.7315
# Epoch 15/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 23s 966ms/step - accuracy: 0.7471 - loss: 0.7713 - precision_1: 0.8637 - val_accuracy: 0.5426 - val_loss: 1.3119 - val_precision_1: 0.7647
# Epoch 16/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 24s 986ms/step - accuracy: 0.7765 - loss: 0.7600 - precision_1: 0.8950 - val_accuracy: 0.5372 - val_loss: 1.2693 - val_precision_1: 0.7182
# Epoch 17/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.7555 - loss: 0.7857 - precision_1: 0.8600 - val_accuracy: 0.5638 - val_loss: 1.2391 - val_precision_1: 0.7523
# Epoch 18/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.8106 - loss: 0.6807 - precision_1: 0.9360 - val_accuracy: 0.5426 - val_loss: 1.2860 - val_precision_1: 0.6860
# Epoch 19/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 24s 999ms/step - accuracy: 0.7730 - loss: 0.7343 - precision_1: 0.8637 - val_accuracy: 0.5585 - val_loss: 1.2079 - val_precision_1: 0.7636
# Epoch 20/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 24s 987ms/step - accuracy: 0.7629 - loss: 0.7042 - precision_1: 0.9012 - val_accuracy: 0.5372 - val_loss: 1.2548 - val_precision_1: 0.7069
# Epoch 21/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 23s 969ms/step - accuracy: 0.7787 - loss: 0.7108 - precision_1: 0.8951 - val_accuracy: 0.5479 - val_loss: 1.2213 - val_precision_1: 0.7009
# Epoch 22/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 23s 973ms/step - accuracy: 0.7903 - loss: 0.6702 - precision_1: 0.9313 - val_accuracy: 0.5532 - val_loss: 1.2490 - val_precision_1: 0.7288
# Epoch 23/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 23s 979ms/step - accuracy: 0.7831 - loss: 0.6814 - precision_1: 0.8904 - val_accuracy: 0.5372 - val_loss: 1.2991 - val_precision_1: 0.7190
# Epoch 24/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.8023 - loss: 0.6279 - precision_1: 0.9083 - val_accuracy: 0.5319 - val_loss: 1.3407 - val_precision_1: 0.7059
# Epoch 25/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 24s 997ms/step - accuracy: 0.8005 - loss: 0.6572 - precision_1: 0.9148 - val_accuracy: 0.5798 - val_loss: 1.2144 - val_precision_1: 0.7167
#
# Testing -------------------------------
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 7s 570ms/step - accuracy: 0.6569 - loss: 0.9756 - precision_1: 0.7717
# Test Loss: 0.9155
# Test Accuracy: 68.45%
# Test Precision: 80.65%

# %%
from mobilenet_utils import plot_training_history

plot_training_history(history)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix
import numpy as np

# Generujemy predykcje
y_pred = model.predict(val_generator)
y_pred_classes = np.argmax(y_pred, axis=1)

# Prawdziwe etykiety
y_true = val_generator.classes

# Nazwy klas
class_labels = list(val_generator.class_indices.keys())

cm = confusion_matrix(y_true, y_pred_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel("Prediction")
plt.ylabel("Class")
plt.title("Confusion matrix")
plt.show()
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step
